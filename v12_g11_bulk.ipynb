# %%
# imports libraries + project modules
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# plotting and tsv 
import TsvMapHelperFunctions as helper
#genome loading/guide mapping
import postprocessHelpers as php

# %%
# Load genome sequence from FASTA file
from Bio import SeqIO

genome_fasta = 'cJP003_assembly.fasta'  # or your genome filename
genome_sequence = str(next(SeqIO.parse(genome_fasta, "fasta")).seq).upper()

print(f"Genome loaded: {len(genome_sequence)} bp")
# Out:
# Genome loaded: 4634619 bp

# %%
# Bulk configuration: discover TSVs and set output directory
from pathlib import Path
import re
import pandas as pd

# Folder containing TSVs (relative to notebook, or set absolute path)
input_tsv_dir = Path("combined_R1_tsv_files")

# Where to write per-sample CSV outputs (change this)
output_csv_dir = Path("/Users/ecreed/Desktop/KelloggRotation/02052026_TagmentatioAnalysis_251218_260117_260203_combined/FilteredCandidateSpacersBulk")
output_csv_dir.mkdir(parents=True, exist_ok=True)

# Discover TSV files following: {i}_S{i}_L001_R1_001.insertions.5p.tsv
tsv_files = sorted(
    input_tsv_dir.glob("*_S*_L001_R1_001.insertions.5p.tsv"),
    key=lambda p: int(re.match(r"(\d+)_S\1_", p.name).group(1)) if re.match(r"(\d+)_S\1_", p.name) else p.name
)

print(f"Found {len(tsv_files)} TSV files in {input_tsv_dir}")

# Load guide RNA info (must align 1:1 with tsv_files ordering/indexing)
guideRNA = pd.read_csv("FinalGuides_251218_260117_260203_combined.csv")

# Filters / knobs used elsewhere (do not change processing logic below)
min_mapq = 30
# Out:
# Found 120 TSV files in combined_R1_tsv_files

# %%
window_bp = 200

def percent_within_distance(insertions, target_position, window_bp):
    
    if len(insertions) == 0:
        return 0.0
    
    count_within = sum(
        abs(pos - target_position) <= window_bp
        for pos in insertions
    )
    
    return 100.0 * count_within / len(insertions)

# %%
# find PAM and making new sgRNA sequences

from typing import List, Dict

def find_pam_and_generate_sgrna(
    genome_seq: str,
    alignment_start: int,
    alignment_end: int,
    best_strand: str,
    window_bp: int = 25,
    pam_motif: str = "NGG",
    spacer_len: int = 20,
) -> list[dict]:
    """
    Find PAM sites in a window around guide alignment and generate sgRNA sequences.
    """
    alignment_center = (alignment_start + alignment_end) // 2
    search_start = max(0, alignment_center - window_bp)
    search_end = min(len(genome_seq), alignment_center + window_bp)
    window_seq = genome_seq[search_start:search_end]
    
    results = []
    
    pam_hits = php.extract_spacers(  # <-- use php prefix
        window_seq,
        pam_motif,
        spacer_len=spacer_len,
        spacer_side="5prime",
        search_strands="both"
    )
    
    for hit in pam_hits:
        pam_start_genomic = search_start + hit.pam_start
        pam_end_genomic = search_start + hit.pam_end
        spacer_start_genomic = search_start + hit.spacer_start
        spacer_end_genomic = search_start + hit.spacer_end
        
        if pam_end_genomic <= alignment_start:
            distance = alignment_start - pam_end_genomic
            position_rel = "upstream"
        elif pam_start_genomic >= alignment_end:
            distance = pam_start_genomic - alignment_end
            position_rel = "downstream"
        else:
            distance = 0
            position_rel = "overlapping"
        
        spacer_seq = genome_seq[spacer_start_genomic:spacer_end_genomic]
        
        results.append({
            'pam_start': pam_start_genomic,
            'pam_end': pam_end_genomic,
            'spacer_start': spacer_start_genomic,
            'spacer_end': spacer_end_genomic,
            'pam_seq': hit.pam_dna,
            'spacer_seq': spacer_seq,
            'strand': hit.strand,
            'distance_to_alignment': distance,
            'position_relative_to_alignment': position_rel,
        })
    
    results.sort(key=lambda x: x['distance_to_alignment'])
    return results

# %%
# v4 csv output, target site fixed
# v3 single csv, calculate integration freq from cluster
# filtered candidate spacers single csv with insertion strand distribution and frequency columns 
# bulk run + filtering by NGG and distance
# Bulk: write per-sample CSVs but only include NGG guides 66-76 bp from their mcv
# ENHANCED: add strand distribution and hotspot frequency columns
# FIXED: integration_frequency now sums across all cluster members, not just rep_pos

import re
import pandas as pd
from collections import Counter
from pathlib import Path

def revcomp(seq):
    comp = str.maketrans("ACGTacgt", "TGCAtgca")
    return seq.translate(comp)[::-1]

def _sample_id_from_name(p: Path):
    m = re.match(r"(\d+)_S\1_", p.name)
    return int(m.group(1)) if m else None

written = []
skipped = []
all_rows = []

for nn, tsv_path in enumerate(tsv_files):
    sample_id = _sample_id_from_name(tsv_path) or (nn + 1)

    # load + basic filter (min_mapq expected in notebook)
    tsv = pd.read_csv(tsv_path, sep="\t")
    tsv = tsv[tsv["mapq"] >= min_mapq]
    
    # Calculate total insertions in sample and strand counts per insertion position
    total_insertions = len(tsv)
    insertion_strands = {}  # {position: {'+': count, '-': count}}
    for _, row in tsv.iterrows():
        pos = row["ins0"]
        strand = row.get("strand", "+")  # default to + if not present
        if pos not in insertion_strands:
            insertion_strands[pos] = {'+': 0, '-': 0}
        insertion_strands[pos][strand] = insertion_strands[pos].get(strand, 0) + 1

    # collapse hotspots (same logic as before)
    collapse_bp = 5
    min_reads = 500

    counts = Counter(tsv["ins0"])
    gmap = php.map_guide_to_genome(guideRNA["protospacer"][nn], genome_sequence)
    target_guide_start = gmap[0]["start"]
    target_strand = gmap[0]["strand"]
    if target_strand == "+":
        target_insertion_site = target_guide_start + 20 + 2 + 71
    else:
        target_insertion_site = target_guide_start - 2 - 71
    counts[target_insertion_site] = counts.get(target_insertion_site, 0)

    clusters = [{"members": {pos: freq}, "total": freq} for pos, freq in counts.items()]
    merged = True
    while merged:
        merged = False
        new_clusters = []
        while clusters:
            c = clusters.pop(0)
            i = 0
            while i < len(clusters):
                other = clusters[i]
                close = any(abs(p - q) <= collapse_bp for p in c["members"] for q in other["members"])
                if close:
                    for p, f in other["members"].items():
                        c["members"][p] = c["members"].get(p, 0) + f
                    c["total"] += other["total"]
                    clusters.pop(i)
                    merged = True
                else:
                    i += 1
            new_clusters.append(c)
        clusters = new_clusters

    clusters_info = []
    for c in clusters:
        rep_pos, rep_count = max(c["members"].items(), key=lambda x: x[1])
        clusters_info.append({
            "rep_pos": int(rep_pos),
            "rep_count": int(rep_count),
            "total": int(c["total"]),
            "members": sorted(c["members"].keys()),
            "contains_target": (target_insertion_site in c["members"])
        })

    filtered = [c for c in clusters_info if c["total"] > min_reads]
    if not any(c["contains_target"] for c in filtered):
        for c in clusters_info:
            if c["contains_target"]:
                filtered.append(c)
                break

    filtered.sort(key=lambda x: x["total"], reverse=True)
    for idx, c in enumerate(filtered, start=1):
        c["mcv_id"] = idx

    # Build a lookup: rep_pos -> cluster info (for fast integration frequency calculation)
    cluster_lookup = {c["rep_pos"]: c for c in filtered}

    mcv_list = [c["rep_pos"] for c in filtered]
    hotspots = {f"mcv{idx}": pos for idx, pos in enumerate(mcv_list, start=1)}
    for idx, pos in enumerate(mcv_list, start=1):
        globals()[f"mcv{idx}"] = pos

    # Generate guides (methods 1,2,3) exactly as before
    original_guide = guideRNA["protospacer"][nn]
    hotspots_dict = hotspots if (isinstance(hotspots, dict) and hotspots) else ({f"mcv{i+1}": pos for i,pos in enumerate(mcv_list)} if "mcv_list" in globals() else {})
    _alignment_ctx = {}
    for hotspot_name, insertion_site in hotspots_dict.items():
        window_start = max(0, insertion_site - 120)
        window_end = min(len(genome_sequence), insertion_site + 120)
        window_seq = genome_sequence[window_start:window_end]

        aln_fwd = php.local_align(original_guide, window_seq)
        aln_rev = php.local_align(original_guide, revcomp(window_seq))

        if aln_fwd.score >= aln_rev.score:
            best_aln = aln_fwd
            best_strand = "+"
            search_seq = window_seq
        else:
            best_aln = aln_rev
            best_strand = "-"
            search_seq = revcomp(window_seq)

        _alignment_ctx[hotspot_name] = {
            "insertion_site": insertion_site,
            "window_start": window_start,
            "window_end": window_end,
            "window_seq": window_seq,
            "best_aln": best_aln,
            "best_strand": best_strand,
            "search_seq": search_seq,
        }

    rows = []

    window_radius = 120
    # Method 1
    for hotspot_name, insertion_site in hotspots_dict.items():
        win_start = max(0, insertion_site - window_radius)
        win_end = min(len(genome_sequence), insertion_site + window_radius)
        win_seq = genome_sequence[win_start:win_end]

        for i in range(len(win_seq) - 2):
            pam = win_seq[i:i+3]
            if pam[1:3] == "GG":
                pam_genomic_start = win_start + i
                pam_genomic_end = pam_genomic_start + 3
                guide_start = pam_genomic_start - 20
                guide_end = pam_genomic_start
                if guide_start < 0:
                    continue
                guide_seq = genome_sequence[guide_start:guide_end]
                dist = abs((pam_genomic_end - 1) - insertion_site)
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 1,
                    "pam_type": "NGG",
                    "pam_seq": pam,
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "+",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(dist),
                    "insertion_site": int(insertion_site)
                })

        for i in range(len(win_seq) - 2):
            motif = win_seq[i:i+3]
            if motif[0:2] == "CC":
                pam_genomic_start = win_start + i
                pam_genomic_end = pam_genomic_start + 3
                guide_start = pam_genomic_end
                guide_end = guide_start + 20
                if guide_end > len(genome_sequence):
                    continue
                guide_seq = revcomp(genome_sequence[guide_start:guide_end])
                dist = abs(pam_genomic_start - insertion_site)
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 1,
                    "pam_type": "NGG",
                    "pam_seq": revcomp(motif),
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "-",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(dist),
                    "insertion_site": int(insertion_site)
                })

    # Method 2
    for hotspot_name, ctx in _alignment_ctx.items():
        insertion_site = ctx["insertion_site"]
        window_start = ctx["window_start"]
        window_seq = ctx["window_seq"]
        best_aln = ctx["best_aln"]
        best_strand = ctx["best_strand"]
        search_seq = ctx["search_seq"]

        target_coords = best_aln.coordinates[1]
        target_start = int(target_coords[0])
        target_end = int(target_coords[-1])

        if best_strand == "+":
            genomic_start = window_start + target_start
            genomic_end = window_start + target_end
        else:
            genomic_start = window_start + (len(window_seq) - target_end)
            genomic_end = window_start + (len(window_seq) - target_start)

        coords_q = best_aln.coordinates[0]
        coords_t = best_aln.coordinates[1]

        query_seq = best_aln.query
        target_seq = best_aln.target

        first_match_query_pos = None
        first_match_target_pos = None
        query_pos = 0
        target_pos = 0
        for q, t in zip(query_seq, target_seq):
            if q != "-" and t != "-" and q == t:
                first_match_query_pos = query_pos
                first_match_target_pos = target_pos
                break
            if q != "-":
                query_pos += 1
            if t != "-":
                target_pos += 1

        if first_match_query_pos is not None:
            first_match_genomic = genomic_start + first_match_target_pos
            new_guide_start = first_match_genomic - first_match_query_pos
            new_guide_end = new_guide_start + 20
            if 0 <= new_guide_start and new_guide_end <= len(genome_sequence):
                if best_strand == "+":
                    new_guide = genome_sequence[new_guide_start:new_guide_end]
                    new_guide_gstart = new_guide_start
                    new_guide_gend = new_guide_end
                else:
                    new_guide = revcomp(genome_sequence[new_guide_start:new_guide_end])
                    new_guide_gstart = new_guide_start
                    new_guide_gend = new_guide_end

                if best_strand == "+":
                    five_prime_start = target_start - 3
                    five_prime_end = target_start
                    five_prime_seq = window_seq[five_prime_start:five_prime_end] if five_prime_start >= 0 else ""
                    distance_to_mcv = abs(new_guide_gstart - insertion_site)
                else:
                    five_prime_start = target_end
                    five_prime_end = target_end + 3
                    five_prime_seq = revcomp(window_seq)[five_prime_start:five_prime_end] if five_prime_end <= len(window_seq) else ""
                    distance_to_mcv = abs(new_guide_gend - insertion_site)

                pam_type = None
                pam_seq = five_prime_seq
                if len(pam_seq) == 3:
                    if pam_seq[1:3] == "GG":
                        pam_type = "NGG"
                    elif pam_seq[1:3] == "AG":
                        pam_type = "NAG"
                    elif pam_seq[1:3] == "GA":
                        pam_type = "NGA"

                if pam_type:
                    mismatch_count = sum(a != b for a, b in zip(original_guide, new_guide))
                    try:
                        aln_score = php.local_align(original_guide, new_guide).score
                    except Exception:
                        aln_score = None

                    rows.append({
                        "hotspot": hotspot_name,
                        "method": 2,
                        "pam_type": pam_type,
                        "pam_seq": pam_seq,
                        "guide_seq": new_guide,
                        "guide_start": int(new_guide_gstart),
                        "guide_end": int(new_guide_gend),
                        "strand": best_strand,
                        "mismatch_count": int(mismatch_count),
                        "alignment_score": aln_score,
                        "distance_to_mcv": int(distance_to_mcv),
                        "insertion_site": int(insertion_site)
                    })

    # Method 3
    for hotspot_name, ctx in _alignment_ctx.items():
        insertion_site = ctx["insertion_site"]
        window_start = ctx["window_start"]
        window_seq = ctx["window_seq"]
        best_aln = ctx["best_aln"]
        best_strand = ctx["best_strand"]

        target_coords = best_aln.coordinates[1]
        target_start = int(target_coords[0])
        target_end = int(target_coords[-1])

        if best_strand == "+":
            genomic_start = window_start + target_start
            genomic_end = window_start + target_end
        else:
            genomic_start = window_start + (len(window_seq) - target_end)
            genomic_end = window_start + (len(window_seq) - target_start)

        alignment_center = (genomic_start + genomic_end) // 2
        pam_search_start = max(0, alignment_center - 25)
        pam_search_end = min(len(genome_sequence), alignment_center + 25)
        pam_search_seq = genome_sequence[pam_search_start:pam_search_end]

        for i in range(len(pam_search_seq) - 2):
            pam_motif = pam_search_seq[i:i+3]
            pam_type = None
            if pam_motif[1:3] == "GG":
                pam_type = "NGG"
            elif pam_motif[1:3] == "AG":
                pam_type = "NAG"
            elif pam_motif[1:3] == "GA":
                pam_type = "NGA"
            if not pam_type:
                continue

            pam_genomic_start = pam_search_start + i
            pam_genomic_end = pam_genomic_start + 3

            guide_start = pam_genomic_start - 20
            guide_end = pam_genomic_start
            if guide_start >= 0:
                guide_seq = genome_sequence[guide_start:guide_end]
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                distance_to_mcv = abs(pam_genomic_end - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 3,
                    "pam_type": pam_type,
                    "pam_seq": genome_sequence[pam_genomic_start:pam_genomic_end],
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "+",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(distance_to_mcv),
                    "insertion_site": int(insertion_site)
                })

        for i in range(len(pam_search_seq) - 2):
            pam_motif = pam_search_seq[i:i+3]
            pam_type = None
            if pam_motif[0:2] == "CC":
                pam_type = "NGG"
            elif pam_motif[0:2] == "CT":
                pam_type = "NAG"
            elif pam_motif[0:2] == "TC":
                pam_type = "NGA"
            if not pam_type:
                continue

            pam_genomic_start = pam_search_start + i
            pam_genomic_end = pam_genomic_start + 3

            guide_start = pam_genomic_end
            guide_end = guide_start + 20
            if guide_end <= len(genome_sequence):
                guide_seq = revcomp(genome_sequence[guide_start:guide_end])
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                distance_to_mcv = abs(pam_genomic_start - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 3,
                    "pam_type": pam_type,
                    "pam_seq": revcomp(genome_sequence[pam_genomic_start:pam_genomic_end]),
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "-",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(distance_to_mcv),
                    "insertion_site": int(insertion_site)
                })

    # assemble DataFrame and compute PAM coords
    def compute_pam_coords(row):
        try:
            gs = int(row['guide_start']); ge = int(row['guide_end']); strand = row['strand']
        except Exception:
            return pd.Series([None, None])
        if strand == "+":
            return pd.Series([ge, ge + 3])
        else:
            return pd.Series([gs - 3, gs])

    df = pd.DataFrame(rows)
    if df.empty:
        skipped.append((sample_id, str(tsv_path), "No candidates generated"))
        continue

    df[['pam_start', 'pam_end']] = df.apply(compute_pam_coords, axis=1)
    df = df.dropna(subset=['pam_start','pam_end']).reset_index(drop=True)
    df['pam_start'] = df['pam_start'].astype(int)
    df['pam_end'] = df['pam_end'].astype(int)

    pams_unique = df[['hotspot','pam_start','pam_end','pam_type']].drop_duplicates().reset_index(drop=True)
    def overlap(a_s, a_e, b_s, b_e):
        return (a_s < b_e) and (b_s < a_e)

    pams_unique['overlap_any'] = False
    pams_unique['overlap_noncanonical'] = False
    pams_unique['adj_left_any'] = False
    pams_unique['adj_left_noncanonical'] = False
    pams_unique['adj_right_any'] = False
    pams_unique['adj_right_noncanonical'] = False

    for idx, p in pams_unique.iterrows():
        ps, pe, ptype, hotspot = int(p.pam_start), int(p.pam_end), p.pam_type, p.hotspot
        partners = pams_unique[(pams_unique.hotspot == hotspot) & ~((pams_unique.pam_start == ps) & (pams_unique.pam_end == pe))]
        for _, q in partners.iterrows():
            qs, qe, qtype = int(q.pam_start), int(q.pam_end), q.pam_type
            if overlap(ps,pe,qs,qe):
                pams_unique.at[idx,'overlap_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'overlap_noncanonical'] = True
            if qe == ps:
                pams_unique.at[idx,'adj_left_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'adj_left_noncanonical'] = True
            if qs == pe:
                pams_unique.at[idx,'adj_right_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'adj_right_noncanonical'] = True

    df = df.merge(pams_unique, on=['hotspot','pam_start','pam_end','pam_type'], how='left', suffixes=('','_u'))
    
    # Keep only NGG rows and then further filter 66-76 bp
    df_ngg = df[df['pam_type'] == 'NGG'].copy()
    df_ngg_filtered = df_ngg[df_ngg['distance_to_mcv'].between(66, 76)].copy()

    if df_ngg_filtered.empty:
        skipped.append((sample_id, str(tsv_path), "No NGG candidates 66-76 bp"))
        continue

    # Add two new columns: strand_distribution and integration_frequency
    # strand_distribution: "#+ vs #-" format showing insertion counts at that hotspot by strand
    # integration_frequency: sum of all insertions in the cluster / total sample insertions
    def calc_integration_freq(pos):
        cluster = cluster_lookup.get(pos)
        if cluster:
            cluster_total = cluster['total']
            if cluster_total > 0 and total_insertions > 0:
                freq = 100.0 * cluster_total / total_insertions
                return f"{freq:.2f}%"
            elif cluster.get('contains_target', False):
                # This is the target site with no actual integration reads
                return "Target (0%)"
        return "0.00%"
    
    def calc_strand_dist(pos):
        cluster = cluster_lookup.get(pos)
        if cluster:
            plus_total = 0
            minus_total = 0
            for member_pos in cluster['members']:
                strands = insertion_strands.get(member_pos, {'+': 0, '-': 0})
                plus_total += strands.get('+', 0)
                minus_total += strands.get('-', 0)
            if plus_total == 0 and minus_total == 0 and cluster.get('contains_target', False):
                return "Target (0/0)"
            return f"{plus_total}/{minus_total}"
        return "0/0"
    
    df_ngg_filtered['strand_distribution'] = df_ngg_filtered['insertion_site'].apply(calc_strand_dist)
    df_ngg_filtered['integration_frequency'] = df_ngg_filtered['insertion_site'].apply(calc_integration_freq)
    
    # Rename 'strand' column to 'pam_strand' for clarity
    df_ngg_filtered = df_ngg_filtered.rename(columns={'strand': 'pam_strand'})
    
    # relabel hotspot with sample prefix: [sample]_mcv[n]
    df_ngg_filtered['hotspot'] = df_ngg_filtered['hotspot'].apply(lambda h: f"{sample_id}_{h}")

    # collect rows for global aggregation
    all_rows.append(df_ngg_filtered)

# combine all samples and write one CSV
if not all_rows:
    print("No candidates across samples after filtering.")
else:
    combined = pd.concat(all_rows, ignore_index=True)
    out_name = output_csv_dir / "CandidateSpacers_AllSamples_filtered_combined.csv"
    combined.to_csv(out_name, index=False)
    print(f"Wrote combined CSV: {out_name}  (rows: {len(combined)})")

if skipped:
    print(f"Skipped {len(skipped)} samples (no candidates after filtering).")
# Out:
# Wrote combined CSV: /Users/ecreed/Desktop/KelloggRotation/02052026_TagmentatioAnalysis_251218_260117_260203_combined/FilteredCandidateSpacersBulk/CandidateSpacers_AllSamples_filtered_combined.csv  (rows: 5281)

# %%
### above this works###

# %%
# Calculate on-target percentage for each sample and rank by highest to lowest
import pandas as pd

window_bp = 200

def percent_within_distance(insertions, target_position, window_bp):
    if len(insertions) == 0:
        return 0.0
    count_within = sum(abs(pos - target_position) <= window_bp for pos in insertions)
    return 100.0 * count_within / len(insertions)

results = []

for nn, tsv_path in enumerate(tsv_files):
    sample_id = nn + 1
    
    # Load TSV and filter by mapq
    tsv = pd.read_csv(tsv_path, sep="\t")
    tsv = tsv[tsv["mapq"] >= min_mapq]
    
    # Get target position
    gmap = php.map_guide_to_genome(guideRNA["protospacer"][nn], genome_sequence)
    target_position = gmap[0]["start"]
    
    # Get insertions and calculate on-target %
    insertions = tsv["ins0"].tolist()
    on_target_percent = percent_within_distance(insertions, target_position, window_bp)
    
    # Count insertions within window
    on_target_count = sum(abs(pos - target_position) <= window_bp for pos in insertions)
    total_count = len(insertions)
    
    results.append({
        'sample_id': sample_id,
        'sample_name': tsv_path.name,
        'on_target_count': on_target_count,
        'total_insertions': total_count,
        'on_target_percent': on_target_percent
    })

# Create DataFrame and sort by on_target_percent descending
df_on_target = pd.DataFrame(results)
df_on_target = df_on_target.sort_values('on_target_percent', ascending=False).reset_index(drop=True)
df_on_target['rank'] = df_on_target.index + 1

# Display results
print(f"On-Target Analysis (sorted by highest to lowest, within {window_bp}bp)")
print("=" * 80)
print(df_on_target[['rank', 'sample_id', 'sample_name', 'on_target_count', 'total_insertions', 'on_target_percent']].to_string(index=False))
# Out:
# On-Target Analysis (sorted by highest to lowest, within 200bp)
# ================================================================================
#  rank  sample_id                            sample_name  on_target_count  total_insertions  on_target_percent
#     1         92   92_S92_L001_R1_001.insertions.5p.tsv            36441             39438          92.400730
#     2         27   27_S27_L001_R1_001.insertions.5p.tsv            35657             38668          92.213200
#     3        118 118_S118_L001_R1_001.insertions.5p.tsv            31075             33969          91.480467
#     4         13   13_S13_L001_R1_001.insertions.5p.tsv            22885             30174          75.843441
#     5         45   45_S45_L001_R1_001.insertions.5p.tsv            26775             43585          61.431685
#     6         80   80_S80_L001_R1_001.insertions.5p.tsv            28101             49183          57.135596
#     7         78   78_S78_L001_R1_001.insertions.5p.tsv            30551             58700          52.045997
#     8        101 101_S101_L001_R1_001.insertions.5p.tsv            14064             30236          46.514089
#     9         76   76_S76_L001_R1_001.insertions.5p.tsv            21254             47868          44.401270
#    10         46   46_S46_L001_R1_001.insertions.5p.tsv            18310             46050          39.761129
#    11         97   97_S97_L001_R1_001.insertions.5p.tsv            16075             42765          37.589150
#    12         25   25_S25_L001_R1_001.insertions.5p.tsv             6261             17335          36.117681
#    13         41   41_S41_L001_R1_001.insertions.5p.tsv            11713             36788          31.839187
#    14         54   54_S54_L001_R1_001.insertions.5p.tsv            13971             48144          29.019192
#    15         79   79_S79_L001_R1_001.insertions.5p.tsv            14325             58148          24.635413
#    16         77   77_S77_L001_R1_001.insertions.5p.tsv            11646             50168          23.214001
#    17          8     8_S8_L001_R1_001.insertions.5p.tsv             2883             13970          20.637079
#    18         58   58_S58_L001_R1_001.insertions.5p.tsv            12525             63079          19.856054
#    19         28   28_S28_L001_R1_001.insertions.5p.tsv             5049             29582          17.067812
#    20        107 107_S107_L001_R1_001.insertions.5p.tsv             6615             40003          16.536260
#    21         62   62_S62_L001_R1_001.insertions.5p.tsv             7373             56283          13.099870
#    22          2     2_S2_L001_R1_001.insertions.5p.tsv             2332             18510          12.598595
#    23         91   91_S91_L001_R1_001.insertions.5p.tsv             5355             44251          12.101421
#    24         47   47_S47_L001_R1_001.insertions.5p.tsv             5134             42931          11.958724
#    25          7     7_S7_L001_R1_001.insertions.5p.tsv             1193             10278          11.607317
#    26         61   61_S61_L001_R1_001.insertions.5p.tsv             4487             48421           9.266641
#    27         89   89_S89_L001_R1_001.insertions.5p.tsv             3249             36727           8.846353
#    28        116 116_S116_L001_R1_001.insertions.5p.tsv             3319             46414           7.150860
#    29         99   99_S99_L001_R1_001.insertions.5p.tsv             3301             46287           7.131592
#    30         96   96_S96_L001_R1_001.insertions.5p.tsv             2693             41747           6.450763
#    31        117 117_S117_L001_R1_001.insertions.5p.tsv             2657             46216           5.749091
#    32         35   35_S35_L001_R1_001.insertions.5p.tsv             1883             37162           5.067004
#    33         29   29_S29_L001_R1_001.insertions.5p.tsv              859             17250           4.979710
#    34         88   88_S88_L001_R1_001.insertions.5p.tsv             1545             33309           4.638386
#    35        113 113_S113_L001_R1_001.insertions.5p.tsv             2348             51805           4.532381
#    36         12   12_S12_L001_R1_001.insertions.5p.tsv             1865             44865           4.156915
#    37         20   20_S20_L001_R1_001.insertions.5p.tsv              829             21484           3.858686
#    38         57   57_S57_L001_R1_001.insertions.5p.tsv             2054             56223           3.653309
#    39         81   81_S81_L001_R1_001.insertions.5p.tsv             1375             38933           3.531708
#    40        105 105_S105_L001_R1_001.insertions.5p.tsv             1345             40341           3.334077
#    41         34   34_S34_L001_R1_001.insertions.5p.tsv             1356             42677           3.177355
#    42         14   14_S14_L001_R1_001.insertions.5p.tsv              299              9754           3.065409
#    43         26   26_S26_L001_R1_001.insertions.5p.tsv              445             15802           2.816099
#    44         43   43_S43_L001_R1_001.insertions.5p.tsv              924             35381           2.611571
#    45         53   53_S53_L001_R1_001.insertions.5p.tsv             1289             49928           2.581718
#    46         42   42_S42_L001_R1_001.insertions.5p.tsv             1094             42464           2.576300
#    47        110 110_S110_L001_R1_001.insertions.5p.tsv             1072             41976           2.553840
#    48        119 119_S119_L001_R1_001.insertions.5p.tsv             1149             49959           2.299886
#    49        114 114_S114_L001_R1_001.insertions.5p.tsv              871             38190           2.280702
#    50         56   56_S56_L001_R1_001.insertions.5p.tsv              794             39353           2.017635
#    51         51   51_S51_L001_R1_001.insertions.5p.tsv              980             55153           1.776875
#    52        103 103_S103_L001_R1_001.insertions.5p.tsv              740             43438           1.703578
#    53          3     3_S3_L001_R1_001.insertions.5p.tsv              275             17237           1.595405
#    54        102 102_S102_L001_R1_001.insertions.5p.tsv              698             44853           1.556195
#    55        120 120_S120_L001_R1_001.insertions.5p.tsv              702             45224           1.552273
#    56         16   16_S16_L001_R1_001.insertions.5p.tsv              140              9623           1.454848
#    57         37   37_S37_L001_R1_001.insertions.5p.tsv              555             46353           1.197334
#    58         40   40_S40_L001_R1_001.insertions.5p.tsv              170             19192           0.885786
#    59         17   17_S17_L001_R1_001.insertions.5p.tsv              211             24152           0.873634
#    60         48   48_S48_L001_R1_001.insertions.5p.tsv              878            102272           0.858495
#    61         85   85_S85_L001_R1_001.insertions.5p.tsv              255             30997           0.822660
#    62         94   94_S94_L001_R1_001.insertions.5p.tsv              299             38822           0.770182
#    63        108 108_S108_L001_R1_001.insertions.5p.tsv              259             34742           0.745495
#    64         23   23_S23_L001_R1_001.insertions.5p.tsv              132             18301           0.721272
#    65         93   93_S93_L001_R1_001.insertions.5p.tsv              287             39997           0.717554
#    66         83   83_S83_L001_R1_001.insertions.5p.tsv              316             45166           0.699641
#    67          9     9_S9_L001_R1_001.insertions.5p.tsv               95             14088           0.674333
#    68        106 106_S106_L001_R1_001.insertions.5p.tsv              257             41291           0.622412
#    69         19   19_S19_L001_R1_001.insertions.5p.tsv              140             25677           0.545235
#    70          6     6_S6_L001_R1_001.insertions.5p.tsv              149             28571           0.521508
#    71         15   15_S15_L001_R1_001.insertions.5p.tsv               79             15171           0.520730
#    72         82   82_S82_L001_R1_001.insertions.5p.tsv              224             49366           0.453754
#    73        109 109_S109_L001_R1_001.insertions.5p.tsv              165             45479           0.362805
#    74         98   98_S98_L001_R1_001.insertions.5p.tsv              172             48434           0.355122
#    75         84   84_S84_L001_R1_001.insertions.5p.tsv              119             39095           0.304387
#    76        111 111_S111_L001_R1_001.insertions.5p.tsv              111             37605           0.295174
#    77         59   59_S59_L001_R1_001.insertions.5p.tsv              120             45245           0.265223
#    78         33   33_S33_L001_R1_001.insertions.5p.tsv               45             17077           0.263512
#    79          1     1_S1_L001_R1_001.insertions.5p.tsv               38             16822           0.225895
#    80         86   86_S86_L001_R1_001.insertions.5p.tsv              126             58015           0.217185
#    81          4     4_S4_L001_R1_001.insertions.5p.tsv               28             16112           0.173784
#    82         18   18_S18_L001_R1_001.insertions.5p.tsv               30             17760           0.168919
#    83        104 104_S104_L001_R1_001.insertions.5p.tsv               79             47441           0.166523
#    84         60   60_S60_L001_R1_001.insertions.5p.tsv               90             54261           0.165865
#    85         21   21_S21_L001_R1_001.insertions.5p.tsv               39             27740           0.140591
#    86         87   87_S87_L001_R1_001.insertions.5p.tsv               46             33973           0.135402
#    87         31   31_S31_L001_R1_001.insertions.5p.tsv               26             20451           0.127133
#    88         11   11_S11_L001_R1_001.insertions.5p.tsv                4              3203           0.124883
#    89         49   49_S49_L001_R1_001.insertions.5p.tsv               47             47179           0.099621
#    90         74   74_S74_L001_R1_001.insertions.5p.tsv               40             46152           0.086670
#    91         10   10_S10_L001_R1_001.insertions.5p.tsv               15             17571           0.085368
#    92         36   36_S36_L001_R1_001.insertions.5p.tsv               25             30031           0.083247
#    93         38   38_S38_L001_R1_001.insertions.5p.tsv               16             19287           0.082957
#    94         30   30_S30_L001_R1_001.insertions.5p.tsv               15             19713           0.076092
#    95         44   44_S44_L001_R1_001.insertions.5p.tsv               14             39217           0.035699
#    96        100 100_S100_L001_R1_001.insertions.5p.tsv               16             47416           0.033744
#    97         70   70_S70_L001_R1_001.insertions.5p.tsv               12             35846           0.033477
#    98         90   90_S90_L001_R1_001.insertions.5p.tsv               14             43187           0.032417
#    99         52   52_S52_L001_R1_001.insertions.5p.tsv               13             45318           0.028686
#   100        112 112_S112_L001_R1_001.insertions.5p.tsv                9             38946           0.023109
#   101         32   32_S32_L001_R1_001.insertions.5p.tsv                4             19033           0.021016
#   102          5     5_S5_L001_R1_001.insertions.5p.tsv                2             11903           0.016802
#   103         55   55_S55_L001_R1_001.insertions.5p.tsv                3             52965           0.005664
#   104         50   50_S50_L001_R1_001.insertions.5p.tsv                1             44361           0.002254
#   105         39   39_S39_L001_R1_001.insertions.5p.tsv                0             19826           0.000000
#   106         75   75_S75_L001_R1_001.insertions.5p.tsv                0             48839           0.000000
#   107        115 115_S115_L001_R1_001.insertions.5p.tsv                0             44911           0.000000
#   108         63   63_S63_L001_R1_001.insertions.5p.tsv                0             46941           0.000000
#   109         71   71_S71_L001_R1_001.insertions.5p.tsv                0             47478           0.000000
#   110         65   65_S65_L001_R1_001.insertions.5p.tsv                0             52709           0.000000
#   111         66   66_S66_L001_R1_001.insertions.5p.tsv                0             51521           0.000000
#   112         67   67_S67_L001_R1_001.insertions.5p.tsv                0             50820           0.000000
#   113         68   68_S68_L001_R1_001.insertions.5p.tsv                0             42226           0.000000
#   114         73   73_S73_L001_R1_001.insertions.5p.tsv                0             47844           0.000000
#   115         72   72_S72_L001_R1_001.insertions.5p.tsv                0             51915           0.000000
#   116         69   69_S69_L001_R1_001.insertions.5p.tsv                0             39713           0.000000
#   117         95   95_S95_L001_R1_001.insertions.5p.tsv                0             38135           0.000000
#   118         24   24_S24_L001_R1_001.insertions.5p.tsv                0             13551           0.000000
#   119         22   22_S22_L001_R1_001.insertions.5p.tsv                0             31303           0.000000
#   120         64   64_S64_L001_R1_001.insertions.5p.tsv                0             44579           0.000000

# %%
# Analyze top 10 samples by on-target percentage
# For each sample, read the guide candidate CSV, find best alignment per MCV, output alignment figures

import pandas as pd
from pathlib import Path

# Get top 10 samples by on-target percent
top_10_samples = df_on_target.head(10)['sample_id'].tolist()

print(f"Processing top 10 samples by on-target percentage: {top_10_samples}")
print("=" * 80)

# Load the combined candidate spacers CSV
combined_csv = output_csv_dir / "CandidateSpacers_AllSamples_filtered_combined.csv"
df_candidates = pd.read_csv(combined_csv)

for sample_id in top_10_samples:
    # Filter for this sample's candidates (hotspot format: "sample_id_mcvN")
    sample_candidates = df_candidates[df_candidates['hotspot'].str.startswith(f"{sample_id}_")].copy()
    
    if sample_candidates.empty:
        print(f"\nSample {sample_id}: No candidates found")
        continue
    
    print(f"\nSample {sample_id}:")
    print("-" * 80)
    
    original_guide = guideRNA["protospacer"][sample_id - 1]
    
    # Group by hotspot (MCV)
    for hotspot, group in sample_candidates.groupby('hotspot'):
        # Find best alignment (highest alignment_score)
        best_row = group.loc[group['alignment_score'].idxmax()]
        
        print(f"  {hotspot}: alignment_score={best_row['alignment_score']:.1f}, mismatch_count={int(best_row['mismatch_count'])}")
        
        # Perform alignment to display
        guide_seq = best_row['guide_seq']
        try:
            aln = php.local_align(original_guide, guide_seq)
            print(aln)
        except Exception as e:
            print(f"    Error computing alignment: {e}")
# Out:
# Processing top 10 samples by on-target percentage: [92, 27, 118, 13, 45, 80, 78, 101, 76, 46]
# ================================================================================
#
# Sample 92:
# --------------------------------------------------------------------------------
#   92_mcv1: alignment_score=40.0, mismatch_count=0
# target            0 ACTCAGCTGCGCTACGACTA 20
#                   0 |||||||||||||||||||| 20
# query             0 ACTCAGCTGCGCTACGACTA 20
#
#
# Sample 27:
# --------------------------------------------------------------------------------
#   27_mcv1: alignment_score=40.0, mismatch_count=0
# target            0 CGAAATGGCGTATGTGAATG 20
#                   0 |||||||||||||||||||| 20
# query             0 CGAAATGGCGTATGTGAATG 20
#
#   27_mcv2: alignment_score=15.5, mismatch_count=11
# target            4 ATGGCGTATGTGAATG 20
#                   0 ||||----||.||||| 16
# query             8 ATGG----TGGGAATG 20
#
#
# Sample 118:
# --------------------------------------------------------------------------------
#   118_mcv1: alignment_score=40.0, mismatch_count=0
# target            0 CAACAAGTCAGGTTGCGAGA 20
#                   0 |||||||||||||||||||| 20
# query             0 CAACAAGTCAGGTTGCGAGA 20
#
#
# Sample 13:
# --------------------------------------------------------------------------------
#   13_mcv1: alignment_score=40.0, mismatch_count=0
# target            0 CATTTTCAATCCGCACCTCG 20
#                   0 |||||||||||||||||||| 20
# query             0 CATTTTCAATCCGCACCTCG 20
#
#   13_mcv2: alignment_score=28.0, mismatch_count=4
# target            3 TTTCAATCCGCACCTCG 20
#                   0 |||||..|||||||||| 17
# query             3 TTTCATGCCGCACCTCG 20
#
#
# Sample 45:
# --------------------------------------------------------------------------------
#   45_mcv1: alignment_score=40.0, mismatch_count=0
# target            0 TGCAACCGGGGCCGCAACCC 20
#                   0 |||||||||||||||||||| 20
# query             0 TGCAACCGGGGCCGCAACCC 20
#
#   45_mcv2: alignment_score=19.0, mismatch_count=9
# target            5 CCGGGG---CCGCAACCC 20
#                   0 |||..|---||||||||| 18
# query             2 CCGTTGCTACCGCAACCC 20
#
#   45_mcv3: alignment_score=13.0, mismatch_count=13
# target            1 GCAACCGGGGCCGC-AACCC 20
#                   0 ||||..|.|....|-||||| 20
# query             0 GCAAGTGAGTTTACTAACCC 20
#
#   45_mcv4: alignment_score=17.0, mismatch_count=10
# target           10 GCCGCAACCC 20
#                   0 ||||.||||| 10
# query            10 GCCGGAACCC 20
#
#   45_mcv5: alignment_score=16.0, mismatch_count=10
# target            1 GCA-ACCGGGGCCGCAACCC 20
#                   0 |||-.|.|...||.|||||| 20
# query             0 GCATGCTGACACCACAACCC 20
#
#
# Sample 80:
# --------------------------------------------------------------------------------
#   80_mcv1: alignment_score=40.0, mismatch_count=0
# target            0 GCGCGCGCCATGCTGCTCTC 20
#                   0 |||||||||||||||||||| 20
# query             0 GCGCGCGCCATGCTGCTCTC 20
#
#   80_mcv2: alignment_score=15.0, mismatch_count=12
# target            8 CATGCTGCTCTC 20
#                   0 |||..||.|||| 12
# query             6 CATATTGATCTC 18
#
#   80_mcv3: alignment_score=21.0, mismatch_count=11
# target            5 CGCCAT-----GCTGCTCTC 20
#                   0 |||.||-----||||||||| 20
# query             0 CGCTATCTGGGGCTGCTCTC 20
#
#   80_mcv4: alignment_score=17.0, mismatch_count=10
# target            5 CGCC-ATGCTGCTCTC 20
#                   0 ||||-.|.||.||||| 16
# query             4 CGCCGTTTCTCCTCTC 20
#
#   80_mcv5: alignment_score=18.0, mismatch_count=11
# target            5 CGCCATGCTGCTCTC 20
#                   0 ||.||...||||||| 15
# query             3 CGTCAATTTGCTCTC 18
#
#
# Sample 78:
# --------------------------------------------------------------------------------
#   78_mcv1: alignment_score=40.0, mismatch_count=0
# target            0 CGCGCGCCATGCTGCTCTCC 20
#                   0 |||||||||||||||||||| 20
# query             0 CGCGCGCCATGCTGCTCTCC 20
#
#   78_mcv2: alignment_score=24.0, mismatch_count=12
# target            2 CGCGCCATGCTGCTCTCC 20
#                   0 |||.|||-||||||||.| 18
# query             2 CGCCCCA-GCTGCTCTGC 19
#
#   78_mcv3: alignment_score=22.5, mismatch_count=7
# target            3 GCGCCATGCTGCTCTCC 20
#                   0 ||.||--|||||||||| 17
# query             5 GCACC--GCTGCTCTCC 20
#
#   78_mcv4: alignment_score=20.5, mismatch_count=12
# target            4 CGCCATGCTGC----TCTCC 20
#                   0 ||.||.|||||----||||| 20
# query             0 CGGCAAGCTGCTGCATCTCC 20
#
#   78_mcv5: alignment_score=16.5, mismatch_count=10
# target            0 CGCGC-GCCATGCTGCTCTCC 20
#                   0 |||.|-.||||----|||||| 21
# query             3 CGCCCTACCAT----CTCTCC 20
#
#   78_mcv6: alignment_score=12.0, mismatch_count=11
# target            3 GCGCCATGCTGC-TCTCC 20
#                   0 ||..||....||-||||| 18
# query             2 GCCTCAACTGGCGTCTCC 20
#
#
# Sample 101:
# --------------------------------------------------------------------------------
#   101_mcv1: alignment_score=40.0, mismatch_count=0
# target            0 GGGTTGGTACTTCAGCCACC 20
#                   0 |||||||||||||||||||| 20
# query             0 GGGTTGGTACTTCAGCCACC 20
#
#   101_mcv2: alignment_score=20.0, mismatch_count=8
# target            4 TGGTACTTCAGCCACC 20
#                   0 ||..|.|.|||||||| 16
# query             4 TGTCAGTCCAGCCACC 20
#
#   101_mcv3: alignment_score=14.0, mismatch_count=10
# target            2 GTTG-GTACTTCAGCCACC 20
#                   0 ||||-|...|.|.||.||| 19
# query             1 GTTGAGGTTTACCGCTACC 20
#
#
# Sample 76:
# --------------------------------------------------------------------------------
#   76_mcv1: alignment_score=40.0, mismatch_count=0
# target            0 ACACCAGAACATCTTTTCAC 20
#                   0 |||||||||||||||||||| 20
# query             0 ACACCAGAACATCTTTTCAC 20
#
#   76_mcv2: alignment_score=14.0, mismatch_count=13
# target            4 CAGAACATCTTTTCAC 20
#                   0 ||.|.||.|-.||||| 16
# query             5 CAAATCAGC-ATTCAC 20
#
#   76_mcv3: alignment_score=14.0, mismatch_count=11
# target            6 GAACA---TCTTTTCAC 20
#                   0 |||.|---||..||||| 17
# query             3 GAATATGCTCCGTTCAC 20
#
#   76_mcv4: alignment_score=14.5, mismatch_count=11
# target            7 AACAT----CTTTTCAC 20
#                   0 |||.|----|.|||||| 17
# query             3 AACGTTGCGCCTTTCAC 20
#
#   76_mcv5: alignment_score=11.0, mismatch_count=18
# target            1 CACCAGA  8
#                   0 ||||.||  7
# query            13 CACCGGA 20
#
#   76_mcv6: alignment_score=19.0, mismatch_count=7
# target            0 ACACCAGAACATCTTTTCAC 20
#                   0 ||..|...|||||..||||| 20
# query             0 ACGTCCTGACATCCCTTCAC 20
#
#   76_mcv7: alignment_score=10.0, mismatch_count=12
# target           15 TTCAC 20
#                   0 |||||  5
# query            15 TTCAC 20
#
#   76_mcv8: alignment_score=19.5, mismatch_count=9
# target            6 GAAC-ATC--TTTTCAC 20
#                   0 ||||-|||--||||||| 17
# query             3 GAACGATCTATTTTCAC 20
#
#
# Sample 46:
# --------------------------------------------------------------------------------
#   46_mcv1: alignment_score=40.0, mismatch_count=0
# target            0 CGAACTTTACGGTCATCGCG 20
#                   0 |||||||||||||||||||| 20
# query             0 CGAACTTTACGGTCATCGCG 20
#
#   46_mcv2: alignment_score=15.0, mismatch_count=11
# target            1 GAACTTTACGGTCATCGCG 20
#                   0 ||..|.|.|---||||||| 19
# query             4 GATGTGTTC---CATCGCG 20
#
#   46_mcv3: alignment_score=20.5, mismatch_count=12
# target            4 CTTTACGGT----CATCGCG 20
#                   0 ||..|||||----||||||| 20
# query             0 CTGGACGGTTTTACATCGCG 20
#
#   46_mcv4: alignment_score=16.5, mismatch_count=9
# target            0 CGAACTTTACGGTCATCGCG 20
#                   0 ||..|.|--|||..|||||| 20
# query             2 CGTTCCT--CGGCTATCGCG 20

# %%
# For each imperfect alignment, analyze position-by-position match/mismatch/gap frequencies
# USE HIGH ON-TARGET HOTSPOTS

import pandas as pd

# Get top 10 samples by on-target percent
top_10_samples = df_on_target.head(10)['sample_id'].tolist()

# Load the combined candidate spacers CSV
combined_csv = output_csv_dir / "CandidateSpacers_AllSamples_filtered_combined.csv"
df_candidates = pd.read_csv(combined_csv)

# Collect position-level statistics
position_stats = {pos: {'match': 0, 'mismatch': 0, 'gap': 0} for pos in range(20)}

for sample_id in top_10_samples:
    # Filter for this sample's candidates
    sample_candidates = df_candidates[df_candidates['hotspot'].str.startswith(f"{sample_id}_")].copy()
    
    if sample_candidates.empty:
        continue
    
    original_guide = guideRNA["protospacer"][sample_id - 1]
    
    # Group by hotspot (MCV)
    for hotspot, group in sample_candidates.groupby('hotspot'):
        # Find best alignment (highest alignment_score)
        best_row = group.loc[group['alignment_score'].idxmax()]
        guide_seq = best_row['guide_seq']
        
        # Only analyze imperfect alignments (mismatch_count > 0)
        if best_row['mismatch_count'] > 0:
            try:
                aln = php.local_align(original_guide, guide_seq)
                
                coords_q = list(aln.coordinates[0])
                coords_t = list(aln.coordinates[1])
                
                # Build gapped alignment strings from coordinates
                query_gapped = ""
                target_gapped = ""
                
                for i in range(len(coords_q) - 1):
                    q_start, q_end = coords_q[i], coords_q[i + 1]
                    t_start, t_end = coords_t[i], coords_t[i + 1]
                    
                    q_len = q_end - q_start
                    t_len = t_end - t_start
                    
                    if q_len > 0 and t_len > 0:
                        # Both sequences have bases
                        query_gapped += original_guide[q_start:q_end]
                        target_gapped += guide_seq[t_start:t_end]
                    elif q_len > 0:
                        # Gap in target
                        query_gapped += original_guide[q_start:q_end]
                        target_gapped += "-" * q_len
                    elif t_len > 0:
                        # Gap in query
                        query_gapped += "-" * t_len
                        target_gapped += guide_seq[t_start:t_end]
                
                # Track position in original guide
                query_pos = int(coords_q[0])
                
                # Iterate through gapped alignment
                for q_char, t_char in zip(query_gapped, target_gapped):
                    if q_char != '-':
                        # This position exists in query
                        if t_char == '-':
                            position_stats[query_pos]['gap'] += 1
                        elif q_char == t_char:
                            position_stats[query_pos]['match'] += 1
                        else:
                            position_stats[query_pos]['mismatch'] += 1
                        query_pos += 1
                        
            except Exception as e:
                pass

# Display results
print("Position-by-position alignment statistics (imperfect alignments only)")
print("=" * 80)
print(f"{'Pos':>3} {'Match':>6} {'Mismatch':>8} {'Gap':>5} | Match%   Mismatch%   Gap%")
print("-" * 80)

for pos in range(20):
    stats = position_stats[pos]
    total = stats['match'] + stats['mismatch'] + stats['gap']
    
    if total > 0:
        match_pct = (stats['match'] / total) * 100
        mismatch_pct = (stats['mismatch'] / total) * 100
        gap_pct = (stats['gap'] / total) * 100
        
        print(f"{pos:3d} {stats['match']:6d} {stats['mismatch']:8d} {stats['gap']:5d} | {match_pct:6.1f}%  {mismatch_pct:6.1f}%  {gap_pct:6.1f}%")
    else:
        print(f"{pos:3d} {'—':>6} {'—':>8} {'—':>5} | No data")
# Out:
# Position-by-position alignment statistics (imperfect alignments only)
# ================================================================================
# Pos  Match Mismatch   Gap | Match%   Mismatch%   Gap%
# --------------------------------------------------------------------------------
#   0      3        0     0 |  100.0%     0.0%     0.0%
#   1      7        0     0 |  100.0%     0.0%     0.0%
#   2      7        2     0 |   77.8%    22.2%     0.0%
#   3      8        4     0 |   66.7%    33.3%     0.0%
#   4     15        2     0 |   88.2%    11.8%     0.0%
#   5     13        8     0 |   61.9%    38.1%     0.0%
#   6     14        9     0 |   60.9%    39.1%     0.0%
#   7     18        5     1 |   75.0%    20.8%     4.2%
#   8     13        8     3 |   54.2%    33.3%    12.5%
#   9     12        9     3 |   50.0%    37.5%    12.5%
#  10     17        5     3 |   68.0%    20.0%    12.0%
#  11     14        8     3 |   56.0%    32.0%    12.0%
#  12     18        5     2 |   72.0%    20.0%     8.0%
#  13     16        7     2 |   64.0%    28.0%     8.0%
#  14     19        6     0 |   76.0%    24.0%     0.0%
#  15     25        1     0 |   96.2%     3.8%     0.0%
#  16     25        1     0 |   96.2%     3.8%     0.0%
#  17     26        0     0 |  100.0%     0.0%     0.0%
#  18     25        1     0 |   96.2%     3.8%     0.0%
#  19     26        0     0 |  100.0%     0.0%     0.0%

# %%
# v1 cell to identify strong off-target preference
# use previous on-target calculation
# divide genome into 200 bp windows, count integrations in each window, return windows sorted by highest integration count
# once windows are counted, filter out on target, want to hit strong off target hotspots with new guides
# off-target preference is calc by finding off target percent 
    # (integrations in best off target window / total integrations) * 100 = off target percent
# (off target percent) - (on target percent) = off-target preference
    # positive value == guide integrates more off-target than on-ltarget


# Identify samples with high off-target preference
# Adapted from on-target calculation method (cell 8)
# Analyze windows with high integrations and identify off-target preference

import re
from pathlib import Path

window_bp = 200
on_target_window = window_bp

def percent_within_distance(insertions, target_position, window_bp):
    """Calculate percentage of insertions within window_bp distance"""
    if len(insertions) == 0:
        return 0.0
    
    count_within = sum(
        abs(pos - target_position) <= window_bp
        for pos in insertions
    )
    
    return 100.0 * count_within / len(insertions)

def find_high_integration_windows(insertions, window_size=200, min_window_count=50):
    """
    Find windows with high integration counts.
    Returns list of (window_center, count) tuples sorted by count descending
    """
    from collections import defaultdict
    
    if not insertions:
        return []
    
    # Create windows and count integrations
    window_counts = defaultdict(int)
    
    for pos in insertions:
        # Round to nearest window boundary
        window_center = (pos // window_size) * window_size + window_size // 2
        window_counts[window_center] += 1
    
    # Filter windows by minimum count and sort
    high_windows = [(center, count) for center, count in window_counts.items() 
                    if count >= min_window_count]
    high_windows.sort(key=lambda x: x[1], reverse=True)
    
    return high_windows

def _sample_id_from_name(p: Path):
    """Extract sample ID from filename"""
    m = re.match(r"(\d+)_S\1_", p.name)
    return int(m.group(1)) if m else None

# Analyze each sample for off-target preferences
off_target_results = []

for nn, tsv_path in enumerate(tsv_files):
    sample_id = _sample_id_from_name(tsv_path) or (nn + 1)
    
    # Load and filter TSV
    tsv = pd.read_csv(tsv_path, sep="\t")
    tsv = tsv[tsv["mapq"] >= min_mapq]
    
    if len(tsv) == 0:
        continue
    
    insertions = tsv["ins0"].values.tolist()
    total_insertions = len(insertions)
    
    # Get target position for this sample
    try:
        gmap = php.map_guide_to_genome(guideRNA["protospacer"][nn], genome_sequence)
        target_position = gmap[0]["start"]
    except:
        continue
    
    # Calculate on-target percentage
    on_target_percent = percent_within_distance(insertions, target_position, on_target_window)
    on_target_count = sum(abs(pos - target_position) <= on_target_window for pos in insertions)
    
    # Find all high integration windows (off-target and on-target)
    all_windows = find_high_integration_windows(insertions, window_size=200, min_window_count=30)
    
    # Filter to only off-target windows (outside on-target window)
    off_target_windows = []
    for window_center, count in all_windows:
        if abs(window_center - target_position) > on_target_window:
            off_target_windows.append((window_center, count))
    
    # Calculate off-target preference
    if off_target_windows:
        # Get best (highest count) off-target window
        best_off_target_window = off_target_windows[0]
        best_off_target_count = best_off_target_window[1]
        off_target_percent = 100.0 * best_off_target_count / total_insertions
    else:
        best_off_target_window = (None, 0)
        best_off_target_count = 0
        off_target_percent = 0.0
    
    # Get sample name
    sample_name = Path(tsv_path).stem
    
    off_target_results.append({
        'sample_id': sample_id,
        'sample_name': sample_name,
        'total_insertions': total_insertions,
        'on_target_count': on_target_count,
        'on_target_percent': on_target_percent,
        'best_off_target_window': best_off_target_window[0],
        'best_off_target_count': best_off_target_count,
        'off_target_percent': off_target_percent,
        'off_target_preference': off_target_percent - on_target_percent,
        'num_high_off_target_windows': len(off_target_windows)
    })

# Create DataFrame and sort by off-target preference (highest to lowest)
df_off_target = pd.DataFrame(off_target_results)
df_off_target = df_off_target.sort_values('off_target_preference', ascending=False).reset_index(drop=True)
df_off_target['rank'] = df_off_target.index + 1

# Display results sorted by highest off-target preference
print("=" * 120)
print("SAMPLES RANKED BY OFF-TARGET PREFERENCE (Highest to Lowest)")
print("=" * 120)
print(df_off_target[['rank', 'sample_id', 'sample_name', 'on_target_percent', 
                     'off_target_percent', 'off_target_preference', 
                     'best_off_target_window', 'num_high_off_target_windows']].to_string(index=False))
print("\n" + "=" * 120)
print(f"Total samples analyzed: {len(df_off_target)}")
print(f"Samples with off-target preference > 0%: {(df_off_target['off_target_preference'] > 0).sum()}")
# Out:
# ========================================================================================================================
# SAMPLES RANKED BY OFF-TARGET PREFERENCE (Highest to Lowest)
# ========================================================================================================================
#  rank  sample_id                        sample_name  on_target_percent  off_target_percent  off_target_preference  best_off_target_window  num_high_off_target_windows
#     1         70   70_S70_L001_R1_001.insertions.5p           0.033477           82.101211              82.067734                 4471500                           27
#     2         31   31_S31_L001_R1_001.insertions.5p           0.127133           76.333676              76.206542                 2170900                           20
#     3        108 108_S108_L001_R1_001.insertions.5p           0.745495           75.372748              74.627252                 1388100                           42
#     4         56   56_S56_L001_R1_001.insertions.5p           2.017635           75.308109              73.290473                 4279500                           27
#     5         87   87_S87_L001_R1_001.insertions.5p           0.135402           69.254997              69.119595                 2000700                           45
#     6         98   98_S98_L001_R1_001.insertions.5p           0.355122           69.071314              68.716191                 1959100                           58
#     7         93   93_S93_L001_R1_001.insertions.5p           0.717554           62.827212              62.109658                  863900                           36
#     8         23   23_S23_L001_R1_001.insertions.5p           0.721272           61.149664              60.428392                 1948700                           19
#     9          1     1_S1_L001_R1_001.insertions.5p           0.225895           58.863393              58.637499                 2110700                           29
#    10         36   36_S36_L001_R1_001.insertions.5p           0.083247           57.077686              56.994439                 1922500                           33
#    11         39   39_S39_L001_R1_001.insertions.5p           0.000000           55.401997              55.401997                 2472100                           49
#    12         68   68_S68_L001_R1_001.insertions.5p           0.000000           52.976839              52.976839                  380100                           39
#    13        102 102_S102_L001_R1_001.insertions.5p           1.556195           54.281765              52.725570                 2202700                           50
#    14         12   12_S12_L001_R1_001.insertions.5p           4.156915           55.038449              50.881533                  627900                           64
#    15         32   32_S32_L001_R1_001.insertions.5p           0.021016           45.174171              45.153155                 1337900                           33
#    16         86   86_S86_L001_R1_001.insertions.5p           0.217185           45.331380              45.114195                 1234500                          122
#    17         99   99_S99_L001_R1_001.insertions.5p           7.131592           51.697021              44.565429                  542700                           31
#    18        111 111_S111_L001_R1_001.insertions.5p           0.295174           42.773567              42.478394                  628700                           37
#    19         59   59_S59_L001_R1_001.insertions.5p           0.265223           41.631119              41.365897                 1035900                           47
#    20         65   65_S65_L001_R1_001.insertions.5p           0.000000           41.114421              41.114421                 3121500                           47
#    21        115 115_S115_L001_R1_001.insertions.5p           0.000000           40.618111              40.618111                  110500                           50
#    22          6     6_S6_L001_R1_001.insertions.5p           0.521508           40.390606              39.869098                 1950900                           96
#    23          4     4_S4_L001_R1_001.insertions.5p           0.173784           38.859235              38.685452                 2170900                           51
#    24        100 100_S100_L001_R1_001.insertions.5p           0.033744           37.394550              37.360806                 1112100                           50
#    25         67   67_S67_L001_R1_001.insertions.5p           0.000000           37.109406              37.109406                  335100                           56
#    26         90   90_S90_L001_R1_001.insertions.5p           0.032417           36.647602              36.615185                  123300                           51
#    27         43   43_S43_L001_R1_001.insertions.5p           2.611571           38.616772              36.005201                  457100                           76
#    28        103 103_S103_L001_R1_001.insertions.5p           1.703578           35.505778              33.802201                 1207900                           45
#    29         17   17_S17_L001_R1_001.insertions.5p           0.873634           34.419510              33.545876                 1894300                          125
#    30         11   11_S11_L001_R1_001.insertions.5p           0.124883           33.000312              32.875429                 1850100                           15
#    31         73   73_S73_L001_R1_001.insertions.5p           0.000000           32.656132              32.656132                 1010100                           69
#    32         14   14_S14_L001_R1_001.insertions.5p           3.065409           35.534140              32.468731                    3500                           24
#    33         71   71_S71_L001_R1_001.insertions.5p           0.000000           31.189182              31.189182                  812300                           82
#    34        117 117_S117_L001_R1_001.insertions.5p           5.749091           36.848710              31.099619                   31500                           29
#    35         85   85_S85_L001_R1_001.insertions.5p           0.822660           31.822434              30.999774                  203700                           49
#    36        109 109_S109_L001_R1_001.insertions.5p           0.362805           31.049495              30.686691                 1536300                           61
#    37         29   29_S29_L001_R1_001.insertions.5p           4.979710           35.153623              30.173913                  865900                           30
#    38         24   24_S24_L001_R1_001.insertions.5p           0.000000           30.123238              30.123238                  356900                           29
#    39         82   82_S82_L001_R1_001.insertions.5p           0.453754           30.565571              30.111818                  610700                           52
#    40         26   26_S26_L001_R1_001.insertions.5p           2.816099           32.103531              29.287432                  752300                           39
#    41          3     3_S3_L001_R1_001.insertions.5p           1.595405           30.144457              28.549051                 1091700                           35
#    42         83   83_S83_L001_R1_001.insertions.5p           0.699641           29.132533              28.432892                  203700                           79
#    43        112 112_S112_L001_R1_001.insertions.5p           0.023109           27.360961              27.337852                 4000100                           74
#    44         49   49_S49_L001_R1_001.insertions.5p           0.099621           26.838212              26.738591                  880700                           55
#    45         20   20_S20_L001_R1_001.insertions.5p           3.858686           30.092162              26.233476                 3640700                           46
#    46         81   81_S81_L001_R1_001.insertions.5p           3.531708           28.733979              25.202271                 3074900                           73
#    47        105 105_S105_L001_R1_001.insertions.5p           3.334077           27.768275              24.434198                  941500                           63
#    48         19   19_S19_L001_R1_001.insertions.5p           0.545235           24.259065              23.713829                 2093500                           44
#    49         95   95_S95_L001_R1_001.insertions.5p           0.000000           23.338141              23.338141                  373500                           94
#    50         37   37_S37_L001_R1_001.insertions.5p           1.197334           24.272431              23.075098                 2253300                          152
#    51         60   60_S60_L001_R1_001.insertions.5p           0.165865           22.834080              22.668215                 4344700                          116
#    52         72   72_S72_L001_R1_001.insertions.5p           0.000000           22.375036              22.375036                 3751100                           79
#    53         88   88_S88_L001_R1_001.insertions.5p           4.638386           26.764538              22.126152                 1236300                           65
#    54         89   89_S89_L001_R1_001.insertions.5p           8.846353           30.819288              21.972935                 1312100                           47
#    55         53   53_S53_L001_R1_001.insertions.5p           2.581718           24.467233              21.885515                 1807900                           85
#    56         40   40_S40_L001_R1_001.insertions.5p           0.885786           22.650063              21.764277                 2090500                           45
#    57         74   74_S74_L001_R1_001.insertions.5p           0.086670           21.641532              21.554862                 1780100                           80
#    58         64   64_S64_L001_R1_001.insertions.5p           0.000000           21.357590              21.357590                  986900                           90
#    59         18   18_S18_L001_R1_001.insertions.5p           0.168919           20.264640              20.095721                 1358700                           37
#    60        113 113_S113_L001_R1_001.insertions.5p           4.532381           24.148248              19.615867                 1242300                           96
#    61         94   94_S94_L001_R1_001.insertions.5p           0.770182           20.369893              19.599712                 3958500                           67
#    62          5     5_S5_L001_R1_001.insertions.5p           0.016802           19.600101              19.583298                 4177100                           44
#    63         63   63_S63_L001_R1_001.insertions.5p           0.000000           19.275260              19.275260                  982900                          117
#    64        120 120_S120_L001_R1_001.insertions.5p           1.552273           20.544401              18.992128                  582100                          126
#    65         66   66_S66_L001_R1_001.insertions.5p           0.000000           18.666175              18.666175                  812300                           93
#    66        110 110_S110_L001_R1_001.insertions.5p           2.553840           21.138269              18.584429                  767900                           87
#    67         21   21_S21_L001_R1_001.insertions.5p           0.140591           18.608508              18.467916                 1240900                           83
#    68         15   15_S15_L001_R1_001.insertions.5p           0.520730           18.864940              18.344209                 1764100                           26
#    69         69   69_S69_L001_R1_001.insertions.5p           0.000000           18.255987              18.255987                  629500                           72
#    70         75   75_S75_L001_R1_001.insertions.5p           0.000000           18.131002              18.131002                  241300                           70
#    71         42   42_S42_L001_R1_001.insertions.5p           2.576300           20.657498              18.081198                 2755300                           66
#    72         33   33_S33_L001_R1_001.insertions.5p           0.263512           17.842712              17.579200                 4000100                           46
#    73         34   34_S34_L001_R1_001.insertions.5p           3.177355           20.734822              17.557467                 2136900                          194
#    74         16   16_S16_L001_R1_001.insertions.5p           1.454848           18.913021              17.458173                 4095500                           24
#    75         44   44_S44_L001_R1_001.insertions.5p           0.035699           17.102277              17.066578                 1969900                           87
#    76          2     2_S2_L001_R1_001.insertions.5p          12.598595           29.665046              17.066451                 1547700                           61
#    77         30   30_S30_L001_R1_001.insertions.5p           0.076092           16.897479              16.821387                 3524700                           49
#    78         51   51_S51_L001_R1_001.insertions.5p           1.776875           17.799576              16.022700                   72500                           81
#    79          9     9_S9_L001_R1_001.insertions.5p           0.674333           15.786485              15.112152                  634700                           55
#    80         91   91_S91_L001_R1_001.insertions.5p          12.101421           25.841224              13.739802                 2473500                           48
#    81         38   38_S38_L001_R1_001.insertions.5p           0.082957           13.293929              13.210971                 2595700                           71
#    82         48   48_S48_L001_R1_001.insertions.5p           0.858495           13.936366              13.077871                 1276900                          374
#    83         22   22_S22_L001_R1_001.insertions.5p           0.000000           12.602626              12.602626                 2540700                          104
#    84         84   84_S84_L001_R1_001.insertions.5p           0.304387           12.472183              12.167796                 3123500                          109
#    85        104 104_S104_L001_R1_001.insertions.5p           0.166523           11.582808              11.416285                  585100                          109
#    86         52   52_S52_L001_R1_001.insertions.5p           0.028686           11.121409              11.092723                 2399100                           77
#    87        106 106_S106_L001_R1_001.insertions.5p           0.622412           11.365673              10.743261                 3800300                           89
#    88         57   57_S57_L001_R1_001.insertions.5p           3.653309           14.394465              10.741156                  770900                          104
#    89        119 119_S119_L001_R1_001.insertions.5p           2.299886           12.610340              10.310455                  620300                           89
#    90         35   35_S35_L001_R1_001.insertions.5p           5.067004           15.357085              10.290081                  224900                           79
#    91         55   55_S55_L001_R1_001.insertions.5p           0.005664            9.578023               9.572359                 1315500                          121
#    92         96   96_S96_L001_R1_001.insertions.5p           6.450763           15.967614               9.516852                 2170900                          108
#    93         58   58_S58_L001_R1_001.insertions.5p          19.856054           29.304523               9.448469                 1222300                           77
#    94         62   62_S62_L001_R1_001.insertions.5p          13.099870           22.537889               9.438019                 3949900                           71
#    95         47   47_S47_L001_R1_001.insertions.5p          11.958724           20.425800               8.467075                 3565700                           67
#    96        116 116_S116_L001_R1_001.insertions.5p           7.150860           15.547033               8.396174                  933100                           98
#    97        114 114_S114_L001_R1_001.insertions.5p           2.280702           10.133543               7.852841                  533300                           64
#    98         10   10_S10_L001_R1_001.insertions.5p           0.085368            7.250583               7.165215                 1562900                           80
#    99         61   61_S61_L001_R1_001.insertions.5p           9.266641           16.265670               6.999029                 2441300                          125
#   100         50   50_S50_L001_R1_001.insertions.5p           0.002254            5.015667               5.013413                  439500                          188
#   101         28   28_S28_L001_R1_001.insertions.5p          17.067812           21.699006               4.631195                 3262900                           53
#   102          8     8_S8_L001_R1_001.insertions.5p          20.637079           25.182534               4.545455                 1409700                           39
#   103          7     7_S7_L001_R1_001.insertions.5p          11.607317           12.181358               0.574042                 4218900                           32
#   104         79   79_S79_L001_R1_001.insertions.5p          24.635413           24.255348              -0.380065                 2998900                           62
#   105        107 107_S107_L001_R1_001.insertions.5p          16.536260           16.048796              -0.487463                 1606900                           75
#   106         54   54_S54_L001_R1_001.insertions.5p          29.019192           27.276504              -1.742689                 4521700                           53
#   107         46   46_S46_L001_R1_001.insertions.5p          39.761129           32.534202              -7.226927                 1869700                           32
#   108         77   77_S77_L001_R1_001.insertions.5p          23.214001           14.282012              -8.931989                  602100                           88
#   109        101 101_S101_L001_R1_001.insertions.5p          46.514089           35.583411             -10.930679                 3594700                           24
#   110         41   41_S41_L001_R1_001.insertions.5p          31.839187           17.282810             -14.556377                 4517900                           31
#   111         97   97_S97_L001_R1_001.insertions.5p          37.589150           22.976733             -14.612417                 1869700                           43
#   112         25   25_S25_L001_R1_001.insertions.5p          36.117681           21.482550             -14.635131                 2637100                           26
#   113         78   78_S78_L001_R1_001.insertions.5p          52.045997           14.080068             -37.965928                 1460300                           52
#   114         76   76_S76_L001_R1_001.insertions.5p          44.401270            4.852929             -39.548341                 3655100                           78
#   115         80   80_S80_L001_R1_001.insertions.5p          57.135596           12.258301             -44.877295                 1034100                           36
#   116         45   45_S45_L001_R1_001.insertions.5p          61.431685           15.425032             -46.006654                 1734500                           52
#   117         13   13_S13_L001_R1_001.insertions.5p          75.843441           19.897925             -55.945516                 2717700                            3
#   118         27   27_S27_L001_R1_001.insertions.5p          92.213200            2.536981             -89.676218                  783100                           17
#   119        118 118_S118_L001_R1_001.insertions.5p          91.480467            1.118667             -90.361800                 2286900                           13
#   120         92   92_S92_L001_R1_001.insertions.5p          92.400730            0.737867             -91.662863                 2654700                           27
#
# ========================================================================================================================
# Total samples analyzed: 120
# Samples with off-target preference > 0%: 103

# %%
##### post novel cast
##### repeat shared features analysis with OFF TARGET samples, what features are shared between candidates and original guide
# high off target pref, shared features with original guide
# ...existing code...
# For each imperfect alignment, analyze position-by-position match/mismatch/gap frequencies
# USE HIGH OFF-TARGET PREFERENCE SAMPLES

import pandas as pd

# Get top 10 samples by off-target preference (highest positive values)
if 'df_off_target' not in globals():
    raise RuntimeError("df_off_target not found. Run the off-target preference cell first.")

top_10_samples = (
    df_off_target
    .dropna(subset=['off_target_preference'])
    .sort_values('off_target_preference', ascending=False)
    .head(10)['sample_id']
    .astype(int)
    .tolist()
)

# Load the combined candidate spacers CSV
combined_csv = output_csv_dir / "CandidateSpacers_AllSamples_filtered_combined.csv"
df_candidates = pd.read_csv(combined_csv)

# Collect position-level statistics
position_stats = {pos: {'match': 0, 'mismatch': 0, 'gap': 0} for pos in range(20)}

for sample_id in top_10_samples:
    # Filter for this sample's candidates
    sample_candidates = df_candidates[df_candidates['hotspot'].str.startswith(f"{sample_id}_")].copy()
    
    if sample_candidates.empty:
        continue
    
    original_guide = guideRNA["protospacer"][sample_id - 1]
    
    # Group by hotspot (MCV)
    for hotspot, group in sample_candidates.groupby('hotspot'):
        # Find best alignment (highest alignment_score)
        best_row = group.loc[group['alignment_score'].idxmax()]
        guide_seq = best_row['guide_seq']
        
        # Only analyze imperfect alignments (mismatch_count > 0)
        if best_row['mismatch_count'] > 0:
            try:
                aln = php.local_align(original_guide, guide_seq)
                
                coords_q = list(aln.coordinates[0])
                coords_t = list(aln.coordinates[1])
                
                # Build gapped alignment strings from coordinates
                query_gapped = ""
                target_gapped = ""
                
                for i in range(len(coords_q) - 1):
                    q_start, q_end = coords_q[i], coords_q[i + 1]
                    t_start, t_end = coords_t[i], coords_t[i + 1]
                    
                    q_len = q_end - q_start
                    t_len = t_end - t_start
                    
                    if q_len > 0 and t_len > 0:
                        # Both sequences have bases
                        query_gapped += original_guide[q_start:q_end]
                        target_gapped += guide_seq[t_start:t_end]
                    elif q_len > 0:
                        # Gap in target
                        query_gapped += original_guide[q_start:q_end]
                        target_gapped += "-" * q_len
                    elif t_len > 0:
                        # Gap in query
                        query_gapped += "-" * t_len
                        target_gapped += guide_seq[t_start:t_end]
                
                # Track position in original guide
                query_pos = int(coords_q[0])
                
                # Iterate through gapped alignment
                for q_char, t_char in zip(query_gapped, target_gapped):
                    if q_char != '-':
                        # This position exists in query
                        if t_char == '-':
                            position_stats[query_pos]['gap'] += 1
                        elif q_char == t_char:
                            position_stats[query_pos]['match'] += 1
                        else:
                            position_stats[query_pos]['mismatch'] += 1
                        query_pos += 1
                        
            except Exception:
                pass

# Display results
print("Position-by-position alignment statistics (imperfect alignments only)")
print("=" * 80)
print(f"{'Pos':>3} {'Match':>6} {'Mismatch':>8} {'Gap':>5} | Match%   Mismatch%   Gap%")
print("-" * 80)

for pos in range(20):
    stats = position_stats[pos]
    total = stats['match'] + stats['mismatch'] + stats['gap']
    
    if total > 0:
        match_pct = (stats['match'] / total) * 100
        mismatch_pct = (stats['mismatch'] / total) * 100
        gap_pct = (stats['gap'] / total) * 100
        
        print(f"{pos:3d} {stats['match']:6d} {stats['mismatch']:8d} {stats['gap']:5d} | {match_pct:6.1f}%  {mismatch_pct:6.1f}%  {gap_pct:6.1f}%")
    else:
        print(f"{pos:3d} {'—':>6} {'—':>8} {'—':>5} | No data")
# ...existing code...
# Out:
# Position-by-position alignment statistics (imperfect alignments only)
# ================================================================================
# Pos  Match Mismatch   Gap | Match%   Mismatch%   Gap%
# --------------------------------------------------------------------------------
#   0      5        0     0 |  100.0%     0.0%     0.0%
#   1      4        4     0 |   50.0%    50.0%     0.0%
#   2     15        1     0 |   93.8%     6.2%     0.0%
#   3     13        7     0 |   65.0%    35.0%     0.0%
#   4     18        5     0 |   78.3%    21.7%     0.0%
#   5     19        6     2 |   70.4%    22.2%     7.4%
#   6     19        8     2 |   65.5%    27.6%     6.9%
#   7     19        9     3 |   61.3%    29.0%     9.7%
#   8     13       13     6 |   40.6%    40.6%    18.8%
#   9     17       16     3 |   47.2%    44.4%     8.3%
#  10     29       10     1 |   72.5%    25.0%     2.5%
#  11     34        4     3 |   82.9%     9.8%     7.3%
#  12     30        7     4 |   73.2%    17.1%     9.8%
#  13     31        8     2 |   75.6%    19.5%     4.9%
#  14     37        4     1 |   88.1%     9.5%     2.4%
#  15     39        3     0 |   92.9%     7.1%     0.0%
#  16     39        3     0 |   92.9%     7.1%     0.0%
#  17     39        3     0 |   92.9%     7.1%     0.0%
#  18     38        2     0 |   95.0%     5.0%     0.0%
#  19     38        0     0 |  100.0%     0.0%     0.0%

# %%
# select ideal giude based on shared features, OFF TARGET PREF
# critical match positions

# %%
# v2, coordinate based not symbol based alignment for on target shared features
# Select ideal guides for each MCV based on alignment criteria
# Filter: no 100% alignment, check matches at positions 0, 1, 16, 17, 18, 19
# Fallback: if criteria not met, choose highest alignment score

import pandas as pd

# Load the combined candidate spacers CSV
combined_csv = output_csv_dir / "CandidateSpacers_AllSamples_filtered_combined.csv"
df_candidates = pd.read_csv(combined_csv)

selected_guides = []
total_hotspots = 0

# Process each sample
for sample_id in df_candidates['hotspot'].str.split('_').str[0].unique():
    sample_id = int(sample_id)
    original_guide = guideRNA["protospacer"][sample_id - 1]
    
    # Get all candidates for this sample
    sample_candidates = df_candidates[df_candidates['hotspot'].str.startswith(f"{sample_id}_")].copy()
    
    # Group by MCV (hotspot)
    for hotspot, group in sample_candidates.groupby('hotspot'):
        total_hotspots += 1
        
        # Filter out 100% alignments
        group_filtered = group[group['mismatch_count'] > 0].copy()
        
        if group_filtered.empty:
            continue
        
        best_guide_criteria = None
        best_score_criteria = -1
        best_alignment_criteria = None
        
        best_guide_fallback = None
        best_score_fallback = -1
        best_alignment_fallback = None
        
        # Evaluate each guide candidate
        for _, row in group_filtered.iterrows():
            guide_seq = row['guide_seq']
            
            # Align new guide to original
            try:
                aln = php.local_align(original_guide, guide_seq)
                
                coords_q = list(aln.coordinates[0])
                coords_t = list(aln.coordinates[1])
                
                # Check matches at critical positions: 0, 1, 16, 17, 18, 19 using coordinates
                critical_positions = [0, 1, 2, 14, 15, 16, 17, 18, 19]
                matches_at_critical = 0
                
                # Process each alignment block
                for i in range(len(coords_q) - 1):
                    q_start, q_end = int(coords_q[i]), int(coords_q[i + 1])
                    t_start, t_end = int(coords_t[i]), int(coords_t[i + 1])
                    
                    q_len = q_end - q_start
                    t_len = t_end - t_start
                    
                    # Only check blocks where both sequences have bases (no gaps)
                    if q_len > 0 and t_len > 0 and q_len == t_len:
                        q_block = original_guide[q_start:q_end]
                        t_block = guide_seq[t_start:t_end]
                        
                        # Check each position in this block
                        for offset, (q_char, t_char) in enumerate(zip(q_block, t_block)):
                            query_pos = q_start + offset
                            if query_pos in critical_positions:
                                if q_char == t_char:
                                    matches_at_critical += 1
                
                # Track best by criteria (critical position matches)
                if matches_at_critical > best_score_criteria:
                    best_score_criteria = matches_at_critical
                    best_guide_criteria = row.copy()
                    best_guide_criteria['critical_position_matches'] = matches_at_critical
                    best_guide_criteria['original_guide'] = original_guide
                    best_guide_criteria['selection_method'] = 'criteria'
                    best_alignment_criteria = aln
                
                # Track best by fallback (alignment score)
                if aln.score > best_score_fallback:
                    best_score_fallback = aln.score
                    best_guide_fallback = row.copy()
                    best_guide_fallback['critical_position_matches'] = matches_at_critical
                    best_guide_fallback['original_guide'] = original_guide
                    best_guide_fallback['selection_method'] = 'fallback_alignment_score'
                    best_alignment_fallback = aln
                    
            except Exception as e:
                pass
        
        # Choose criteria-based if available, otherwise fallback
        if best_guide_criteria is not None:
            selected_guide = best_guide_criteria
            selected_alignment = best_alignment_criteria
        elif best_guide_fallback is not None:
            selected_guide = best_guide_fallback
            selected_alignment = best_alignment_fallback
        else:
            continue
        
        selected_guides.append(selected_guide)
        
        # Display alignment for this selected guide
        print(f"\n{hotspot}:")
        print(f"  Selection method: {selected_guide['selection_method']}")
        print(f"  Critical position matches: {selected_guide['critical_position_matches']}/6")
        print(f"  Mismatch count: {int(selected_guide['mismatch_count'])}")
        print(f"  Alignment score: {selected_guide['alignment_score']:.1f}")
        print(selected_alignment)

# Create results dataframe
df_selected = pd.DataFrame(selected_guides)

# Save to CSV
if not df_selected.empty:
    output_csv = output_csv_dir / "02132026_Selected_Ideal_Guides.csv"
    df_selected.to_csv(output_csv, index=False)
    print("\n" + "=" * 100)
    print(f"✓ Saved selected guides to: {output_csv}")
    print(f"  Total guides selected: {len(df_selected)}")
    print(f"  Total hotspots across all samples: {total_hotspots}")
    
    # Summary by selection method
    print("\nSelection method summary:")
    print(df_selected['selection_method'].value_counts())
else:
    print("\nNo guides selected")
    print(f"Total hotspots across all samples: {total_hotspots}")
# Out:
# 1_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 17.0
# target            6 ATGGCAG---ATCCCAG 20
#                   0 ||..|||---||||||| 17
# query             3 ATTTCAGGTCATCCCAG 20
#
#
# 1_mcv2:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 22.0
# target            3 ACAATGGCAGATCCCAG 20
#                   0 |||||-..||||||||| 17
# query             4 ACAAT-CAAGATCCCAG 20
#
#
# 1_mcv3:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 15.5
# target            4 CAATGG--CAGATCCCAG 20
#                   0 ||..||--.||.|||||| 18
# query             2 CAGCGGGTTAGTTCCCAG 20
#
#
# 1_mcv4:
#   Selection method: criteria
#   Critical position matches: 2/6
#   Mismatch count: 16
#   Alignment score: 8.0
# target            1 TGAC  5
#                   0 ||||  4
# query            12 TGAC 16
#
#
# 2_mcv1:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 12
#   Alignment score: 11.5
# target            4 ACAGCGTGTACCACAG 20
#                   0 |.|.||..|--||||| 16
# query             6 AAACCGATT--CACAG 20
#
#
# 2_mcv2:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 18
#   Alignment score: 32.0
# target            4 ACAGCGTGTACCACAG 20
#                   0 |||||||||||||||| 16
# query             0 ACAGCGTGTACCACAG 16
#
#
# 2_mcv3:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 11
#   Alignment score: 14.0
# target            2 GCACAGCGTGTACC-ACAG 20
#                   0 ||...||..|.|||-|||| 19
# query             1 GCCATGCCAGCACCAACAG 20
#
#
# 2_mcv4:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 13.5
# target            5 CAGCGTGTACCACAG 20
#                   0 ||.||----|||||| 15
# query             9 CATCG----CCACAG 20
#
#
# 2_mcv5:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 12
#   Alignment score: 15.5
# target            5 CAGCGTGTACC----ACAG 20
#                   0 |.|.||.||||----|||| 19
# query             1 CCGAGTATACCTTGTACAG 20
#
#
# 3_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 13
#   Alignment score: 12.0
# target            0 GTGAGCGAGTAACAACCC 18
#                   0 |||-|||..|.|...||| 18
# query             2 GTG-GCGTTTGAATTCCC 19
#
#
# 3_mcv2:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 7
#   Alignment score: 19.0
# target            3 AGCGAGTAACAACCCGT 20
#                   0 ||...|.||||.||||| 17
# query             3 AGATGGCAACAGCCCGT 20
#
#
# 3_mcv3:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 15
#   Alignment score: 19.0
# target            9 TAACAACCCGT 20
#                   0 ||||||||.|| 11
# query             5 TAACAACCTGT 16
#
#
# 3_mcv4:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 16
#   Alignment score: 9.0
# target           11 ACAACCCGT 20
#                   0 |.||.|.||  9
# query             9 AGAAGCGGT 18
#
#
# 4_mcv1:
#   Selection method: criteria
#   Critical position matches: 3/6
#   Mismatch count: 13
#   Alignment score: 7.0
# target           13 TATCG 18
#                   0 |||.|  5
# query             2 TATTG  7
#
#
# 4_mcv2:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 14
#   Alignment score: 10.5
# target            3 CCCGAATCT-CTAT--CGTG 20
#                   0 ||.|..|||-.|||--.||| 20
# query             0 CCTGTGTCTGGTATTCAGTG 20
#
#
# 4_mcv3:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 16
#   Alignment score: 18.0
# target            1 ATCCCGAATCTCTATCGTG 20
#                   0 |.||||||..||---|||| 19
# query             4 AACCCGAAGGTC---CGTG 20
#
#
# 4_mcv4:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 18
#   Alignment score: 34.0
# target            3 CCCGAATCTCTATCGTG 20
#                   0 ||||||||||||||||| 17
# query             0 CCCGAATCTCTATCGTG 17
#
#
# 5_mcv1:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 8
#   Alignment score: 16.0
# target            0 ACGCCAATGTCGTTATCCAG 20
#                   0 ||.||...|.|.|..||||| 20
# query             0 ACACCTTCGACTTCCTCCAG 20
#
#
# 5_mcv2:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 13.5
# target            2 GCCAATGTCGT--TATCCAG 20
#                   0 ||.||..||.|--..||||| 20
# query             0 GCAAAAATCTTCCAGTCCAG 20
#
#
# 5_mcv3:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 11
#   Alignment score: 14.0
# target            1 CGCCAATGTCGTTA--TCCAG 20
#                   0 ||||---||--|||--||||| 21
# query             4 CGCC---GT--TTACTTCCAG 20
#
#
# 5_mcv4:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 15
#   Alignment score: 18.0
# target            2 GCCAATGTCGTTATCCAG 20
#                   0 ||..||...|.||||||| 18
# query             1 GCGGATTAAGATATCCAG 19
#
#
# 5_mcv5:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 15
#   Alignment score: 13.0
# target            0 ACGCCAATGTCGTTATC 17
#                   0 |.||.||..||..|.|| 17
# query             1 ATGCAAAAATCCATTTC 18
#
#
# 6_mcv1:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 10
#   Alignment score: 13.5
# target            2 GGTGAACTGATCGCGCAG 20
#                   0 ||||--|.|---|||||| 18
# query             7 GGTG--CGG---GCGCAG 20
#
#
# 6_mcv2:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 7
#   Alignment score: 19.0
# target            0 CGGGTGAACTGATCGCGCAG 20
#                   0 |.|||.|..|..|.|||||| 20
# query             0 CTGGTAAGGTCTTTGCGCAG 20
#
#
# 6_mcv3:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 15
#   Alignment score: 12.0
# target            8 CTGATCGCGCAG 20
#                   0 |||-.|||||.| 12
# query             6 CTG-GCGCGCGG 17
#
#
# 6_mcv4:
#   Selection method: criteria
#   Critical position matches: 3/6
#   Mismatch count: 13
#   Alignment score: 11.0
# target           10 GATCGCG 17
#                   0 |||.|||  7
# query             6 GATGGCG 13
#
#
# 7_mcv1:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 11
#   Alignment score: 12.0
# target            5 CGGCTTCTGACCATG 20
#                   0 |||.|.....||||| 15
# query             5 CGGGTAGCACCCATG 20
#
#
# 7_mcv2:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 14
#   Alignment score: 9.5
# target            1 TGC--CCGGCTTCTGACC 17
#                   0 |||--|||....|-|||| 18
# query             0 TGCAACCGAACGC-GACC 17
#
#
# 7_mcv3:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 11
#   Alignment score: 11.5
# target            4 CCGGCTTCTGACCATG 20
#                   0 |||--||.|-||.||| 16
# query             7 CCG--TTAT-ACTATG 20
#
#
# 7_mcv4:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 16
#   Alignment score: 12.0
# target            2 GCCCGGCTTCTGACCATG 20
#                   0 ||..|.||||...|..|| 18
# query             0 GCTGGCCTTCATGCACTG 18
#
#
# 8_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 19.5
# target            5 ACCATC--ACCGCGAGG 20
#                   0 ||.|||--.|||||||| 17
# query             3 ACGATCCTGCCGCGAGG 20
#
#
# 8_mcv2:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 34.0
# target            0 GCAGCACCATCACCGCG 17
#                   0 ||||||||||||||||| 17
# query             3 GCAGCACCATCACCGCG 20
#
#
# 8_mcv3:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 9
#   Alignment score: 17.0
# target            4 CACCATCACCGCGAGG 20
#                   0 ||.|.|..|.|||||| 16
# query             4 CAGCGTTGCTGCGAGG 20
#
#
# 8_mcv4:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 14
#   Alignment score: 11.5
# target            0 GCA--GCACCATC-ACCGC 16
#                   0 |||--|..||.||-.|||| 19
# query             0 GCAGTGTGCCGTCTTCCGC 19
#
#
# 9_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 13
#   Alignment score: 14.5
# target            4 TTATCGATGAGCGTGG 20
#                   0 |.||||--..|||||| 16
# query             6 TCATCG--TCGCGTGG 20
#
#
# 9_mcv2:
#   Selection method: criteria
#   Critical position matches: 9/6
#   Mismatch count: 11
#   Alignment score: 20.0
# target            0 GAAATTATCGATGAGCGTGG 20
#                   0 ||||||.|---|..|||||| 20
# query             3 GAAATTTT---TCGGCGTGG 20
#
#
# 9_mcv3:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 12
#   Alignment score: 13.0
# target            9 GATGAGCGTGG 20
#                   0 |.|||..|||| 11
# query             6 GTTGATTGTGG 17
#
#
# 9_mcv4:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 12
#   Alignment score: 11.0
# target            1 AAATTATCGATGAGCGTGG 20
#                   0 ||..|.|.|..|.|-|||| 19
# query             1 AAGGTTTTGCAGTG-GTGG 19
#
#
# 9_mcv5:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 16.0
# target            2 AATTATC-GA-TGAGCGTGG 20
#                   0 ||..|||-||-|.|.||||| 20
# query             0 AAAGATCAGATTAACCGTGG 20
#
#
# 9_mcv6:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 14
#   Alignment score: 10.0
# target            9 GATGAGCGTGG 20
#                   0 |.||...|||| 11
# query             6 GTTGGCGGTGG 17
#
#
# 9_mcv7:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 14
#   Alignment score: 34.0
# target            0 GAAATTATCGATGAGCG 17
#                   0 ||||||||||||||||| 17
# query             3 GAAATTATCGATGAGCG 20
#
#
# 10_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 20.0
# target           10 CATCACCGCG 20
#                   0 |||||||||| 10
# query            10 CATCACCGCG 20
#
#
# 10_mcv2:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 12
#   Alignment score: 12.0
# target            6 GCACCATC-ACCGCG 20
#                   0 ||..|.||-.||||| 15
# query             5 GCTTCTTCTGCCGCG 20
#
#
# 10_mcv3:
#   Selection method: criteria
#   Critical position matches: 1/6
#   Mismatch count: 12
#   Alignment score: 11.0
# target            9 CCATCAC 16
#                   0 |||||.|  7
# query            12 CCATCGC 19
#
#
# 10_mcv4:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 15
#   Alignment score: 10.0
# target           10 CAT-CACCGCG 20
#                   0 |||-.|.|||| 11
# query             0 CATAAAACGCG 11
#
#
# 10_mcv5:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 34.0
# target            3 GCAGCACCATCACCGCG 20
#                   0 ||||||||||||||||| 17
# query             0 GCAGCACCATCACCGCG 17
#
#
# 11_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 8
#   Alignment score: 22.5
# target            2 GCGGG--GAGCGTCACACTG 20
#                   0 |||||--..|||||||.||| 20
# query             0 GCGGGATCGGCGTCACCCTG 20
#
#
# 12_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 9
#   Alignment score: 16.0
# target           12 GCAGACGA 20
#                   0 ||||||||  8
# query            12 GCAGACGA 20
#
#
# 12_mcv10:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 10
#   Alignment score: 14.5
# target            7 GATGA----GCAGACGA 20
#                   0 |.|||----||.||||| 17
# query             3 GTTGATACTGCTGACGA 20
#
#
# 12_mcv11:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 10
#   Alignment score: 17.0
# target            3 CATGGATGA---GCAGACGA 20
#                   0 ||..|||||---|..||||| 20
# query             0 CAGCGATGAAGTGGTGACGA 20
#
#
# 12_mcv2:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 17.0
# target            4 ATGGATGAGCAGACGA 20
#                   0 ||.|-||-|||||||| 16
# query             6 ATTG-TG-GCAGACGA 20
#
#
# 12_mcv3:
#   Selection method: criteria
#   Critical position matches: 3/6
#   Mismatch count: 13
#   Alignment score: 9.5
# target            4 ATGGATGAGCAGACG 19
#                   0 ||.||--|.|..||| 15
# query             4 ATTGA--AACCCACG 17
#
#
# 12_mcv4:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 13
#   Alignment score: 13.0
# target            3 CATGGATGAGCAGACGA 20
#                   0 |.||..|||-..||||| 17
# query             4 CCTGCGTGA-ATGACGA 20
#
#
# 12_mcv5:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 12
#   Alignment score: 16.0
# target           12 GCAGACGA 20
#                   0 ||||||||  8
# query            12 GCAGACGA 20
#
#
# 12_mcv6:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 18
#   Alignment score: 10.0
# target           15 GACGA 20
#                   0 |||||  5
# query            13 GACGA 18
#
#
# 12_mcv7:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 10
#   Alignment score: 15.0
# target            5 TGGATGAGCAGACGA 20
#                   0 ||..||-||.||||| 15
# query             6 TGACTG-GCTGACGA 20
#
#
# 12_mcv8:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 13
#   Alignment score: 10.5
# target            1 GTCATGGATGA-GCAGACGA 20
#                   0 |||.|--||.|-||..||.| 20
# query             1 GTCTT--ATCAGGCCTACAA 19
#
#
# 12_mcv9:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 18
#   Alignment score: 11.0
# target           13 CAGACGA 20
#                   0 |.|||||  7
# query            12 CTGACGA 19
#
#
# 13_mcv1:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 14
#   Alignment score: 9.0
# target            7 AATCCGCA-CCT 18
#                   0 ||.|.|.|-||| 12
# query             1 AAGCAGAAGCCT 13
#
#
# 13_mcv2:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 4
#   Alignment score: 28.0
# target            3 TTTCAATCCGCACCTCG 20
#                   0 |||||..|||||||||| 17
# query             3 TTTCATGCCGCACCTCG 20
#
#
# 14_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 12
#   Alignment score: 10.0
# target            0 CAGCTGGCGTA-ATAGCGAA 19
#                   0 |.|.|..|.||-.|..|||| 20
# query             0 CCGATTTCTTATTTCACGAA 20
#
#
# 14_mcv2:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 8
#   Alignment score: 18.0
# target            3 CTGGCG-TAATAGCGAAG 20
#                   0 |.||||-||...|||||| 18
# query             2 CCGGCGATAGCGGCGAAG 20
#
#
# 14_mcv3:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 11
#   Alignment score: 13.5
# target            8 GTAATAGC--GAAG 20
#                   0 ||.|||.|--|||| 14
# query             6 GTCATAACCAGAAG 20
#
#
# 14_mcv4:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 14
#   Alignment score: 11.5
# target            2 GCTGGCGTAATAGCGA 18
#                   0 |.||--|.||..|||| 16
# query             0 GTTG--GGAAGGGCGA 14
#
#
# 15_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 9
#   Alignment score: 19.5
# target            3 ACCAGATGATCACACTC 20
#                   0 |||--||.|.||||||| 17
# query             5 ACC--ATAACCACACTC 20
#
#
# 15_mcv2:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 11
#   Alignment score: 11.5
# target            5 CAG--ATGAT---CACACTC 20
#                   0 |||--.||||---..||||| 20
# query             0 CAGTATTGATACCGGCACTC 20
#
#
# 15_mcv3:
#   Selection method: criteria
#   Critical position matches: 0/6
#   Mismatch count: 14
#   Alignment score: 8.0
# target            4 CCAGATG 11
#                   0 |.|.|||  7
# query             0 CGAAATG  7
#
#
# 15_mcv4:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 5
#   Alignment score: 26.0
# target            1 CGACCAGATGATCACACTC 20
#                   0 ||.|..|||||||||.||| 19
# query             1 CGGCACGATGATCACTCTC 20
#
#
# 15_mcv5:
#   Selection method: criteria
#   Critical position matches: 3/6
#   Mismatch count: 17
#   Alignment score: 11.0
# target            2 GAC-CAGATGATCACA 17
#                   0 |||-||..|||-|.|| 16
# query             5 GACACAACTGA-CGCA 20
#
#
# 15_mcv6:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 19
#   Alignment score: 38.0
# target            0 GCGACCAGATGATCACACT 19
#                   0 ||||||||||||||||||| 19
# query             1 GCGACCAGATGATCACACT 20
#
#
# 16_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 12.5
# target            8 TGATGCTCGTGA 20
#                   0 |.||--|||||| 12
# query            10 TCAT--TCGTGA 20
#
#
# 16_mcv2:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 17
#   Alignment score: 11.0
# target            0 GCAGAGGATGATGCTC 16
#                   0 |||..||..||...|| 16
# query             4 GCATGGGCGGAGTTTC 20
#
#
# 16_mcv3:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 13
#   Alignment score: 11.0
# target           13 CTCGTGA 20
#                   0 ||.||||  7
# query            13 CTGGTGA 20
#
#
# 16_mcv4:
#   Selection method: criteria
#   Critical position matches: 3/6
#   Mismatch count: 16
#   Alignment score: 12.0
# target            3 GAGGATGATGCTCGT 18
#                   0 |.||.||.|...||| 15
# query             5 GCGGCTGGTCAACGT 20
#
#
# 16_mcv5:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 17.0
# target           10 ATGCTCGTGA 20
#                   0 ||.||||||| 10
# query            10 ATACTCGTGA 20
#
#
# 17_mcv1:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 17
#   Alignment score: 24.0
# target            1 GTAATGGGATAGGTCACG 19
#                   0 ||.|.|..|||||||||| 18
# query             0 GTCAGGAAATAGGTCACG 18
#
#
# 17_mcv2:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 15
#   Alignment score: 20.0
# target            4 ATGGGATAGGTCACGT 20
#                   0 |||...||.||||||| 16
# query             1 ATGTAGTAAGTCACGT 17
#
#
# 17_mcv3:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 12
#   Alignment score: 17.5
# target            0 CGTAATGGGATAGGTCACGT 20
#                   0 ||.|||----.|.||||||| 20
# query             4 CGCAAT----CAAGTCACGT 20
#
#
# 17_mcv4:
#   Selection method: criteria
#   Critical position matches: 2/6
#   Mismatch count: 12
#   Alignment score: 8.5
# target            3 AATGGG--ATAGGTCA 17
#                   0 ||.|.|--||..|.|| 16
# query             1 AAAGCGCCATTCGCCA 17
#
#
# 18_mcv1:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 10
#   Alignment score: 15.0
# target            2 TCGGGCAAATAATATCGG 20
#                   0 |.|.||-.|..||||||| 18
# query             3 TGGAGC-CACGATATCGG 20
#
#
# 18_mcv2:
#   Selection method: criteria
#   Critical position matches: 3/6
#   Mismatch count: 17
#   Alignment score: 10.0
# target            0 CAT-CGGGCAA 10
#                   0 |||-|.|.||| 11
# query             6 CATACTGTCAA 17
#
#
# 18_mcv3:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 11
#   Alignment score: 16.5
# target            0 CATCGGGCAAATAATATCGG 20
#                   0 |.|||...||--.||||||| 20
# query             2 CTTCGATGAA--GATATCGG 20
#
#
# 18_mcv4:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 12
#   Alignment score: 13.5
# target            2 TCGGGCA--AATAATATCGG 20
#                   0 ||.||||--..|...||||| 20
# query             0 TCTGGCAGGCCTGGGATCGG 20
#
#
# 18_mcv5:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 17.0
# target            3 CGGGCAAATAAT----ATCGG 20
#                   0 |||--|.|||||----||||| 21
# query             1 CGG--AGATAATCGAGATCGG 20
#
#
# 18_mcv6:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 10
#   Alignment score: 12.0
# target            5 GGCAAATAATATCGG 20
#                   0 ||||......||||| 15
# query             5 GGCATCACTGATCGG 20
#
#
# 18_mcv7:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 15
#   Alignment score: 34.0
# target            0 CATCGGGCAAATAATAT 17
#                   0 ||||||||||||||||| 17
# query             3 CATCGGGCAAATAATAT 20
#
#
# 19_mcv1:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 14
#   Alignment score: 13.0
# target            1 TCGCTCGGGAAGACGTACG 20
#                   0 ||.|.||.|-----||||| 19
# query             2 TCTCCCGTG-----GTACG 16
#
#
# 19_mcv10:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 15
#   Alignment score: 38.0
# target            0 TTCGCTCGGGAAGACGTAC 19
#                   0 ||||||||||||||||||| 19
# query             1 TTCGCTCGGGAAGACGTAC 20
#
#
# 19_mcv2:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 12
#   Alignment score: 14.0
# target           13 ACGTACG 20
#                   0 |||||||  7
# query            13 ACGTACG 20
#
#
# 19_mcv3:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 7
#   Alignment score: 21.0
# target            2 CGCTCGGGAAGACGTACG 20
#                   0 ||.||.||...||||||| 18
# query             2 CGATCAGGTTTACGTACG 20
#
#
# 19_mcv4:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 17
#   Alignment score: 10.0
# target           15 GTACG 20
#                   0 |||||  5
# query            12 GTACG 17
#
#
# 19_mcv5:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 11
#   Alignment score: 20.5
# target            3 GCTCGGGAAGACGTAC 19
#                   0 |.||||--|||||||| 16
# query             5 GATCGG--AGACGTAC 19
#
#
# 19_mcv6:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 8
#   Alignment score: 18.0
# target            1 TCGCTCGGGAAGACGTAC 19
#                   0 ||||.....||||||.|| 18
# query             1 TCGCGGATAAAGACGAAC 19
#
#
# 19_mcv7:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 14.0
# target            4 CTCGGGAAGACGTACG 20
#                   0 ||.|..|...|||||| 16
# query             4 CTGGCAATTGCGTACG 20
#
#
# 19_mcv8:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 12.0
# target            2 CGCTCGGGAAGACGTACG 20
#                   0 |||...|..|...||||| 18
# query             2 CGCATCGCCACCGGTACG 20
#
#
# 19_mcv9:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 11.5
# target            3 GCTCGGGAAGAC--GTACG 20
#                   0 ||||......||--||||| 19
# query             1 GCTCCATTTCACTGGTACG 20
#
#
# 20_mcv1:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 10
#   Alignment score: 12.0
# target           11 GCTGCTGAA 20
#                   0 |.|.|||||  9
# query            11 GATCCTGAA 20
#
#
# 20_mcv2:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 8
#   Alignment score: 19.5
# target            2 TGGTCTG--CTGCTGCTGAA 20
#                   0 ||.|..|--||||||.|||| 20
# query             0 TGTTGGGAACTGCTGATGAA 20
#
#
# 20_mcv3:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 12
#   Alignment score: 16.5
# target            3 GGTCTG--CTGC-TGCTGAA 20
#                   0 ||||.|--.|.|-||||||| 20
# query             0 GGTCAGAATTACGTGCTGAA 20
#
#
# 20_mcv4:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 13.0
# target            9 CTGCTGCTGAA 20
#                   0 ||.|-|||||| 11
# query            10 CTTC-GCTGAA 20
#
#
# 20_mcv5:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 16
#   Alignment score: 12.0
# target            4 GTCTGCTGCTGCTGA 19
#                   0 ||.|.|..|.||.|| 15
# query             5 GTGTACCACAGCGGA 20
#
#
# 20_mcv6:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 8
#   Alignment score: 22.0
# target            0 AATGGTCTGCTGCTGCTGAA 20
#                   0 |||||-||.|..||||.||| 20
# query             1 AATGG-CTACCACTGCCGAA 20
#
#
# 20_mcv7:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 13
#   Alignment score: 10.0
# target            1 ATGGTCTGCTGCTGCTGAA 20
#                   0 |.|.||.||-----.|||| 19
# query             6 AGGATCAGC-----ATGAA 20
#
#
# 21_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 19
#   Alignment score: 20.0
# target            7 ACTGGGAAAACCC 20
#                   0 |||-||||||||| 13
# query             5 ACT-GGAAAACCC 17
#
#
# 21_mcv2:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 17
#   Alignment score: 12.0
# target            7 ACTGGGAAAA---CCC 20
#                   0 ||||..||.|---||| 16
# query             1 ACTGCCAATAATGCCC 17
#
#
# 21_mcv3:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 15
#   Alignment score: 18.0
# target           10 GGGAAAACC 19
#                   0 |||||||||  9
# query             7 GGGAAAACC 16
#
#
# 21_mcv4:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 9
#   Alignment score: 17.0
# target            1 GTCG-TGACTGGGAAAACC 19
#                   0 ||||-|.|.|..||||.|| 19
# query             1 GTCGATAAATTTGAAACCC 20
#
#
# 21_mcv5:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 14
#   Alignment score: 8.0
# target           15 AACC 19
#                   0 ||||  4
# query             7 AACC 11
#
#
# 21_mcv6:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 11
#   Alignment score: 9.0
# target           10 GGGAAAACC 19
#                   0 |.|.|.|||  9
# query             4 GTGTATACC 13
#
#
# 21_mcv7:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 10
#   Alignment score: 13.0
# target            9 TGGGAAAACCC 20
#                   0 ||||.||..|| 11
# query             9 TGGGTAACGCC 20
#
#
# 22_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 14
#   Alignment score: 11.5
# target            1 ATGCAGCAACGAGACGTCA 20
#                   0 ||||.|--.||...|||.| 19
# query             3 ATGCTG--GCGGACCGTTA 20
#
#
# 22_mcv10:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 11
#   Alignment score: 13.0
# target           12 AGACGTCA 20
#                   0 |||||.||  8
# query             1 AGACGGCA  9
#
#
# 22_mcv2:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 10
#   Alignment score: 10.0
# target           12 AGACGTCA 20
#                   0 ||..||||  8
# query            12 AGCTGTCA 20
#
#
# 22_mcv3:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 11
#   Alignment score: 10.0
# target           15 CGTCA 20
#                   0 |||||  5
# query            15 CGTCA 20
#
#
# 22_mcv4:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 16
#   Alignment score: 20.0
# target            1 ATGCAGCAACGAGACGTCA 20
#                   0 |.||.||||..|..||||| 19
# query             0 AGGCTGCAAACATGCGTCA 19
#
#
# 22_mcv5:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 17
#   Alignment score: 12.0
# target            2 TGCAGCAACGAGACGTCA 20
#                   0 ||||...|...|.|||.| 18
# query             0 TGCATTTAATTGCCGTAA 18
#
#
# 22_mcv6:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 11
#   Alignment score: 13.5
# target            0 TATGCAGCAACGAGACGTCA 20
#                   0 |||.|||--------||||| 20
# query             8 TATCCAG--------CGTCA 20
#
#
# 22_mcv7:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 16
#   Alignment score: 17.0
# target            5 AGCAAC-GAGACGTCA 20
#                   0 ||||||-||.||-||| 16
# query             0 AGCAACTGACAC-TCA 15
#
#
# 22_mcv8:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 8
#   Alignment score: 16.0
# target            0 TATGCAGCAACGAGACGTCA 20
#                   0 ||||||.|.......||||| 20
# query             0 TATGCAACGCATTTGCGTCA 20
#
#
# 22_mcv9:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 15
#   Alignment score: 13.5
# target            3 GCAGCAACGAGACGTCA 20
#                   0 |||..|||--..||||| 17
# query             2 GCAAAAAC--TGCGTCA 17
#
#
# 23_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 13
#   Alignment score: 19.5
# target            1 TGTGATCATCTGGTCGC 18
#                   0 ||..|||--|||||||| 17
# query             2 TGGCATC--CTGGTCGC 17
#
#
# 23_mcv2:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 8
#   Alignment score: 18.0
# target            5 ATCATCTGGTCGCTG 20
#                   0 ||.|.||||..|||| 15
# query             5 ATGAACTGGAAGCTG 20
#
#
# 23_mcv3:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 10
#   Alignment score: 15.0
# target            0 GTGTGATCATCTGGTCGCTG 20
#                   0 |.|||-----||.|||.||| 20
# query             5 GGGTG-----CTAGTCCCTG 20
#
#
# 23_mcv4:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 7
#   Alignment score: 23.0
# target            7 CATCTGGTCGCTG 20
#                   0 ||||||||.|||| 13
# query             7 CATCTGGTTGCTG 20
#
#
# 23_mcv5:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 19
#   Alignment score: 38.0
# target            0 GTGTGATCATCTGGTCGCT 19
#                   0 ||||||||||||||||||| 19
# query             1 GTGTGATCATCTGGTCGCT 20
#
#
# 24_mcv1:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 14
#   Alignment score: 20.0
# target            9 CCGCTCACGC 19
#                   0 |||||||||| 10
# query             8 CCGCTCACGC 18
#
#
# 24_mcv2:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 11
#   Alignment score: 19.0
# target            1 GATTACGACCGCTCACGCG 20
#                   0 ||||-----.||||||||| 19
# query             6 GATT-----TGCTCACGCG 20
#
#
# 24_mcv3:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 16
#   Alignment score: 13.5
# target            0 TGATTAC-GACCGCTCACGC 19
#                   0 |||--||-|.|.|||..||| 20
# query             2 TGA--ACTGCCAGCTGGCGC 20
#
#
# 25_mcv1:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 13
#   Alignment score: 38.0
# target            0 CCAGGCGTTAGGGTCAATG 19
#                   0 ||||||||||||||||||| 19
# query             1 CCAGGCGTTAGGGTCAATG 20
#
#
# 25_mcv2:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 16
#   Alignment score: 17.0
# target           10 GGGTCAATGC 20
#                   0 |.|||||||| 10
# query             7 GAGTCAATGC 17
#
#
# 25_mcv3:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 17
#   Alignment score: 15.0
# target            4 GCG---TTAGGGTCAATGC 20
#                   0 |||---|..|..||||||| 19
# query             0 GCGATCTCCGCTTCAATGC 19
#
#
# 25_mcv4:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 15.0
# target           11 GGTCAATGC 20
#                   0 |.|||||||  9
# query            11 GCTCAATGC 20
#
#
# 25_mcv5:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 15.0
# target            7 TTAGGGTCAATGC 20
#                   0 |||---||||||| 13
# query            10 TTA---TCAATGC 20
#
#
# 26_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 15.5
# target            5 TGCGTGACTACCTAC 20
#                   0 |||.|--.||||||| 15
# query             7 TGCCT--ATACCTAC 20
#
#
# 26_mcv2:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 12
#   Alignment score: 19.0
# target            1 GAGTTGCGTGACTACC-TAC 20
#                   0 ||..||-|.|||||||-||| 20
# query             1 GATATG-GCGACTACCGTAC 20
#
#
# 26_mcv3:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 13
#   Alignment score: 14.0
# target            0 CGAGTTGCGTGACTACCTAC 20
#                   0 |.|.||---||||-.||||| 20
# query             4 CAAATT---TGAC-GCCTAC 20
#
#
# 26_mcv4:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 17.0
# target            1 GAGTTGCGTGACTACCTAC 20
#                   0 ||.|||-|.|||...|||| 19
# query             2 GATTTG-GCGACGCTCTAC 20
#
#
# 26_mcv5:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 13
#   Alignment score: 11.5
# target            6 GCGTGA--CTACCTAC 20
#                   0 ||.|.|--|..||||| 16
# query             4 GCCTTATCCGTCCTAC 20
#
#
# 26_mcv6:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 18
#   Alignment score: 38.0
# target            0 CGAGTTGCGTGACTACCTA 19
#                   0 ||||||||||||||||||| 19
# query             1 CGAGTTGCGTGACTACCTA 20
#
#
# 27_mcv1:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 14
#   Alignment score: 12.5
# target            8 CGTATG--TGAA 18
#                   0 ||.|||--|||| 12
# query             7 CGGATGGATGAA 19
#
#
# 27_mcv2:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 11
#   Alignment score: 15.5
# target            4 ATGGCGTATGTGAATG 20
#                   0 ||||----||.||||| 16
# query             8 ATGG----TGGGAATG 20
#
#
# 28_mcv1:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 14
#   Alignment score: 9.5
# target           10 CGAAAC--TGGT 20
#                   0 |.||.|--|||| 12
# query             5 CAAATCCGTGGT 17
#
#
# 28_mcv2:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 14
#   Alignment score: 32.0
# target            0 GATGAACTGGCGAAAC 16
#                   0 |||||||||||||||| 16
# query             4 GATGAACTGGCGAAAC 20
#
#
# 28_mcv3:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 10
#   Alignment score: 13.0
# target            3 GAACTGGCGAAACTGGT 20
#                   0 |.||-||.|...||||| 17
# query             4 GTAC-GGTGCGTCTGGT 20
#
#
# 28_mcv4:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 11
#   Alignment score: 10.0
# target           15 CTGGT 20
#                   0 |||||  5
# query            15 CTGGT 20
#
#
# 28_mcv5:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 5
#   Alignment score: 25.5
# target            0 GATGAACTGGCGAAACTGGT 20
#                   0 ||.|--||||||||.||||| 20
# query             2 GACG--CTGGCGAAGCTGGT 20
#
#
# 28_mcv6:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 16
#   Alignment score: 10.0
# target            9 GCGAAACTGGT 20
#                   0 |.|..||||.| 11
# query             4 GTGCTACTGAT 15
#
#
# 28_mcv7:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 12
#   Alignment score: 12.5
# target            7 TGGCGAAACTGGT 20
#                   0 ||||----||||| 13
# query            11 TGGC----CTGGT 20
#
#
# 28_mcv8:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 12
#   Alignment score: 12.0
# target           14 ACTGGT 20
#                   0 ||||||  6
# query            14 ACTGGT 20
#
#
# 29_mcv1:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 12
#   Alignment score: 13.0
# target            0 GATTCTCGACAACGAAAGCA 20
#                   0 ||||.||-------.||||| 20
# query             7 GATTTTC-------TAAGCA 20
#
#
# 29_mcv2:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 9
#   Alignment score: 20.5
# target            1 ATTCTCGACAACGAAAGCA 20
#                   0 |||||.|-||--||||||| 19
# query             4 ATTCTTG-CA--GAAAGCA 20
#
#
# 29_mcv3:
#   Selection method: criteria
#   Critical position matches: 2/6
#   Mismatch count: 11
#   Alignment score: 10.0
# target            0 GATTCT-CGACAAC 13
#                   0 |.||.|-||.||.| 14
# query             5 GTTTATGCGCCAGC 19
#
#
# 29_mcv5:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 12
#   Alignment score: 16.0
# target            1 ATTCTCGACAACGAAAGCA 20
#                   0 ||.||||-----|.||||| 19
# query             6 ATACTCG-----GTAAGCA 20
#
#
# 30_mcv1:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 9
#   Alignment score: 17.5
# target            1 ATCAAAAACAATAATACCG 20
#                   0 |||.|...||--||||||| 19
# query             3 ATCCATTGCA--AATACCG 20
#
#
# 30_mcv2:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 11
#   Alignment score: 13.0
# target           12 TAATACCG 20
#                   0 ||||.|||  8
# query            12 TAATGCCG 20
#
#
# 30_mcv3:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 12
#   Alignment score: 13.0
# target           12 TAATACCG 20
#                   0 |||.||||  8
# query            12 TAACACCG 20
#
#
# 30_mcv4:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 7
#   Alignment score: 22.0
# target            3 CAAAAACAATAATACCG 20
#                   0 |.|..|.|||||||||| 17
# query             3 CCACCATAATAATACCG 20
#
#
# 30_mcv5:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 13
#   Alignment score: 10.0
# target           15 TACCG 20
#                   0 |||||  5
# query             0 TACCG  5
#
#
# 30_mcv6:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 14.0
# target           10 AATAATACCG 20
#                   0 |||-|||||| 10
# query            11 AAT-ATACCG 20
#
#
# 30_mcv7:
#   Selection method: criteria
#   Critical position matches: 3/6
#   Mismatch count: 12
#   Alignment score: 11.0
# target            8 ACAATAATAC 18
#                   0 |||.|.||.| 10
# query             1 ACAGTGATTC 11
#
#
# 30_mcv8:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 10
#   Alignment score: 12.0
# target            2 TCAAAAACAATAATACCG 20
#                   0 |.||...||.|.|..||| 18
# query             2 TGAACGCCAGTGACGCCG 20
#
#
# 31_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 12.0
# target           14 CCAGTG 20
#                   0 ||||||  6
# query            14 CCAGTG 20
#
#
# 31_mcv2:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 13
#   Alignment score: 12.0
# target           14 CCAGTG 20
#                   0 ||||||  6
# query            14 CCAGTG 20
#
#
# 31_mcv3:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 12
#   Alignment score: 13.0
# target            2 TTATCCCCTTATC-CAG 18
#                   0 |.|||.|..||.|-||| 17
# query             2 TAATCACAATACCGCAG 19
#
#
# 32_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 14
#   Alignment score: 11.5
# target            2 TGAACG--CCAGTGACGCCG 20
#                   0 ||.|.|--.|||---||||| 20
# query             3 TGCAAGGATCAG---CGCCG 20
#
#
# 32_mcv2:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 14
#   Alignment score: 10.0
# target           15 CGCCG 20
#                   0 |||||  5
# query            15 CGCCG 20
#
#
# 32_mcv3:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 13
#   Alignment score: 23.0
# target            3 GAACGCCAGTGA---CGCCG 20
#                   0 ||.|||||||.|---||||| 20
# query             0 GACCGCCAGTCAGTGCGCCG 20
#
#
# 32_mcv4:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 13
#   Alignment score: 11.0
# target            2 TGAACGCCAGTGACGCCG 20
#                   0 ||||.|-----|.|||.| 18
# query             7 TGAATG-----GGCGCAG 20
#
#
# 32_mcv5:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 12
#   Alignment score: 12.5
# target            0 GCTGAACGCCAG-TGACGCCG 20
#                   0 |.||--||.|.|-|.||.||| 21
# query             1 GATG--CGGCGGTTAACACCG 20
#
#
# 32_mcv6:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 10
#   Alignment score: 12.0
# target            2 TGAACGCCAGTGACGCCG 20
#                   0 |.||...||.|.|..||| 18
# query             2 TCAAAAACAATAATACCG 20
#
#
# 33_mcv1:
#   Selection method: criteria
#   Critical position matches: 3/6
#   Mismatch count: 15
#   Alignment score: 13.0
# target           10 AACTGAAC 18
#                   0 ||||||.|  8
# query             4 AACTGACC 12
#
#
# 33_mcv2:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 13
#   Alignment score: 10.5
# target           11 ACTGA--ACGG 20
#                   0 |||.|--|||| 11
# query             9 ACTCACTACGG 20
#
#
# 33_mcv3:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 14.5
# target            6 TGAAAACTGAACGG 20
#                   0 |||----||||||| 14
# query            10 TGA----TGAACGG 20
#
#
# 33_mcv4:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 8
#   Alignment score: 18.0
# target            3 CCCTG-AAAACTGAACGG 20
#                   0 |||.|-|...|||||||| 18
# query             2 CCCAGCAGTCCTGAACGG 20
#
#
# 33_mcv5:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 13
#   Alignment score: 11.5
# target            5 CTGAAA----ACTG-AACGG 20
#                   0 |.|.||----||.|-||||| 20
# query             0 CGGCAACATTACGGAAACGG 20
#
#
# 33_mcv6:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 14
#   Alignment score: 9.5
# target            4 CCTGAAAACTGA--ACGG 20
#                   0 ||.|.|...|||--|.|| 18
# query             1 CCCGTATCGTGATTATGG 19
#
#
# 33_mcv7:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 16.0
# target            7 GAAAACTG-------AACGG 20
#                   0 |||.||||-------||||| 20
# query             0 GAATACTGTGGTCGCAACGG 20
#
#
# 33_mcv8:
#   Selection method: criteria
#   Critical position matches: 3/6
#   Mismatch count: 13
#   Alignment score: 15.0
# target            0 TCTCCCTGAAAACTG 15
#                   0 ||.|.|||..|||.| 15
# query             5 TCCCGCTGGGAACGG 20
#
#
# 33_mcv9:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 16
#   Alignment score: 34.0
# target            0 TCTCCCTGAAAACTGAA 17
#                   0 ||||||||||||||||| 17
# query             3 TCTCCCTGAAAACTGAA 20
#
#
# 34_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 15
#   Alignment score: 15.0
# target           11 CGATCAACG 20
#                   0 |.|||||||  9
# query             8 CCATCAACG 17
#
#
# 34_mcv2:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 11
#   Alignment score: 18.5
# target            1 CGCCGC--CAGACGATCAACG 20
#                   0 |.|.||--|||-.|||||||| 21
# query             0 CCCTGCATCAG-GGATCAACG 20
#
#
# 34_mcv3:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 5
#   Alignment score: 27.0
# target            1 CGCCGCCAGACGATCAAC 19
#                   0 |||...|||||||||||| 18
# query             1 CGCATACAGACGATCAAC 19
#
#
# 34_mcv4:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 10
#   Alignment score: 21.5
# target            1 CGCCGCCAGACGATCAACG 20
#                   0 ||||||.|----||||||| 19
# query             5 CGCCGCTA----ATCAACG 20
#
#
# 34_mcv5:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 17.0
# target            6 CCAG---ACGATCAACG 20
#                   0 ||||---..|||||||| 17
# query             3 CCAGTGTCGGATCAACG 20
#
#
# 34_mcv6:
#   Selection method: criteria
#   Critical position matches: 3/6
#   Mismatch count: 12
#   Alignment score: 15.0
# target            7 CAGACGATCAAC 19
#                   0 |||.||||.|.| 12
# query             4 CAGCCGATGATC 16
#
#
# 34_mcv7:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 11
#   Alignment score: 12.0
# target           11 CGATCAACG 20
#                   0 |.|.|||||  9
# query            11 CCACCAACG 20
#
#
# 34_mcv8:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 10
#   Alignment score: 11.0
# target           13 ATCAACG 20
#                   0 |.|||||  7
# query            13 AACAACG 20
#
#
# 35_mcv1:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 9
#   Alignment score: 14.0
# target            1 ATCCTCGTTGATCGTCTGG 20
#                   0 ||...||.|....|||||| 19
# query             1 ATTGGCGCTTCGGGTCTGG 20
#
#
# 35_mcv10:
#   Selection method: criteria
#   Critical position matches: 3/6
#   Mismatch count: 13
#   Alignment score: 12.5
# target            3 CCTCGTTGATC-GTC 17
#                   0 |||--|||.||-||| 15
# query             2 CCT--TTGGTCAGTC 15
#
#
# 35_mcv11:
#   Selection method: criteria
#   Critical position matches: 9/6
#   Mismatch count: 8
#   Alignment score: 16.0
# target            0 GATCCTCGTTGATCGTCTGG 20
#                   0 |||.....|.|..||||||| 20
# query             0 GATGGAGCTGGGACGTCTGG 20
#
#
# 35_mcv12:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 12
#   Alignment score: 14.0
# target            4 CTCGTT--GATC--GTCTGG 20
#                   0 |.|.||--|.||--|||||| 20
# query             0 CGCATTACGCTCTGGTCTGG 20
#
#
# 35_mcv13:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 13
#   Alignment score: 14.0
# target            4 CTCGTTGATCGTCTGG 20
#                   0 |.||..|.|||-|||| 16
# query             5 CCCGCCGTTCG-CTGG 20
#
#
# 35_mcv2:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 11
#   Alignment score: 13.5
# target            6 CGTTGATCGTCTGG 20
#                   0 ||.||.||--|||| 14
# query             8 CGGTGGTC--CTGG 20
#
#
# 35_mcv3:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 13
#   Alignment score: 9.5
# target            8 TTGATCGTCTGG 20
#                   0 |||--||-|||| 12
# query            11 TTG--CG-CTGG 20
#
#
# 35_mcv4:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 14
#   Alignment score: 9.0
# target           13 CGTCTG 19
#                   0 |||.||  6
# query             5 CGTTTG 11
#
#
# 35_mcv5:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 14.0
# target           13 CGTCTGG 20
#                   0 |||||||  7
# query            13 CGTCTGG 20
#
#
# 35_mcv6:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 17
#   Alignment score: 28.0
# target            6 CGTTGATCGTCTGG 20
#                   0 |||||||||||||| 14
# query             0 CGTTGATCGTCTGG 14
#
#
# 35_mcv7:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 8
#   Alignment score: 20.0
# target            4 CTCGTTGATCGTCTGG 20
#                   0 ||...|.||||||||| 16
# query             4 CTGAGTAATCGTCTGG 20
#
#
# 35_mcv8:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 15.0
# target            8 TTGATCGTCTGG 20
#                   0 ||..|.|||||| 12
# query             8 TTACTGGTCTGG 20
#
#
# 35_mcv9:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 9
#   Alignment score: 14.0
# target           13 CGTCTGG 20
#                   0 |||||||  7
# query            13 CGTCTGG 20
#
#
# 36_mcv1:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 9
#   Alignment score: 19.0
# target            9 GCTGGCAGTTC 20
#                   0 ||||||||.|| 11
# query             9 GCTGGCAGGTC 20
#
#
# 36_mcv2:
#   Selection method: criteria
#   Critical position matches: 9/6
#   Mismatch count: 6
#   Alignment score: 22.0
# target            0 CCTGCGCCAGCTGGCAGTTC 20
#                   0 ||||.....||.|||||||| 20
# query             0 CCTGTTTTTGCAGGCAGTTC 20
#
#
# 36_mcv3:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 17
#   Alignment score: 11.0
# target            9 GCTGGCAGTT 19
#                   0 |.||.||.|| 10
# query             4 GATGTCATTT 14
#
#
# 36_mcv4:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 18
#   Alignment score: 11.0
# target           11 TGGCA-GTTC 20
#                   0 ||.||-|||| 10
# query             2 TGACATGTTC 12
#
#
# 36_mcv5:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 19.0
# target            9 GCTGGCAGTTC 20
# ...
#   Mismatch count: 10
#   Alignment score: 13.0
# target            9 TCCCGGTACCG 20
#                   0 ||...|||||| 11
# query             9 TCGTTGTACCG 20
#
#
# 115_mcv5:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 15
#   Alignment score: 11.0
# target           13 GGTACCG 20
#                   0 ||.||||  7
# query            10 GGCACCG 17
#
#
# 115_mcv6:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 16
#   Alignment score: 11.5
# target            6 CTATCCCGGT--ACCG 20
#                   0 ||...|.|||--|||| 16
# query             0 CTCGGCGGGTTAACCG 16
#
#
# 115_mcv7:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 8
#   Alignment score: 20.5
# target            0 AGAAGCCTATCCCGGTACCG 20
#                   0 |.||||----.||||||||| 20
# query             4 ACAAGC----ACCGGTACCG 20
#
#
# 115_mcv8:
#   Selection method: criteria
#   Critical position matches: 3/6
#   Mismatch count: 13
#   Alignment score: 9.5
# target            4 GCCTATCCCGGTACC 19
#                   0 ||.|.|--||..||| 15
# query             6 GCTTTT--CGACACC 19
#
#
# 115_mcv9:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 15
#   Alignment score: 8.0
# target           14 GTAC 18
#                   0 ||||  4
# query             6 GTAC 10
#
#
# 116_mcv1:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 10
#   Alignment score: 16.0
# target            0 ATGAGCCTCATCTTCTGGCA 20
#                   0 ||||-|...|.||||..||| 20
# query             1 ATGA-CGAGAACTTCCAGCA 20
#
#
# 116_mcv10:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 12
#   Alignment score: 23.0
# target            1 TGAGCCTCATCTTCTGGCA 20
#                   0 |||...||-|||||||||| 19
# query             1 TGATTATC-TCTTCTGGCA 19
#
#
# 116_mcv11:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 12
#   Alignment score: 13.0
# target            7 TCATCTTCT-GGCA 20
#                   0 |.||.||||-.||| 14
# query             6 TGATTTTCTAAGCA 20
#
#
# 116_mcv12:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 8
#   Alignment score: 16.0
# target            0 ATGAGCCTCATCTTCTGGCA 20
#                   0 |||.....|..|||||.||| 20
# query             0 ATGGTTAACTACTTCTTGCA 20
#
#
# 116_mcv13:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 9
#   Alignment score: 23.0
# target            1 TGAGCCTC-ATCTTCTGGC 19
#                   0 ||.|.|.|-|||||||||| 19
# query             0 TGCGACGCAATCTTCTGGC 19
#
#
# 116_mcv14:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 7
#   Alignment score: 20.0
# target            7 TCATCTTCTGGCA 20
#                   0 |||.|||||||.| 13
# query             7 TCACCTTCTGGTA 20
#
#
# 116_mcv15:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 8
#   Alignment score: 17.0
# target            1 TGAGCCTCATCTTCTGGCA 20
#                   0 ||..|.|..|||||..||| 19
# query             1 TGCACGTTCTCTTCCAGCA 20
#
#
# 116_mcv16:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 12.5
# target            1 TGAGCCTCATCTTC--TGGCA 20
#                   0 |.||-||.|-||||--.|||| 21
# query             1 TAAG-CTGA-CTTCCACGGCA 20
#
#
# 116_mcv17:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 15
#   Alignment score: 23.0
# target            2 GAGCCTCATCTTCTG-GCA 20
#                   0 |.||.|.||||||||-||| 19
# query             1 GGGCGTGATCTTCTGAGCA 20
#
#
# 116_mcv2:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 17
#   Alignment score: 15.0
# target            3 AGCCTCATCTTCTGG 18
#                   0 |.||..|-||||||| 15
# query             2 ACCCAGA-CTTCTGG 16
#
#
# 116_mcv3:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 10
#   Alignment score: 18.0
# target            8 CATCTTCTGGCA 20
#                   0 |.|||||.|||| 12
# query             8 CGTCTTCCGGCA 20
#
#
# 116_mcv4:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 17
#   Alignment score: 38.0
# target            1 TGAGCCTCATCTTCTGGCA 20
#                   0 ||||||||||||||||||| 19
# query             0 TGAGCCTCATCTTCTGGCA 19
#
#
# 116_mcv5:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 8
#   Alignment score: 20.5
# target            1 TGAGCCTCATCTTCTGGCA 20
#                   0 ||.|..|--|||||||||| 19
# query             3 TGGGGAT--TCTTCTGGCA 20
#
#
# 116_mcv6:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 12
#   Alignment score: 20.0
# target            1 TGAGCCTCATCTTCTGGCA 20
#                   0 ||.|.||-|.|.||||||| 19
# query             1 TGTGACT-AACATCTGGCA 19
#
#
# 116_mcv7:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 17
#   Alignment score: 24.0
# target            1 TGAGCCTCATCTTCTGGC 19
#                   0 |||.|..|.||||||||| 18
# query             0 TGATCAGCGTCTTCTGGC 18
#
#
# 116_mcv8:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 16.0
# target           12 TTCTGGCA 20
#                   0 ||||||||  8
# query            12 TTCTGGCA 20
#
#
# 116_mcv9:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 12
#   Alignment score: 10.0
# target           11 CTTCTGGC 19
#                   0 ||.|.|||  8
# query             2 CTGCGGGC 10
#
#
# 117_mcv1:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 10
#   Alignment score: 17.0
# target           10 CCCCTTGCAC 20
#                   0 ||||||||.| 10
# query            10 CCCCTTGCCC 20
#
#
# 117_mcv2:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 10
#   Alignment score: 10.0
# target            0 TACATAAGAGCCCCTTGCAC 20
#                   0 ||.|....|..|..||||.| 20
# query             0 TAAACCGCAATCTTTTGCTC 20
#
#
# 117_mcv3:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 6
#   Alignment score: 22.0
# target            0 TACATAAGAGCCCCTTGCAC 20
#                   0 |.||.||...||||||.||| 20
# query             0 TTCAGAATCACCCCTTTCAC 20
#
#
# 117_mcv4:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 7
#   Alignment score: 19.0
# target            0 TACATAAGAGCCCCTTGCAC 20
#                   0 |.||.||....|||||.||| 20
# query             0 TGCACAACTAACCCTTACAC 20
#
#
# 117_mcv5:
#   Selection method: criteria
#   Critical position matches: 1/6
#   Mismatch count: 15
#   Alignment score: 7.0
# target            2 CATAAGAGCCC 13
#                   0 |.|..||..|| 11
# query             3 CTTTTGATTCC 14
#
#
# 117_mcv6:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 8
#   Alignment score: 16.0
# target            3 ATAAGAGCCCCTTGCAC 20
#                   0 ||..|..||||||.|.| 17
# query             3 ATTTGTACCCCTTACCC 20
#
#
# 117_mcv7:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 11
#   Alignment score: 14.0
# target            7 GAGCCCCTTGCAC 20
#                   0 |.||..|.||||| 13
# query             7 GGGCATCCTGCAC 20
#
#
# 118_mcv1:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 14
#   Alignment score: 11.0
# target           13 TGCGAGA 20
#                   0 |||.|||  7
# query             0 TGCCAGA  7
#
#
# 119_mcv1:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 12
#   Alignment score: 10.0
# target           15 GACGG 20
#                   0 |||||  5
# query            15 GACGG 20
#
#
# 119_mcv10:
#   Selection method: criteria
#   Critical position matches: 9/6
#   Mismatch count: 10
#   Alignment score: 15.0
# target            0 GAGACAACAATTAACGACGG 20
#                   0 ||||.|.|-----.|||||| 20
# query             5 GAGAAAGC-----TCGACGG 20
#
#
# 119_mcv11:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 13.5
# target            5 AAC--AATTAACGACGG 20
#                   0 |||--||....|||||| 17
# query             3 AACCTAACAGGCGACGG 20
#
#
# 119_mcv12:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 13
#   Alignment score: 10.0
# target           15 GACGG 20
#                   0 |||||  5
# query            15 GACGG 20
#
#
# 119_mcv13:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 12
#   Alignment score: 13.0
# target            0 GAGACAACAATTAACGACGG 20
#                   0 ||||-||...||..|..||| 20
# query             1 GAGA-AATCTTTTTCCCCGG 20
#
#
# 119_mcv14:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 34.0
# target            0 GAGACAACAATTAACGA 17
#                   0 ||||||||||||||||| 17
# query             3 GAGACAACAATTAACGA 20
#
#
# 119_mcv15:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 15
#   Alignment score: 11.0
# target           13 ACGACGG 20
#                   0 |.|||||  7
# query             9 AGGACGG 16
#
#
# 119_mcv16:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 8
#   Alignment score: 18.0
# target            2 GACAACAATTAACGACGG 20
#                   0 |.||.|..||..|||||| 18
# query             2 GTCAGCCGTTGCCGACGG 20
#
#
# 119_mcv17:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 9
#   Alignment score: 16.0
# target            2 GACAAC----AATTAACGACGG 20
#                   0 ||||.|----||--||.||||| 22
# query             0 GACATCGCGGAA--AAAGACGG 20
#
#
# 119_mcv18:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 12
#   Alignment score: 12.0
# target            5 AACAATTAACGACGG 20
#                   0 ||...||...||||| 15
# query             2 AATGCTTCTGGACGG 17
#
#
# 119_mcv19:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 12
#   Alignment score: 13.0
# target            1 AGACAACAA-TTAACGACGG 20
#                   0 |||....||-.|..|||||| 20
# query             0 AGATTTGAACGTGCCGACGG 20
#
#
# 119_mcv2:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 12
#   Alignment score: 10.0
# target           11 TAAC-GAC 18
#                   0 ||||-|||  8
# query             3 TAACTGAC 11
#
#
# 119_mcv20:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 14.0
# target           10 TTAACGACGG 20
#                   0 ||..|||||| 10
# query            10 TTTGCGACGG 20
#
#
# 119_mcv21:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 13
#   Alignment score: 11.0
# target            5 AACAATTAAC-GACGG 20
#                   0 |.|||.|..|-.|||| 16
# query             4 ATCAAATGCCATACGG 20
#
#
# 119_mcv22:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 8
#   Alignment score: 18.0
# target            5 AACAATTAACGACGG 20
#                   0 ||...||||||||.| 15
# query             5 AAAGGTTAACGACAG 20
#
#
# 119_mcv23:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 10
#   Alignment score: 15.0
# target           11 TAACGACGG 20
#                   0 ||.||||||  9
# query            11 TAGCGACGG 20
#
#
# 119_mcv3:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 9
#   Alignment score: 13.5
# target            2 GACAACAATTAACGACGG 20
#                   0 ||.|.|.||----||||| 18
# query             6 GAAAGCGAT----GACGG 20
#
#
# 119_mcv4:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 12
#   Alignment score: 12.0
# target            9 ATTAAC-------GACGG 20
#                   0 |||.||-------||||| 18
# query             2 ATTCACTTCCGCTGACGG 20
#
#
# 119_mcv5:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 11.0
# target            3 ACAACAAT-TAAC-GACGG 20
#                   0 |.|.|.||-|..|-||||| 19
# query             1 AGATCGATGTGGCTGACGG 20
#
#
# 119_mcv6:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 8
#   Alignment score: 17.0
# target            1 AGACAACAATTAACGACGG 20
#                   0 |||...|.|.|.||.|||| 19
# query             1 AGAGCGCCACTCACTACGG 20
#
#
# 119_mcv7:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 12
#   Alignment score: 10.0
# target           15 GACGG 20
#                   0 |||||  5
# query            15 GACGG 20
#
#
# 119_mcv8:
#   Selection method: criteria
#   Critical position matches: 8/6
#   Mismatch count: 10
#   Alignment score: 25.0
# target            0 GAGACAACAATTAACGACGG 20
#                   0 |.|||||||.||-.|||||| 20
# query             1 GCGACAACAGTT-GCGACGG 20
#
#
# 119_mcv9:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 14
#   Alignment score: 7.5
# target           10 TTAA--CGA---CGG 20
#                   0 ||.|--|||---||| 15
# query             2 TTGATGCGAAAGCGG 17
#
#
# 120_mcv1:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 17.0
# target            3 CCCGTTAACGATG---CATA 20
#                   0 ||||.|...||||---|||| 20
# query             0 CCCGGTGGTGATGGCACATA 20
#
#
# 120_mcv10:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 12
#   Alignment score: 21.0
# target            5 CGTTAACG-----ATGCATA 20
#                   0 |||.||||-----||||||| 20
# query             0 CGTAAACGATATTATGCATA 20
#
#
# 120_mcv11:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 11
#   Alignment score: 18.0
# target           11 CGATGCATA 20
#                   0 |||||||||  9
# query            11 CGATGCATA 20
#
#
# 120_mcv12:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 8
#   Alignment score: 17.0
# target            1 ACCCCGTTAACGATGCATA 20
#                   0 |.|..|||...|.|||||| 19
# query             1 AACGTGTTCCAGTTGCATA 20
#
#
# 120_mcv2:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 13
#   Alignment score: 10.0
# target            7 TTAACGA-TGCATA 20
#                   0 |||..||-|..||| 14
# query             4 TTATTGACTTAATA 18
#
#
# 120_mcv3:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 16
#   Alignment score: 10.0
# target            0 AACCCCGTTAACGATG 16
#                   0 ||||-----|||..|| 16
# query             8 AACC-----AACATTG 19
#
#
# 120_mcv4:
#   Selection method: criteria
#   Critical position matches: 5/6
#   Mismatch count: 11
#   Alignment score: 11.5
# target            1 ACCCCGTTAACGATGCATA 20
#                   0 |.|.||.|--|.|..|||| 19
# query             3 ATCACGCT--CTAGACATA 20
#
#
# 120_mcv5:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 16
#   Alignment score: 13.0
# target            3 CCCGTTAACGATGCATA 20
#                   0 |.|..|||..||.||.| 17
# query             1 CGCTATAAATATTCACA 18
#
#
# 120_mcv6:
#   Selection method: criteria
#   Critical position matches: 6/6
#   Mismatch count: 12
#   Alignment score: 11.0
# target            0 AACCCCGTTAACGATGCATA 20
#                   0 |.|.||---|.|.|||..|| 20
# query             1 ATCACC---AGCAATGGCTA 18
#
#
# 120_mcv7:
#   Selection method: criteria
#   Critical position matches: 7/6
#   Mismatch count: 13
#   Alignment score: 14.0
# target            0 AACCCCGTTAACGATGCATA 20
#                   0 ||.|.|.||---|..||||| 20
# query             3 AAACACTTT---GCCGCATA 20
#
#
# 120_mcv8:
#   Selection method: criteria
#   Critical position matches: 4/6
#   Mismatch count: 13
#   Alignment score: 8.0
# target            4 CCGTTAACGATGCATA 20
#                   0 |.|||....|-|||.| 16
# query             3 CAGTTGGTCA-GCACA 18
#
#
# 120_mcv9:
#   Selection method: criteria
#   Critical position matches: 0/6
#   Mismatch count: 13
#   Alignment score: 6.0
# target            6 GTT  9
#                   0 |||  3
# query             7 GTT 10
#
#
# ====================================================================================================
# ✓ Saved selected guides to: /Users/ecreed/Desktop/KelloggRotation/02052026_TagmentatioAnalysis_251218_260117_260203_combined/FilteredCandidateSpacersBulk/02132026_Selected_Ideal_Guides.csv
#   Total guides selected: 1105
#   Total hotspots across all samples: 1115
#
# Selection method summary:
# selection_method
# criteria    1105
# Name: count, dtype: int64

# %%
# v2 table copy and paste + cell to identify strong off-target preference
# use previous on-target calculation
# divide genome into 200 bp windows, count integrations in each window, return windows sorted by highest integration count
# once windows are counted, filter out on target, want to hit strong off target hotspots with new guides
# off-target preference is calc by finding off target percent 
    # (integrations in best off target window / total integrations) * 100 = off target percent
# (off target percent) - (on target percent) = off-target preference
    # positive value == guide integrates more off-target than on-ltarget


# Identify samples with high off-target preference
# Adapted from on-target calculation method (cell 8)
# Analyze windows with high integrations and identify off-target preference

import re
from pathlib import Path

window_bp = 200
on_target_window = window_bp

def percent_within_distance(insertions, target_position, window_bp):
    """Calculate percentage of insertions within window_bp distance"""
    if len(insertions) == 0:
        return 0.0
    
    count_within = sum(
        abs(pos - target_position) <= window_bp
        for pos in insertions
    )
    
    return 100.0 * count_within / len(insertions)

def find_high_integration_windows(insertions, window_size=200, min_window_count=50):
    """
    Find windows with high integration counts.
    Returns list of (window_center, count) tuples sorted by count descending
    """
    from collections import defaultdict
    
    if not insertions:
        return []
    
    # Create windows and count integrations
    window_counts = defaultdict(int)
    
    for pos in insertions:
        # Round to nearest window boundary
        window_center = (pos // window_size) * window_size + window_size // 2
        window_counts[window_center] += 1
    
    # Filter windows by minimum count and sort
    high_windows = [(center, count) for center, count in window_counts.items() 
                    if count >= min_window_count]
    high_windows.sort(key=lambda x: x[1], reverse=True)
    
    return high_windows

def _sample_id_from_name(p: Path):
    """Extract sample ID from filename"""
    m = re.match(r"(\d+)_S\1_", p.name)
    return int(m.group(1)) if m else None

# Analyze each sample for off-target preferences
off_target_results = []

for nn, tsv_path in enumerate(tsv_files):
    sample_id = _sample_id_from_name(tsv_path) or (nn + 1)
    
    # Load and filter TSV
    tsv = pd.read_csv(tsv_path, sep="\t")
    tsv = tsv[tsv["mapq"] >= min_mapq]
    
    if len(tsv) == 0:
        continue
    
    insertions = tsv["ins0"].values.tolist()
    total_insertions = len(insertions)
    
    # Get target position for this sample
    try:
        gmap = php.map_guide_to_genome(guideRNA["protospacer"][nn], genome_sequence)
        target_position = gmap[0]["start"]
    except:
        continue
    
    # Calculate on-target percentage
    on_target_percent = percent_within_distance(insertions, target_position, on_target_window)
    on_target_count = sum(abs(pos - target_position) <= on_target_window for pos in insertions)
    
    # Find all high integration windows (off-target and on-target)
    all_windows = find_high_integration_windows(insertions, window_size=200, min_window_count=30)
    
    # Filter to only off-target windows (outside on-target window)
    off_target_windows = []
    for window_center, count in all_windows:
        if abs(window_center - target_position) > on_target_window:
            off_target_windows.append((window_center, count))
    
    # Calculate off-target preference
    if off_target_windows:
        # Get best (highest count) off-target window
        best_off_target_window = off_target_windows[0]
        best_off_target_count = best_off_target_window[1]
        off_target_percent = 100.0 * best_off_target_count / total_insertions
    else:
        best_off_target_window = (None, 0)
        best_off_target_count = 0
        off_target_percent = 0.0
    
    # Get sample name
    sample_name = Path(tsv_path).stem
    
    off_target_results.append({
        'sample_id': sample_id,
        'sample_name': sample_name,
        'total_insertions': total_insertions,
        'on_target_count': on_target_count,
        'on_target_percent': on_target_percent,
        'best_off_target_window': best_off_target_window[0],
        'best_off_target_count': best_off_target_count,
        'off_target_percent': off_target_percent,
        'off_target_preference': off_target_percent - on_target_percent,
        'num_high_off_target_windows': len(off_target_windows)
    })

# Create DataFrame and sort by off-target preference (highest to lowest)
df_off_target = pd.DataFrame(off_target_results)
df_off_target = df_off_target.sort_values('off_target_preference', ascending=False).reset_index(drop=True)
df_off_target['rank'] = df_off_target.index + 1
'''
# Display results sorted by highest off-target preference
print("=" * 120)
print("SAMPLES RANKED BY OFF-TARGET PREFERENCE (Highest to Lowest)")
print("=" * 120)
print(df_off_target[['rank', 'sample_id', 'sample_name', 'on_target_percent', 
                     'off_target_percent', 'off_target_preference', 
                     'best_off_target_window', 'num_high_off_target_windows']].to_string(index=False))
print("\n" + "=" * 120)
print(f"Total samples analyzed: {len(df_off_target)}")
print(f"Samples with off-target preference > 0%: {(df_off_target['off_target_preference'] > 0).sum()}")
'''
# Create a clean table for PowerPoint (tab-separated for easy copy-paste)
print("\n\n" + "=" * 120)
print("COPY-PASTE READY TABLE FOR POWERPOINT")
print("=" * 120)
print("(Select the table below and copy directly into PowerPoint)\n")

# Create a simplified table with key columns
ppt_df = df_off_target[['rank', 'sample_id', 'sample_name', 'total_insertions', 
                         'on_target_percent', 'off_target_percent', 
                         'off_target_preference', 'num_high_off_target_windows']].copy()

# Round percentages for cleaner display
ppt_df['on_target_percent'] = ppt_df['on_target_percent'].round(1)
ppt_df['off_target_percent'] = ppt_df['off_target_percent'].round(1)
ppt_df['off_target_preference'] = ppt_df['off_target_preference'].round(1)

# Rename columns for PowerPoint
ppt_df.columns = ['Rank', 'Sample ID', 'Sample Name', 'Total Insertions', 
                  'On-Target %', 'Off-Target %', 'Off-Target Preference', '# Off-Target Windows']

# Display as tab-separated (easy to paste into PowerPoint)
print(ppt_df.to_csv(sep='\t', index=False))

print("\nInstructions:")
print("1. Select and copy the table above")
print("2. In PowerPoint, go to Insert → Table → Insert Table from Text")
print("3. Or paste into Excel first, then copy to PowerPoint")
# Out:
# ========================================================================================================================
# COPY-PASTE READY TABLE FOR POWERPOINT
# ========================================================================================================================
# (Select the table below and copy directly into PowerPoint)
#
# Rank	Sample ID	Sample Name	Total Insertions	On-Target %	Off-Target %	Off-Target Preference	# Off-Target Windows
# 1	70	70_S70_L001_R1_001.insertions.5p	35846	0.0	82.1	82.1	27
# 2	31	31_S31_L001_R1_001.insertions.5p	20451	0.1	76.3	76.2	20
# 3	108	108_S108_L001_R1_001.insertions.5p	34742	0.7	75.4	74.6	42
# 4	56	56_S56_L001_R1_001.insertions.5p	39353	2.0	75.3	73.3	27
# 5	87	87_S87_L001_R1_001.insertions.5p	33973	0.1	69.3	69.1	45
# 6	98	98_S98_L001_R1_001.insertions.5p	48434	0.4	69.1	68.7	58
# 7	93	93_S93_L001_R1_001.insertions.5p	39997	0.7	62.8	62.1	36
# 8	23	23_S23_L001_R1_001.insertions.5p	18301	0.7	61.1	60.4	19
# 9	1	1_S1_L001_R1_001.insertions.5p	16822	0.2	58.9	58.6	29
# 10	36	36_S36_L001_R1_001.insertions.5p	30031	0.1	57.1	57.0	33
# 11	39	39_S39_L001_R1_001.insertions.5p	19826	0.0	55.4	55.4	49
# 12	68	68_S68_L001_R1_001.insertions.5p	42226	0.0	53.0	53.0	39
# 13	102	102_S102_L001_R1_001.insertions.5p	44853	1.6	54.3	52.7	50
# 14	12	12_S12_L001_R1_001.insertions.5p	44865	4.2	55.0	50.9	64
# 15	32	32_S32_L001_R1_001.insertions.5p	19033	0.0	45.2	45.2	33
# 16	86	86_S86_L001_R1_001.insertions.5p	58015	0.2	45.3	45.1	122
# 17	99	99_S99_L001_R1_001.insertions.5p	46287	7.1	51.7	44.6	31
# 18	111	111_S111_L001_R1_001.insertions.5p	37605	0.3	42.8	42.5	37
# 19	59	59_S59_L001_R1_001.insertions.5p	45245	0.3	41.6	41.4	47
# 20	65	65_S65_L001_R1_001.insertions.5p	52709	0.0	41.1	41.1	47
# 21	115	115_S115_L001_R1_001.insertions.5p	44911	0.0	40.6	40.6	50
# 22	6	6_S6_L001_R1_001.insertions.5p	28571	0.5	40.4	39.9	96
# 23	4	4_S4_L001_R1_001.insertions.5p	16112	0.2	38.9	38.7	51
# 24	100	100_S100_L001_R1_001.insertions.5p	47416	0.0	37.4	37.4	50
# 25	67	67_S67_L001_R1_001.insertions.5p	50820	0.0	37.1	37.1	56
# 26	90	90_S90_L001_R1_001.insertions.5p	43187	0.0	36.6	36.6	51
# 27	43	43_S43_L001_R1_001.insertions.5p	35381	2.6	38.6	36.0	76
# 28	103	103_S103_L001_R1_001.insertions.5p	43438	1.7	35.5	33.8	45
# 29	17	17_S17_L001_R1_001.insertions.5p	24152	0.9	34.4	33.5	125
# 30	11	11_S11_L001_R1_001.insertions.5p	3203	0.1	33.0	32.9	15
# 31	73	73_S73_L001_R1_001.insertions.5p	47844	0.0	32.7	32.7	69
# 32	14	14_S14_L001_R1_001.insertions.5p	9754	3.1	35.5	32.5	24
# 33	71	71_S71_L001_R1_001.insertions.5p	47478	0.0	31.2	31.2	82
# 34	117	117_S117_L001_R1_001.insertions.5p	46216	5.7	36.8	31.1	29
# 35	85	85_S85_L001_R1_001.insertions.5p	30997	0.8	31.8	31.0	49
# 36	109	109_S109_L001_R1_001.insertions.5p	45479	0.4	31.0	30.7	61
# 37	29	29_S29_L001_R1_001.insertions.5p	17250	5.0	35.2	30.2	30
# 38	24	24_S24_L001_R1_001.insertions.5p	13551	0.0	30.1	30.1	29
# 39	82	82_S82_L001_R1_001.insertions.5p	49366	0.5	30.6	30.1	52
# 40	26	26_S26_L001_R1_001.insertions.5p	15802	2.8	32.1	29.3	39
# 41	3	3_S3_L001_R1_001.insertions.5p	17237	1.6	30.1	28.5	35
# 42	83	83_S83_L001_R1_001.insertions.5p	45166	0.7	29.1	28.4	79
# 43	112	112_S112_L001_R1_001.insertions.5p	38946	0.0	27.4	27.3	74
# 44	49	49_S49_L001_R1_001.insertions.5p	47179	0.1	26.8	26.7	55
# 45	20	20_S20_L001_R1_001.insertions.5p	21484	3.9	30.1	26.2	46
# 46	81	81_S81_L001_R1_001.insertions.5p	38933	3.5	28.7	25.2	73
# 47	105	105_S105_L001_R1_001.insertions.5p	40341	3.3	27.8	24.4	63
# 48	19	19_S19_L001_R1_001.insertions.5p	25677	0.5	24.3	23.7	44
# 49	95	95_S95_L001_R1_001.insertions.5p	38135	0.0	23.3	23.3	94
# 50	37	37_S37_L001_R1_001.insertions.5p	46353	1.2	24.3	23.1	152
# 51	60	60_S60_L001_R1_001.insertions.5p	54261	0.2	22.8	22.7	116
# 52	72	72_S72_L001_R1_001.insertions.5p	51915	0.0	22.4	22.4	79
# 53	88	88_S88_L001_R1_001.insertions.5p	33309	4.6	26.8	22.1	65
# 54	89	89_S89_L001_R1_001.insertions.5p	36727	8.8	30.8	22.0	47
# 55	53	53_S53_L001_R1_001.insertions.5p	49928	2.6	24.5	21.9	85
# 56	40	40_S40_L001_R1_001.insertions.5p	19192	0.9	22.7	21.8	45
# 57	74	74_S74_L001_R1_001.insertions.5p	46152	0.1	21.6	21.6	80
# 58	64	64_S64_L001_R1_001.insertions.5p	44579	0.0	21.4	21.4	90
# 59	18	18_S18_L001_R1_001.insertions.5p	17760	0.2	20.3	20.1	37
# 60	113	113_S113_L001_R1_001.insertions.5p	51805	4.5	24.1	19.6	96
# 61	94	94_S94_L001_R1_001.insertions.5p	38822	0.8	20.4	19.6	67
# 62	5	5_S5_L001_R1_001.insertions.5p	11903	0.0	19.6	19.6	44
# 63	63	63_S63_L001_R1_001.insertions.5p	46941	0.0	19.3	19.3	117
# 64	120	120_S120_L001_R1_001.insertions.5p	45224	1.6	20.5	19.0	126
# 65	66	66_S66_L001_R1_001.insertions.5p	51521	0.0	18.7	18.7	93
# 66	110	110_S110_L001_R1_001.insertions.5p	41976	2.6	21.1	18.6	87
# 67	21	21_S21_L001_R1_001.insertions.5p	27740	0.1	18.6	18.5	83
# 68	15	15_S15_L001_R1_001.insertions.5p	15171	0.5	18.9	18.3	26
# 69	69	69_S69_L001_R1_001.insertions.5p	39713	0.0	18.3	18.3	72
# 70	75	75_S75_L001_R1_001.insertions.5p	48839	0.0	18.1	18.1	70
# 71	42	42_S42_L001_R1_001.insertions.5p	42464	2.6	20.7	18.1	66
# 72	33	33_S33_L001_R1_001.insertions.5p	17077	0.3	17.8	17.6	46
# 73	34	34_S34_L001_R1_001.insertions.5p	42677	3.2	20.7	17.6	194
# 74	16	16_S16_L001_R1_001.insertions.5p	9623	1.5	18.9	17.5	24
# 75	44	44_S44_L001_R1_001.insertions.5p	39217	0.0	17.1	17.1	87
# 76	2	2_S2_L001_R1_001.insertions.5p	18510	12.6	29.7	17.1	61
# 77	30	30_S30_L001_R1_001.insertions.5p	19713	0.1	16.9	16.8	49
# 78	51	51_S51_L001_R1_001.insertions.5p	55153	1.8	17.8	16.0	81
# 79	9	9_S9_L001_R1_001.insertions.5p	14088	0.7	15.8	15.1	55
# 80	91	91_S91_L001_R1_001.insertions.5p	44251	12.1	25.8	13.7	48
# 81	38	38_S38_L001_R1_001.insertions.5p	19287	0.1	13.3	13.2	71
# 82	48	48_S48_L001_R1_001.insertions.5p	102272	0.9	13.9	13.1	374
# 83	22	22_S22_L001_R1_001.insertions.5p	31303	0.0	12.6	12.6	104
# 84	84	84_S84_L001_R1_001.insertions.5p	39095	0.3	12.5	12.2	109
# 85	104	104_S104_L001_R1_001.insertions.5p	47441	0.2	11.6	11.4	109
# 86	52	52_S52_L001_R1_001.insertions.5p	45318	0.0	11.1	11.1	77
# 87	106	106_S106_L001_R1_001.insertions.5p	41291	0.6	11.4	10.7	89
# 88	57	57_S57_L001_R1_001.insertions.5p	56223	3.7	14.4	10.7	104
# 89	119	119_S119_L001_R1_001.insertions.5p	49959	2.3	12.6	10.3	89
# 90	35	35_S35_L001_R1_001.insertions.5p	37162	5.1	15.4	10.3	79
# 91	55	55_S55_L001_R1_001.insertions.5p	52965	0.0	9.6	9.6	121
# 92	96	96_S96_L001_R1_001.insertions.5p	41747	6.5	16.0	9.5	108
# 93	58	58_S58_L001_R1_001.insertions.5p	63079	19.9	29.3	9.4	77
# 94	62	62_S62_L001_R1_001.insertions.5p	56283	13.1	22.5	9.4	71
# 95	47	47_S47_L001_R1_001.insertions.5p	42931	12.0	20.4	8.5	67
# 96	116	116_S116_L001_R1_001.insertions.5p	46414	7.2	15.5	8.4	98
# 97	114	114_S114_L001_R1_001.insertions.5p	38190	2.3	10.1	7.9	64
# 98	10	10_S10_L001_R1_001.insertions.5p	17571	0.1	7.3	7.2	80
# 99	61	61_S61_L001_R1_001.insertions.5p	48421	9.3	16.3	7.0	125
# 100	50	50_S50_L001_R1_001.insertions.5p	44361	0.0	5.0	5.0	188
# 101	28	28_S28_L001_R1_001.insertions.5p	29582	17.1	21.7	4.6	53
# 102	8	8_S8_L001_R1_001.insertions.5p	13970	20.6	25.2	4.5	39
# 103	7	7_S7_L001_R1_001.insertions.5p	10278	11.6	12.2	0.6	32
# 104	79	79_S79_L001_R1_001.insertions.5p	58148	24.6	24.3	-0.4	62
# 105	107	107_S107_L001_R1_001.insertions.5p	40003	16.5	16.0	-0.5	75
# 106	54	54_S54_L001_R1_001.insertions.5p	48144	29.0	27.3	-1.7	53
# 107	46	46_S46_L001_R1_001.insertions.5p	46050	39.8	32.5	-7.2	32
# 108	77	77_S77_L001_R1_001.insertions.5p	50168	23.2	14.3	-8.9	88
# 109	101	101_S101_L001_R1_001.insertions.5p	30236	46.5	35.6	-10.9	24
# 110	41	41_S41_L001_R1_001.insertions.5p	36788	31.8	17.3	-14.6	31
# 111	97	97_S97_L001_R1_001.insertions.5p	42765	37.6	23.0	-14.6	43
# 112	25	25_S25_L001_R1_001.insertions.5p	17335	36.1	21.5	-14.6	26
# 113	78	78_S78_L001_R1_001.insertions.5p	58700	52.0	14.1	-38.0	52
# 114	76	76_S76_L001_R1_001.insertions.5p	47868	44.4	4.9	-39.5	78
# 115	80	80_S80_L001_R1_001.insertions.5p	49183	57.1	12.3	-44.9	36
# 116	45	45_S45_L001_R1_001.insertions.5p	43585	61.4	15.4	-46.0	52
# 117	13	13_S13_L001_R1_001.insertions.5p	30174	75.8	19.9	-55.9	3
# 118	27	27_S27_L001_R1_001.insertions.5p	38668	92.2	2.5	-89.7	17
# 119	118	118_S118_L001_R1_001.insertions.5p	33969	91.5	1.1	-90.4	13
# 120	92	92_S92_L001_R1_001.insertions.5p	39438	92.4	0.7	-91.7	27
#
#
# Instructions:
# 1. Select and copy the table above
# 2. In PowerPoint, go to Insert → Table → Insert Table from Text
# 3. Or paste into Excel first, then copy to PowerPoint

# %%
# v2 zoomed in analysis of on vs off target windows
# Visualize on-target and off-target windows for a specific sample
# Set the sample you want to analyze
nn = 92  # Change this to your sample of interest

import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Load sample data
tsv = pd.read_csv(tsv_files[nn], sep="\t")
tsv = tsv[tsv["mapq"] >= min_mapq]
insertions = tsv["ins0"].values.tolist()

# Get target position
gmap = php.map_guide_to_genome(guideRNA["protospacer"][nn], genome_sequence)
target_position = gmap[0]["start"]
guide_length = 20

# Find off-target windows
all_windows = find_high_integration_windows(insertions, window_size=200, min_window_count=30)
off_target_windows = [(center, count) for center, count in all_windows 
                      if abs(center - target_position) > 200]

# Get best off-target window
if off_target_windows:
    best_off_target_pos, best_off_target_count = off_target_windows[0]
else:
    best_off_target_pos, best_off_target_count = None, 0

# Calculate stats
on_target_count = sum(abs(pos - target_position) <= 200 for pos in insertions)
on_target_percent = 100.0 * on_target_count / len(insertions) if insertions else 0
off_target_percent = 100.0 * best_off_target_count / len(insertions) if insertions and best_off_target_pos else 0

# Create visualization
if best_off_target_pos:
    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(14, 10))
else:
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 7))

# Plot 1: Full genome view (UNCHANGED)
ax1.hist(insertions, bins=100, alpha=0.7, color='gray', edgecolor='black')
ax1.axvline(target_position, color='red', linewidth=3, label=f'Guide Target (pos {target_position})', linestyle='--')
ax1.axvspan(target_position - 200, target_position + 200, alpha=0.2, color='green', 
            label=f'On-Target Window (±200bp)')

if best_off_target_pos:
    ax1.axvline(best_off_target_pos, color='orange', linewidth=3, 
                label=f'Best Off-Target (pos {best_off_target_pos})', linestyle='--')
    ax1.axvspan(best_off_target_pos - 100, best_off_target_pos + 100, alpha=0.2, color='orange',
                label=f'Off-Target Window')

ax1.set_xlabel("Genomic Position (bp)", fontsize=12)
ax1.set_ylabel("Insertion Count", fontsize=12)
ax1.set_title(f"Sample {nn+1}: Genome-wide Integration Profile\nOn-Target: {on_target_percent:.1f}%  |  Off-Target: {off_target_percent:.1f}%", 
              fontsize=14, fontweight='bold')
ax1.legend(loc='upper right', fontsize=10)
ax1.grid(True, alpha=0.3)

# Plot 2: On-target zoom (on separate line)
on_target_insertions = [pos for pos in insertions if target_position - 400 <= pos <= target_position + 400]
ax2.hist(on_target_insertions, bins=50, alpha=0.7, color='green', edgecolor='black')
ax2.axvline(target_position, color='red', linewidth=2, linestyle='--')
ax2.axvspan(target_position - 200, target_position + 200, alpha=0.2, color='green')
ax2.axvspan(target_position, target_position + guide_length, alpha=0.3, color='blue',
            label='Guide Binding (20bp)')

ax2.set_xlabel("Genomic Position (bp)", fontsize=10)
ax2.set_ylabel("Insertion Count", fontsize=10)
ax2.set_title(f"On-Target Window\n{on_target_count} insertions ({on_target_percent:.1f}%)", 
              fontsize=11, fontweight='bold')
ax2.legend(fontsize=8)
ax2.grid(True, alpha=0.3)

# Plot 3: Off-target zoom (on separate line)
if best_off_target_pos:
    off_target_insertions = [pos for pos in insertions 
                            if best_off_target_pos - 400 <= pos <= best_off_target_pos + 400]
    ax3.hist(off_target_insertions, bins=50, alpha=0.7, color='orange', edgecolor='black')
    ax3.axvline(best_off_target_pos, color='orange', linewidth=2, linestyle='--')
    ax3.axvspan(best_off_target_pos - 100, best_off_target_pos + 100, alpha=0.2, color='orange')
    ax3.set_xlabel("Genomic Position (bp)", fontsize=10)
    ax3.set_ylabel("Insertion Count", fontsize=10)
    ax3.set_title(f"Best Off-Target Window\n{best_off_target_count} insertions ({off_target_percent:.1f}%)", 
                  fontsize=11, fontweight='bold')
    ax3.grid(True, alpha=0.3)
    
    # Match y-axis scales between on-target and off-target
    max_y = max(ax2.get_ylim()[1], ax3.get_ylim()[1])
    ax2.set_ylim(0, max_y)
    ax3.set_ylim(0, max_y)

plt.tight_layout()
plt.show()

# Print detailed stats
print("\n" + "=" * 80)
print(f"SAMPLE {nn+1} ANALYSIS")
print("=" * 80)
print(f"Sample Name: {Path(tsv_files[nn]).stem}")
print(f"Total Insertions: {len(insertions):,}")
print(f"\nGuide Target Position: {target_position:,} bp")
print(f"Guide Binding Region: {target_position:,} - {target_position + guide_length:,} bp")
print(f"\nOn-Target Window: {target_position - 200:,} - {target_position + 200:,} bp (±200bp)")
print(f"  Insertions: {on_target_count:,} ({on_target_percent:.1f}%)")
if best_off_target_pos:
    distance = abs(best_off_target_pos - target_position)
    print(f"\nBest Off-Target Window: {best_off_target_pos - 100:,} - {best_off_target_pos + 100:,} bp")
    print(f"  Center Position: {best_off_target_pos:,} bp")
    print(f"  Distance from Target: {distance:,} bp")
    print(f"  Insertions: {best_off_target_count:,} ({off_target_percent:.1f}%)")
    print(f"\nOff-Target Preference: {off_target_percent - on_target_percent:+.1f}%")
else:
    print("\nNo significant off-target windows found (≥30 integrations)")
print("=" * 80)
# Out:
# ================================================================================
# SAMPLE 93 ANALYSIS
# ================================================================================
# Sample Name: 93_S93_L001_R1_001.insertions.5p
# Total Insertions: 39,997
#
# Guide Target Position: 882,545 bp
# Guide Binding Region: 882,545 - 882,565 bp
#
# On-Target Window: 882,345 - 882,745 bp (±200bp)
#   Insertions: 287 (0.7%)
#
# Best Off-Target Window: 863,800 - 864,000 bp
#   Center Position: 863,900 bp
#   Distance from Target: 18,645 bp
#   Insertions: 25,129 (62.8%)
#
# Off-Target Preference: +62.1%
# ================================================================================

# %%
# Check if selected ideal guides bind in best off-target windows
# For samples with strong off-target preference, find guide binding positions in off-target regions
# Uses Selected_Ideal_Guides.csv

import pandas as pd
from pathlib import Path

# Load the selected ideal guides CSV
selected_guides_csv = output_csv_dir / "02132026_Selected_Ideal_Guides.csv"

if not selected_guides_csv.exists():
    print(f"ERROR: {selected_guides_csv} not found")
else:
    df_selected = pd.read_csv(selected_guides_csv)
    
    # Extract sample_id from hotspot column (format: "sample_id_mcvN")
    df_selected['sample_id'] = df_selected['hotspot'].str.split('_').str[0].astype(int)
    
    # Get samples with strong off-target preference (top 10)
    top_off_target_samples = df_off_target.head(10)
    
    off_target_binding_results = []
    
    print("=" * 140)
    print("CHECKING IF SELECTED IDEAL GUIDES BIND IN BEST OFF-TARGET WINDOWS")
    print("=" * 140)
    
    for idx, off_target_row in top_off_target_samples.iterrows():
        sample_id = off_target_row['sample_id']
        nn = sample_id - 1
        
        print(f"\nSample {sample_id}: {off_target_row['sample_name']}")
        print(f"  Off-target preference: {off_target_row['off_target_preference']:.1f}%")
        print(f"  Best off-target window position: {off_target_row['best_off_target_window']:,}")
        print(f"  Best off-target window integrations: {off_target_row['best_off_target_count']}")
        
        # Get selected guides for this sample from CSV
        sample_guides = df_selected[df_selected['sample_id'] == sample_id]
        
        if sample_guides.empty:
            print(f"  No selected guides found for this sample")
            continue
        
        # Get insertion data for this sample
        tsv = pd.read_csv(tsv_files[nn], sep="\t")
        tsv = tsv[tsv["mapq"] >= min_mapq]
        insertions = tsv["ins0"].values.tolist()

        # Get insertion data for this sample
        tsv = pd.read_csv(tsv_files[nn], sep="\t")
        tsv = tsv[tsv["mapq"] >= min_mapq]
        insertions = tsv["ins0"].values.tolist()

        # Get strand info for insertions near the MCV
        mcv_position = insertion_site  # MCV position from guide_row
        if "strand" in tsv.columns:
            # Find insertions at exact MCV position
            mcv_insertions = tsv[tsv["ins0"] == mcv_position]
    
            if not mcv_insertions.empty:
                strand_counts = mcv_insertions["strand"].value_counts().to_dict()
                plus_count = strand_counts.get('+', 0)
                minus_count = strand_counts.get('-', 0)
                total_at_mcv = len(mcv_insertions)
                
                print(f"    Insertion strand distribution at MCV position {mcv_position:,}:")
                print(f"      + strand: {plus_count}")
                print(f"      - strand: {minus_count}")
                print(f"      Total: {total_at_mcv}")
            else:
                print(f"    No insertions found at exact MCV position {mcv_position:,}")
        else:
            print("    Strand column not available in TSV")
            
        # Get target position
        gmap = php.map_guide_to_genome(guideRNA["protospacer"][nn], genome_sequence)
        target_position = gmap[0]["start"]
        
        # Get best off-target window position
        best_off_target_window = off_target_row['best_off_target_window']
        
        # Check each selected guide to see if it aligns to the off-target window region
        for _, guide_row in sample_guides.iterrows():
            guide_seq = guide_row['guide_seq']
            hotspot = guide_row['hotspot']
            insertion_site = guide_row['insertion_site']  # MCV position
            distance_to_mcv = guide_row['distance_to_mcv']  # Distance from guide to MCV
            
            # Find where this guide sequence occurs in the genome near the off-target window
            # Search in ±500bp around the best off-target window
            search_start = max(0, int(best_off_target_window) - 500)
            search_end = min(len(genome_sequence), int(best_off_target_window) + 500)
            search_seq = genome_sequence[search_start:search_end]
            
            # Look for exact matches of guide sequence
            binding_positions = []
            for i in range(len(search_seq) - len(guide_seq) + 1):
                if search_seq[i:i+len(guide_seq)] == guide_seq:
                    genomic_pos = search_start + i
                    distance_to_window = abs(genomic_pos - best_off_target_window)
                    binding_positions.append((genomic_pos, distance_to_window))
            
            # Also check reverse complement
            revcomp_seq = revcomp(guide_seq)
            for i in range(len(search_seq) - len(revcomp_seq) + 1):
                if search_seq[i:i+len(revcomp_seq)] == revcomp_seq:
                    genomic_pos = search_start + i
                    distance_to_window = abs(genomic_pos - best_off_target_window)
                    binding_positions.append((genomic_pos, distance_to_window))
            
            if binding_positions:
                # Get closest binding position to off-target window
                binding_positions.sort(key=lambda x: x[1])
                best_binding_pos, min_distance = binding_positions[0]
                
                # Count insertions near this binding position
                nearby_insertions = sum(1 for pos in insertions 
                                       if abs(pos - best_binding_pos) <= 100)
                
                print(f"\n  {hotspot}:")
                print(f"    Guide sequence: {guide_seq}")
                print(f"    MCV position: {insertion_site:,}")
                print(f"    Distance from guide to MCV: {distance_to_mcv} bp")
                print(f"    Binding position in off-target region: {best_binding_pos:,}")
                print(f"    Distance to best off-target window: {min_distance} bp")
                print(f"    Insertions within ±100bp of binding: {nearby_insertions}")
                
                off_target_binding_results.append({
                    'sample_id': sample_id,
                    'sample_name': off_target_row['sample_name'],
                    'off_target_preference': off_target_row['off_target_preference'],
                    'hotspot': hotspot,
                    'guide_seq': guide_seq,
                    'mcv_position': insertion_site,
                    'distance_guide_to_mcv': distance_to_mcv,
                    'binding_position': best_binding_pos,
                    'best_off_target_window': int(best_off_target_window),
                    'distance_binding_to_window': min_distance,
                    'nearby_insertions': nearby_insertions,
                    'original_guide': guide_row.get('original_guide', '')
                })
            else:
                print(f"\n  {hotspot}: Guide does NOT bind in off-target window region")
    
    if off_target_binding_results:
        # Create summary DataFrame
        df_off_target_binding = pd.DataFrame(off_target_binding_results)
        df_off_target_binding = df_off_target_binding.sort_values('off_target_preference', ascending=False)
        
        print("\n" + "=" * 140)
        print("SUMMARY: SELECTED GUIDES BINDING IN OFF-TARGET WINDOWS")
        print("=" * 140)
        print(df_off_target_binding[['sample_id', 'sample_name', 'off_target_preference', 
                                     'hotspot', 'guide_seq', 'distance_guide_to_mcv',
                                     'binding_position', 'best_off_target_window',
                                     'distance_binding_to_window', 'nearby_insertions']].to_string(index=False))
        
        # Save to CSV
        output_csv = output_csv_dir / "02132026_T10_SelectedGuides.csv"
        df_off_target_binding.to_csv(output_csv, index=False)
        print(f"\n✓ Saved results to: {output_csv}")
    else:
        print("\nNo selected guides found binding in off-target windows")
# Out:
# ============================================================================================================================================
# CHECKING IF SELECTED IDEAL GUIDES BIND IN BEST OFF-TARGET WINDOWS
# ============================================================================================================================================
#
# Sample 70: 70_S70_L001_R1_001.insertions.5p
#   Off-target preference: 82.1%
#   Best off-target window position: 4,471,500
#   Best off-target window integrations: 29430
#     No insertions found at exact MCV position 2,528,741
#
#   70_mcv1:
#     Guide sequence: GAGAGATCGACATATAAATC
#     MCV position: 4,471,450
#     Distance from guide to MCV: 69 bp
#     Binding position in off-target region: 4,471,359
#     Distance to best off-target window: 141 bp
#     Insertions within ±100bp of binding: 29343
#
#   70_mcv2: Guide does NOT bind in off-target window region
#
#   70_mcv3: Guide does NOT bind in off-target window region
#
# Sample 31: 31_S31_L001_R1_001.insertions.5p
#   Off-target preference: 76.2%
#   Best off-target window position: 2,170,900
#   Best off-target window integrations: 15611
#     No insertions found at exact MCV position 868,051
#
#   31_mcv1:
#     Guide sequence: GATATTGGCGCGGGCCAGTG
#     MCV position: 2,170,825
#     Distance from guide to MCV: 70 bp
#     Binding position in off-target region: 2,170,898
#     Distance to best off-target window: 2 bp
#     Insertions within ±100bp of binding: 15611
#
#   31_mcv2: Guide does NOT bind in off-target window region
#
#   31_mcv3: Guide does NOT bind in off-target window region
#
# Sample 108: 108_S108_L001_R1_001.insertions.5p
#   Off-target preference: 74.6%
#   Best off-target window position: 1,388,100
#   Best off-target window integrations: 26186
#     No insertions found at exact MCV position 1,939,901
#
#   108_mcv1:
#     Guide sequence: GTGGTGGGCAACATGGGCGG
#     MCV position: 1,388,173
#     Distance from guide to MCV: 67 bp
#     Binding position in off-target region: 1,388,243
#     Distance to best off-target window: 143 bp
#     Insertions within ±100bp of binding: 26160
#
#   108_mcv2: Guide does NOT bind in off-target window region
#
#   108_mcv3: Guide does NOT bind in off-target window region
#
#   108_mcv4: Guide does NOT bind in off-target window region
#
#   108_mcv5: Guide does NOT bind in off-target window region
#
#   108_mcv6: Guide does NOT bind in off-target window region
#
#   108_mcv7: Guide does NOT bind in off-target window region
#
# Sample 56: 56_S56_L001_R1_001.insertions.5p
#   Off-target preference: 73.3%
#   Best off-target window position: 4,279,500
#   Best off-target window integrations: 29636
#     No insertions found at exact MCV position 4,211,117
#
#   56_mcv1:
#     Guide sequence: GCTGCTGATGGCGAAAGCGC
#     MCV position: 4,279,409
#     Distance from guide to MCV: 70 bp
#     Binding position in off-target region: 4,279,482
#     Distance to best off-target window: 18 bp
#     Insertions within ±100bp of binding: 29661
#
#   56_mcv2: Guide does NOT bind in off-target window region
#
#   56_mcv3: Guide does NOT bind in off-target window region
#
#   56_mcv4: Guide does NOT bind in off-target window region
#
#   56_mcv5: Guide does NOT bind in off-target window region
#
#   56_mcv6: Guide does NOT bind in off-target window region
#
# Sample 87: 87_S87_L001_R1_001.insertions.5p
#   Off-target preference: 69.1%
#   Best off-target window position: 2,000,700
#   Best off-target window integrations: 23528
#     No insertions found at exact MCV position 1,045,952
#
#   87_mcv1:
#     Guide sequence: CAAGTAGGAAGTCGAGAGGA
#     MCV position: 2,000,666
#     Distance from guide to MCV: 70 bp
#     Binding position in off-target region: 2,000,739
#     Distance to best off-target window: 39 bp
#     Insertions within ±100bp of binding: 23541
#
#   87_mcv2: Guide does NOT bind in off-target window region
#
#   87_mcv3: Guide does NOT bind in off-target window region
#
#   87_mcv4: Guide does NOT bind in off-target window region
#
# Sample 98: 98_S98_L001_R1_001.insertions.5p
#   Off-target preference: 68.7%
#   Best off-target window position: 1,959,100
#   Best off-target window integrations: 33454
#     No insertions found at exact MCV position 2,235,709
#
#   98_mcv1:
#     Guide sequence: TGGCGGCGGTGTGACGTTAT
#     MCV position: 1,959,187
#     Distance from guide to MCV: 70 bp
#     Binding position in off-target region: 1,959,095
#     Distance to best off-target window: 5 bp
#     Insertions within ±100bp of binding: 33240
#
#   98_mcv2: Guide does NOT bind in off-target window region
#
#   98_mcv3: Guide does NOT bind in off-target window region
#
#   98_mcv4: Guide does NOT bind in off-target window region
#
#   98_mcv5: Guide does NOT bind in off-target window region
#
# Sample 93: 93_S93_L001_R1_001.insertions.5p
#   Off-target preference: 62.1%
#   Best off-target window position: 863,900
#   Best off-target window integrations: 25129
#     No insertions found at exact MCV position 762,306
#
#   93_mcv1:
#     Guide sequence: CATCGCCTTTACTACCGTAA
#     MCV position: 863,812
#     Distance from guide to MCV: 71 bp
#     Binding position in off-target region: 863,719
#     Distance to best off-target window: 181 bp
#     Insertions within ±100bp of binding: 26126
#
#   93_mcv2: Guide does NOT bind in off-target window region
#
#   93_mcv3: Guide does NOT bind in off-target window region
#
#   93_mcv4: Guide does NOT bind in off-target window region
#
#   93_mcv5: Guide does NOT bind in off-target window region
#
#   93_mcv6: Guide does NOT bind in off-target window region
#
#   93_mcv7: Guide does NOT bind in off-target window region
#
#   93_mcv8: Guide does NOT bind in off-target window region
#
# Sample 23: 23_S23_L001_R1_001.insertions.5p
#   Off-target preference: 60.4%
#   Best off-target window position: 1,948,700
#   Best off-target window integrations: 11191
#     No insertions found at exact MCV position 882,638
#
#   23_mcv1:
#     Guide sequence: GTTGGCATCCTGGTCGCCTG
#     MCV position: 1,948,746
#     Distance from guide to MCV: 70 bp
#     Binding position in off-target region: 1,948,654
#     Distance to best off-target window: 46 bp
#     Insertions within ±100bp of binding: 11186
#
#   23_mcv2: Guide does NOT bind in off-target window region
#
#   23_mcv3: Guide does NOT bind in off-target window region
#
#   23_mcv4: Guide does NOT bind in off-target window region
#
#   23_mcv5: Guide does NOT bind in off-target window region
#
# Sample 1: 1_S1_L001_R1_001.insertions.5p
#   Off-target preference: 58.6%
#   Best off-target window position: 2,110,700
#   Best off-target window integrations: 9902
#     No insertions found at exact MCV position 2,529,873
#
#   1_mcv1:
#     Guide sequence: GGGATTTCAGGTCATCCCAG
#     MCV position: 2,110,612
#     Distance from guide to MCV: 71 bp
#     Binding position in off-target region: 2,110,519
#     Distance to best off-target window: 181 bp
#     Insertions within ±100bp of binding: 9928
#
#   1_mcv2: Guide does NOT bind in off-target window region
#
#   1_mcv3: Guide does NOT bind in off-target window region
#
#   1_mcv4: Guide does NOT bind in off-target window region
#
# Sample 36: 36_S36_L001_R1_001.insertions.5p
#   Off-target preference: 57.0%
#   Best off-target window position: 1,922,500
#   Best off-target window integrations: 17141
#     No insertions found at exact MCV position 2,528,640
#
#   36_mcv1:
#     Guide sequence: GGATAGTTGGCTGGCAGGTC
#     MCV position: 1,922,467
#     Distance from guide to MCV: 69 bp
#     Binding position in off-target region: 1,922,376
#     Distance to best off-target window: 124 bp
#     Insertions within ±100bp of binding: 17051
#
#   36_mcv2: Guide does NOT bind in off-target window region
#
#   36_mcv3: Guide does NOT bind in off-target window region
#
#   36_mcv4: Guide does NOT bind in off-target window region
#
#   36_mcv5: Guide does NOT bind in off-target window region
#
#   36_mcv6: Guide does NOT bind in off-target window region
#
#   36_mcv7: Guide does NOT bind in off-target window region
#
# ============================================================================================================================================
# SUMMARY: SELECTED GUIDES BINDING IN OFF-TARGET WINDOWS
# ============================================================================================================================================
#  sample_id                        sample_name  off_target_preference  hotspot            guide_seq  distance_guide_to_mcv  binding_position  best_off_target_window  distance_binding_to_window  nearby_insertions
#         70   70_S70_L001_R1_001.insertions.5p              82.067734  70_mcv1 GAGAGATCGACATATAAATC                     69           4471359                 4471500                         141              29343
#         31   31_S31_L001_R1_001.insertions.5p              76.206542  31_mcv1 GATATTGGCGCGGGCCAGTG                     70           2170898                 2170900                           2              15611
#        108 108_S108_L001_R1_001.insertions.5p              74.627252 108_mcv1 GTGGTGGGCAACATGGGCGG                     67           1388243                 1388100                         143              26160
#         56   56_S56_L001_R1_001.insertions.5p              73.290473  56_mcv1 GCTGCTGATGGCGAAAGCGC                     70           4279482                 4279500                          18              29661
#         87   87_S87_L001_R1_001.insertions.5p              69.119595  87_mcv1 CAAGTAGGAAGTCGAGAGGA                     70           2000739                 2000700                          39              23541
#         98   98_S98_L001_R1_001.insertions.5p              68.716191  98_mcv1 TGGCGGCGGTGTGACGTTAT                     70           1959095                 1959100                           5              33240
#         93   93_S93_L001_R1_001.insertions.5p              62.109658  93_mcv1 CATCGCCTTTACTACCGTAA                     71            863719                  863900                         181              26126
#         23   23_S23_L001_R1_001.insertions.5p              60.428392  23_mcv1 GTTGGCATCCTGGTCGCCTG                     70           1948654                 1948700                          46              11186
#          1     1_S1_L001_R1_001.insertions.5p              58.637499   1_mcv1 GGGATTTCAGGTCATCCCAG                     71           2110519                 2110700                         181               9928
#         36   36_S36_L001_R1_001.insertions.5p              56.994439  36_mcv1 GGATAGTTGGCTGGCAGGTC                     69           1922376                 1922500                         124              17051
#
# ✓ Saved results to: /Users/ecreed/Desktop/KelloggRotation/02052026_TagmentatioAnalysis_251218_260117_260203_combined/FilteredCandidateSpacersBulk/02132026_T10_SelectedGuides.csv

# %%
# messing around with cell directly above
# Check if selected ideal guides bind in best off-target windows
# For samples with strong off-target preference, find guide binding positions in off-target regions
# Uses Selected_Ideal_Guides.csv

import pandas as pd
from pathlib import Path

# Load the selected ideal guides CSV
selected_guides_csv = output_csv_dir / "02132026_Selected_Ideal_Guides.csv"

if not selected_guides_csv.exists():
    print(f"ERROR: {selected_guides_csv} not found")
else:
    df_selected = pd.read_csv(selected_guides_csv)
    
    # Extract sample_id from hotspot column (format: "sample_id_mcvN")
    df_selected['sample_id'] = df_selected['hotspot'].str.split('_').str[0].astype(int)
    
    # Get samples with strong off-target preference (top 10)
    top_off_target_samples = df_off_target.head(10)
    
    off_target_binding_results = []
    
    print("=" * 140)
    print("CHECKING IF SELECTED IDEAL GUIDES BIND IN BEST OFF-TARGET WINDOWS")
    print("=" * 140)
    
    for idx, off_target_row in top_off_target_samples.iterrows():
        sample_id = off_target_row['sample_id']
        nn = sample_id - 1
        
        print(f"\nSample {sample_id}: {off_target_row['sample_name']}")
        print(f"  Off-target preference: {off_target_row['off_target_preference']:.1f}%")
        print(f"  Best off-target window position: {off_target_row['best_off_target_window']:,}")
        print(f"  Best off-target window integrations: {off_target_row['best_off_target_count']}")
        
        # Get selected guides for this sample from CSV
        sample_guides = df_selected[df_selected['sample_id'] == sample_id]
        
        if sample_guides.empty:
            print(f"  No selected guides found for this sample")
            continue
        
        # Get insertion data for this sample
        tsv = pd.read_csv(tsv_files[nn], sep="\t")
        tsv = tsv[tsv["mapq"] >= min_mapq]
        insertions = tsv["ins0"].values.tolist()

        # Get insertion data for this sample
        tsv = pd.read_csv(tsv_files[nn], sep="\t")
        tsv = tsv[tsv["mapq"] >= min_mapq]
        insertions = tsv["ins0"].values.tolist()

        # Get strand info for insertions near the MCV
        mcv_position = insertion_site  # MCV position from guide_row
        if "strand" in tsv.columns:
            # Find insertions at exact MCV position
            mcv_insertions = tsv[tsv["ins0"] == mcv_position]
    
            if not mcv_insertions.empty:
                strand_counts = mcv_insertions["strand"].value_counts().to_dict()
                plus_count = strand_counts.get('+', 0)
                minus_count = strand_counts.get('-', 0)
                total_at_mcv = len(mcv_insertions)
                
                print(f"    Insertion strand distribution at MCV position {mcv_position:,}:")
                print(f"      + strand: {plus_count}")
                print(f"      - strand: {minus_count}")
                print(f"      Total: {total_at_mcv}")
            else:
                print(f"    No insertions found at exact MCV position {mcv_position:,}")
        else:
            print("    Strand column not available in TSV")
            
        # Get target position
        gmap = php.map_guide_to_genome(guideRNA["protospacer"][nn], genome_sequence)
        target_position = gmap[0]["start"]
        
        # Get best off-target window position
        best_off_target_window = off_target_row['best_off_target_window']
        
        # Check each selected guide to see if it aligns to the off-target window region
        for _, guide_row in sample_guides.iterrows():
            guide_seq = guide_row['guide_seq']
            hotspot = guide_row['hotspot']
            insertion_site = guide_row['insertion_site']  # MCV position
            distance_to_mcv = guide_row['distance_to_mcv']  # Distance from guide to MCV
            
            # Find where this guide sequence occurs in the genome near the off-target window
            # Search in ±500bp around the best off-target window
            search_start = max(0, int(best_off_target_window) - 500)
            search_end = min(len(genome_sequence), int(best_off_target_window) + 500)
            search_seq = genome_sequence[search_start:search_end]
            
            # Look for exact matches of guide sequence
            binding_positions = []
            for i in range(len(search_seq) - len(guide_seq) + 1):
                if search_seq[i:i+len(guide_seq)] == guide_seq:
                    genomic_pos = search_start + i
                    distance_to_window = abs(genomic_pos - best_off_target_window)
                    binding_positions.append((genomic_pos, distance_to_window))
            
            # Also check reverse complement
            revcomp_seq = revcomp(guide_seq)
            for i in range(len(search_seq) - len(revcomp_seq) + 1):
                if search_seq[i:i+len(revcomp_seq)] == revcomp_seq:
                    genomic_pos = search_start + i
                    distance_to_window = abs(genomic_pos - best_off_target_window)
                    binding_positions.append((genomic_pos, distance_to_window))
            
            if binding_positions:
                # Get closest binding position to off-target window
                binding_positions.sort(key=lambda x: x[1])
                best_binding_pos, min_distance = binding_positions[0]
                
                # Count insertions near this binding position
                binding_window = 50
                nearby_insertions = sum(1 for pos in insertions 
                                       if abs(pos - best_binding_pos) <= binding_window)
                
                # Get strand distribution in this window
                if "strand" in tsv.columns:
                    nearby_insertions_df = tsv[
                        (tsv["ins0"] >= best_binding_pos - binding_window) & 
                        (tsv["ins0"] <= best_binding_pos + binding_window)
                    ]
                    strand_counts = nearby_insertions_df["strand"].value_counts().to_dict()
                    plus_count = strand_counts.get('+', 0)
                    minus_count = strand_counts.get('-', 0)
                else:
                    plus_count = minus_count = 0
                
                print(f"\n  {hotspot}:")
                print(f"    Guide sequence: {guide_seq}")
                print(f"    MCV position: {insertion_site:,}")
                print(f"    Distance from guide to MCV: {distance_to_mcv} bp")
                print(f"    Binding position in off-target region: {best_binding_pos:,}")
                print(f"    Distance to best off-target window: {min_distance} bp")
                print(f"    Insertions within ±{binding_window}bp of binding: {nearby_insertions}")
                if "strand" in tsv.columns:
                    print(f"      + strand: {plus_count}, - strand: {minus_count}")
                
                off_target_binding_results.append({
                    'sample_id': sample_id,
                    'sample_name': off_target_row['sample_name'],
                    'off_target_preference': off_target_row['off_target_preference'],
                    'hotspot': hotspot,
                    'guide_seq': guide_seq,
                    'mcv_position': insertion_site,
                    'distance_guide_to_mcv': distance_to_mcv,
                    'binding_position': best_binding_pos,
                    'best_off_target_window': int(best_off_target_window),
                    'distance_binding_to_window': min_distance,
                    'nearby_insertions': nearby_insertions,
                    'original_guide': guide_row.get('original_guide', '')
                })
            else:
                print(f"\n  {hotspot}: Guide does NOT bind in off-target window region")
    
    if off_target_binding_results:
        # Create summary DataFrame
        df_off_target_binding = pd.DataFrame(off_target_binding_results)
        df_off_target_binding = df_off_target_binding.sort_values('off_target_preference', ascending=False)
        
        print("\n" + "=" * 140)
        print("SUMMARY: SELECTED GUIDES BINDING IN OFF-TARGET WINDOWS")
        print("=" * 140)
        print(df_off_target_binding[['sample_id', 'sample_name', 'off_target_preference', 
                                     'hotspot', 'guide_seq', 'distance_guide_to_mcv',
                                     'binding_position', 'best_off_target_window',
                                     'distance_binding_to_window', 'nearby_insertions']].to_string(index=False))
        
        # Save to CSV
        output_csv = output_csv_dir / "blahblahblah_02132026_T10_SelectedGuides.csv"
        df_off_target_binding.to_csv(output_csv, index=False)
        print(f"\n✓ Saved results to: {output_csv}")
    else:
        print("\nNo selected guides found binding in off-target windows")
# Out:
# ============================================================================================================================================
# CHECKING IF SELECTED IDEAL GUIDES BIND IN BEST OFF-TARGET WINDOWS
# ============================================================================================================================================
#
# Sample 70: 70_S70_L001_R1_001.insertions.5p
#   Off-target preference: 82.1%
#   Best off-target window position: 4,471,500
#   Best off-target window integrations: 29430
#     No insertions found at exact MCV position 2,528,741
#
#   70_mcv1:
#     Guide sequence: GAGAGATCGACATATAAATC
#     MCV position: 4,471,450
#     Distance from guide to MCV: 69 bp
#     Binding position in off-target region: 4,471,359
#     Distance to best off-target window: 141 bp
#     Insertions within ±50bp of binding: 45
#       + strand: 0, - strand: 45
#
#   70_mcv2: Guide does NOT bind in off-target window region
#
#   70_mcv3: Guide does NOT bind in off-target window region
#
# Sample 31: 31_S31_L001_R1_001.insertions.5p
#   Off-target preference: 76.2%
#   Best off-target window position: 2,170,900
#   Best off-target window integrations: 15611
#     No insertions found at exact MCV position 868,051
#
#   31_mcv1:
#     Guide sequence: GATATTGGCGCGGGCCAGTG
#     MCV position: 2,170,825
#     Distance from guide to MCV: 70 bp
#     Binding position in off-target region: 2,170,898
#     Distance to best off-target window: 2 bp
#     Insertions within ±50bp of binding: 156
#       + strand: 156, - strand: 0
#
#   31_mcv2: Guide does NOT bind in off-target window region
#
#   31_mcv3: Guide does NOT bind in off-target window region
#
# Sample 108: 108_S108_L001_R1_001.insertions.5p
#   Off-target preference: 74.6%
#   Best off-target window position: 1,388,100
#   Best off-target window integrations: 26186
#     No insertions found at exact MCV position 1,939,901
#
#   108_mcv1:
#     Guide sequence: GTGGTGGGCAACATGGGCGG
#     MCV position: 1,388,173
#     Distance from guide to MCV: 67 bp
#     Binding position in off-target region: 1,388,243
#     Distance to best off-target window: 143 bp
#     Insertions within ±50bp of binding: 20
#       + strand: 20, - strand: 0
#
#   108_mcv2: Guide does NOT bind in off-target window region
#
#   108_mcv3: Guide does NOT bind in off-target window region
#
#   108_mcv4: Guide does NOT bind in off-target window region
#
#   108_mcv5: Guide does NOT bind in off-target window region
#
#   108_mcv6: Guide does NOT bind in off-target window region
#
#   108_mcv7: Guide does NOT bind in off-target window region
#
# Sample 56: 56_S56_L001_R1_001.insertions.5p
#   Off-target preference: 73.3%
#   Best off-target window position: 4,279,500
#   Best off-target window integrations: 29636
#     No insertions found at exact MCV position 4,211,117
#
#   56_mcv1:
#     Guide sequence: GCTGCTGATGGCGAAAGCGC
#     MCV position: 4,279,409
#     Distance from guide to MCV: 70 bp
#     Binding position in off-target region: 4,279,482
#     Distance to best off-target window: 18 bp
#     Insertions within ±50bp of binding: 13
#       + strand: 13, - strand: 0
#
#   56_mcv2: Guide does NOT bind in off-target window region
#
#   56_mcv3: Guide does NOT bind in off-target window region
#
#   56_mcv4: Guide does NOT bind in off-target window region
#
#   56_mcv5: Guide does NOT bind in off-target window region
#
#   56_mcv6: Guide does NOT bind in off-target window region
#
# Sample 87: 87_S87_L001_R1_001.insertions.5p
#   Off-target preference: 69.1%
#   Best off-target window position: 2,000,700
#   Best off-target window integrations: 23528
#     No insertions found at exact MCV position 1,045,952
#
#   87_mcv1:
#     Guide sequence: CAAGTAGGAAGTCGAGAGGA
#     MCV position: 2,000,666
#     Distance from guide to MCV: 70 bp
#     Binding position in off-target region: 2,000,739
#     Distance to best off-target window: 39 bp
#     Insertions within ±50bp of binding: 149
#       + strand: 149, - strand: 0
#
#   87_mcv2: Guide does NOT bind in off-target window region
#
#   87_mcv3: Guide does NOT bind in off-target window region
#
#   87_mcv4: Guide does NOT bind in off-target window region
#
# Sample 98: 98_S98_L001_R1_001.insertions.5p
#   Off-target preference: 68.7%
#   Best off-target window position: 1,959,100
#   Best off-target window integrations: 33454
#     No insertions found at exact MCV position 2,235,709
#
#   98_mcv1:
#     Guide sequence: TGGCGGCGGTGTGACGTTAT
#     MCV position: 1,959,187
#     Distance from guide to MCV: 70 bp
#     Binding position in off-target region: 1,959,095
#     Distance to best off-target window: 5 bp
#     Insertions within ±50bp of binding: 132
#       + strand: 42, - strand: 90
#
#   98_mcv2: Guide does NOT bind in off-target window region
#
#   98_mcv3: Guide does NOT bind in off-target window region
#
#   98_mcv4: Guide does NOT bind in off-target window region
#
#   98_mcv5: Guide does NOT bind in off-target window region
#
# Sample 93: 93_S93_L001_R1_001.insertions.5p
#   Off-target preference: 62.1%
#   Best off-target window position: 863,900
#   Best off-target window integrations: 25129
#     No insertions found at exact MCV position 762,306
#
#   93_mcv1:
#     Guide sequence: CATCGCCTTTACTACCGTAA
#     MCV position: 863,812
#     Distance from guide to MCV: 71 bp
#     Binding position in off-target region: 863,719
#     Distance to best off-target window: 181 bp
#     Insertions within ±50bp of binding: 96
#       + strand: 0, - strand: 96
#
#   93_mcv2: Guide does NOT bind in off-target window region
#
#   93_mcv3: Guide does NOT bind in off-target window region
#
#   93_mcv4: Guide does NOT bind in off-target window region
#
#   93_mcv5: Guide does NOT bind in off-target window region
#
#   93_mcv6: Guide does NOT bind in off-target window region
#
#   93_mcv7: Guide does NOT bind in off-target window region
#
#   93_mcv8: Guide does NOT bind in off-target window region
#
# Sample 23: 23_S23_L001_R1_001.insertions.5p
#   Off-target preference: 60.4%
#   Best off-target window position: 1,948,700
#   Best off-target window integrations: 11191
#     No insertions found at exact MCV position 882,638
#
#   23_mcv1:
#     Guide sequence: GTTGGCATCCTGGTCGCCTG
#     MCV position: 1,948,746
#     Distance from guide to MCV: 70 bp
#     Binding position in off-target region: 1,948,654
#     Distance to best off-target window: 46 bp
#     Insertions within ±50bp of binding: 1
#       + strand: 0, - strand: 1
#
#   23_mcv2: Guide does NOT bind in off-target window region
#
#   23_mcv3: Guide does NOT bind in off-target window region
#
#   23_mcv4: Guide does NOT bind in off-target window region
#
#   23_mcv5: Guide does NOT bind in off-target window region
#
# Sample 1: 1_S1_L001_R1_001.insertions.5p
#   Off-target preference: 58.6%
#   Best off-target window position: 2,110,700
#   Best off-target window integrations: 9902
#     No insertions found at exact MCV position 2,529,873
#
#   1_mcv1:
#     Guide sequence: GGGATTTCAGGTCATCCCAG
#     MCV position: 2,110,612
#     Distance from guide to MCV: 71 bp
#     Binding position in off-target region: 2,110,519
#     Distance to best off-target window: 181 bp
#     Insertions within ±50bp of binding: 20
#       + strand: 0, - strand: 20
#
#   1_mcv2: Guide does NOT bind in off-target window region
#
#   1_mcv3: Guide does NOT bind in off-target window region
#
#   1_mcv4: Guide does NOT bind in off-target window region
#
# Sample 36: 36_S36_L001_R1_001.insertions.5p
#   Off-target preference: 57.0%
#   Best off-target window position: 1,922,500
#   Best off-target window integrations: 17141
#     No insertions found at exact MCV position 2,528,640
#
#   36_mcv1:
#     Guide sequence: GGATAGTTGGCTGGCAGGTC
#     MCV position: 1,922,467
#     Distance from guide to MCV: 69 bp
#     Binding position in off-target region: 1,922,376
#     Distance to best off-target window: 124 bp
#     Insertions within ±50bp of binding: 4
#       + strand: 0, - strand: 4
#
#   36_mcv2: Guide does NOT bind in off-target window region
#
#   36_mcv3: Guide does NOT bind in off-target window region
#
#   36_mcv4: Guide does NOT bind in off-target window region
#
#   36_mcv5: Guide does NOT bind in off-target window region
#
#   36_mcv6: Guide does NOT bind in off-target window region
#
#   36_mcv7: Guide does NOT bind in off-target window region
#
# ============================================================================================================================================
# SUMMARY: SELECTED GUIDES BINDING IN OFF-TARGET WINDOWS
# ============================================================================================================================================
#  sample_id                        sample_name  off_target_preference  hotspot            guide_seq  distance_guide_to_mcv  binding_position  best_off_target_window  distance_binding_to_window  nearby_insertions
#         70   70_S70_L001_R1_001.insertions.5p              82.067734  70_mcv1 GAGAGATCGACATATAAATC                     69           4471359                 4471500                         141                 45
#         31   31_S31_L001_R1_001.insertions.5p              76.206542  31_mcv1 GATATTGGCGCGGGCCAGTG                     70           2170898                 2170900                           2                156
#        108 108_S108_L001_R1_001.insertions.5p              74.627252 108_mcv1 GTGGTGGGCAACATGGGCGG                     67           1388243                 1388100                         143                 20
#         56   56_S56_L001_R1_001.insertions.5p              73.290473  56_mcv1 GCTGCTGATGGCGAAAGCGC                     70           4279482                 4279500                          18                 13
#         87   87_S87_L001_R1_001.insertions.5p              69.119595  87_mcv1 CAAGTAGGAAGTCGAGAGGA                     70           2000739                 2000700                          39                149
#         98   98_S98_L001_R1_001.insertions.5p              68.716191  98_mcv1 TGGCGGCGGTGTGACGTTAT                     70           1959095                 1959100                           5                132
#         93   93_S93_L001_R1_001.insertions.5p              62.109658  93_mcv1 CATCGCCTTTACTACCGTAA                     71            863719                  863900                         181                 96
#         23   23_S23_L001_R1_001.insertions.5p              60.428392  23_mcv1 GTTGGCATCCTGGTCGCCTG                     70           1948654                 1948700                          46                  1
#          1     1_S1_L001_R1_001.insertions.5p              58.637499   1_mcv1 GGGATTTCAGGTCATCCCAG                     71           2110519                 2110700                         181                 20
#         36   36_S36_L001_R1_001.insertions.5p              56.994439  36_mcv1 GGATAGTTGGCTGGCAGGTC                     69           1922376                 1922500                         124                  4
#
# ✓ Saved results to: /Users/ecreed/Desktop/KelloggRotation/02052026_TagmentatioAnalysis_251218_260117_260203_combined/FilteredCandidateSpacersBulk/blahblahblah_02132026_T10_SelectedGuides.csv

# %%
# v3 single csv, calculate integration freq from cluster
# filtered candidate spacers single csv with insertion strand distribution and frequency columns 
# bulk run + filtering by NGG and distance
# Bulk: write per-sample CSVs but only include NGG guides 66-76 bp from their mcv
# ENHANCED: add strand distribution and hotspot frequency columns
# FIXED: integration_frequency now sums across all cluster members, not just rep_pos

import re
import pandas as pd
from collections import Counter
from pathlib import Path

def revcomp(seq):
    comp = str.maketrans("ACGTacgt", "TGCAtgca")
    return seq.translate(comp)[::-1]

def _sample_id_from_name(p: Path):
    m = re.match(r"(\d+)_S\1_", p.name)
    return int(m.group(1)) if m else None

written = []
skipped = []
all_rows = []

for nn, tsv_path in enumerate(tsv_files):
    sample_id = _sample_id_from_name(tsv_path) or (nn + 1)

    # load + basic filter (min_mapq expected in notebook)
    tsv = pd.read_csv(tsv_path, sep="\t")
    tsv = tsv[tsv["mapq"] >= min_mapq]
    
    # Calculate total insertions in sample and strand counts per insertion position
    total_insertions = len(tsv)
    insertion_strands = {}  # {position: {'+': count, '-': count}}
    for _, row in tsv.iterrows():
        pos = row["ins0"]
        strand = row.get("strand", "+")  # default to + if not present
        if pos not in insertion_strands:
            insertion_strands[pos] = {'+': 0, '-': 0}
        insertion_strands[pos][strand] = insertion_strands[pos].get(strand, 0) + 1

    # collapse hotspots (same logic as before)
    collapse_bp = 5
    min_reads = 500

    counts = Counter(tsv["ins0"])
    gmap = php.map_guide_to_genome(guideRNA["protospacer"][nn], genome_sequence)
    target_position = gmap[0]["start"]
    counts[target_position] = counts.get(target_position, 0)

    clusters = [{"members": {pos: freq}, "total": freq} for pos, freq in counts.items()]
    merged = True
    while merged:
        merged = False
        new_clusters = []
        while clusters:
            c = clusters.pop(0)
            i = 0
            while i < len(clusters):
                other = clusters[i]
                close = any(abs(p - q) <= collapse_bp for p in c["members"] for q in other["members"])
                if close:
                    for p, f in other["members"].items():
                        c["members"][p] = c["members"].get(p, 0) + f
                    c["total"] += other["total"]
                    clusters.pop(i)
                    merged = True
                else:
                    i += 1
            new_clusters.append(c)
        clusters = new_clusters

    clusters_info = []
    for c in clusters:
        rep_pos, rep_count = max(c["members"].items(), key=lambda x: x[1])
        clusters_info.append({
            "rep_pos": int(rep_pos),
            "rep_count": int(rep_count),
            "total": int(c["total"]),
            "members": sorted(c["members"].keys()),
            "contains_target": (target_position in c["members"])
        })

    filtered = [c for c in clusters_info if c["total"] > min_reads]
    if not any(c["contains_target"] for c in filtered):
        for c in clusters_info:
            if c["contains_target"]:
                filtered.append(c)
                break

    filtered.sort(key=lambda x: x["total"], reverse=True)
    for idx, c in enumerate(filtered, start=1):
        c["mcv_id"] = idx

    # Build a lookup: rep_pos -> cluster info (for fast integration frequency calculation)
    cluster_lookup = {c["rep_pos"]: c for c in filtered}

    mcv_list = [c["rep_pos"] for c in filtered]
    hotspots = {f"mcv{idx}": pos for idx, pos in enumerate(mcv_list, start=1)}
    for idx, pos in enumerate(mcv_list, start=1):
        globals()[f"mcv{idx}"] = pos

    # Generate guides (methods 1,2,3) exactly as before
    original_guide = guideRNA["protospacer"][nn]
    hotspots_dict = hotspots if (isinstance(hotspots, dict) and hotspots) else ({f"mcv{i+1}": pos for i,pos in enumerate(mcv_list)} if "mcv_list" in globals() else {})
    _alignment_ctx = {}
    for hotspot_name, insertion_site in hotspots_dict.items():
        window_start = max(0, insertion_site - 120)
        window_end = min(len(genome_sequence), insertion_site + 120)
        window_seq = genome_sequence[window_start:window_end]

        aln_fwd = php.local_align(original_guide, window_seq)
        aln_rev = php.local_align(original_guide, revcomp(window_seq))

        if aln_fwd.score >= aln_rev.score:
            best_aln = aln_fwd
            best_strand = "+"
            search_seq = window_seq
        else:
            best_aln = aln_rev
            best_strand = "-"
            search_seq = revcomp(window_seq)

        _alignment_ctx[hotspot_name] = {
            "insertion_site": insertion_site,
            "window_start": window_start,
            "window_end": window_end,
            "window_seq": window_seq,
            "best_aln": best_aln,
            "best_strand": best_strand,
            "search_seq": search_seq,
        }

    rows = []

    window_radius = 120
    # Method 1
    for hotspot_name, insertion_site in hotspots_dict.items():
        win_start = max(0, insertion_site - window_radius)
        win_end = min(len(genome_sequence), insertion_site + window_radius)
        win_seq = genome_sequence[win_start:win_end]

        for i in range(len(win_seq) - 2):
            pam = win_seq[i:i+3]
            if pam[1:3] == "GG":
                pam_genomic_start = win_start + i
                pam_genomic_end = pam_genomic_start + 3
                guide_start = pam_genomic_start - 20
                guide_end = pam_genomic_start
                if guide_start < 0:
                    continue
                guide_seq = genome_sequence[guide_start:guide_end]
                dist = abs((pam_genomic_end - 1) - insertion_site)
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 1,
                    "pam_type": "NGG",
                    "pam_seq": pam,
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "+",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(dist),
                    "insertion_site": int(insertion_site)
                })

        for i in range(len(win_seq) - 2):
            motif = win_seq[i:i+3]
            if motif[0:2] == "CC":
                pam_genomic_start = win_start + i
                pam_genomic_end = pam_genomic_start + 3
                guide_start = pam_genomic_end
                guide_end = guide_start + 20
                if guide_end > len(genome_sequence):
                    continue
                guide_seq = revcomp(genome_sequence[guide_start:guide_end])
                dist = abs(pam_genomic_start - insertion_site)
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 1,
                    "pam_type": "NGG",
                    "pam_seq": revcomp(motif),
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "-",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(dist),
                    "insertion_site": int(insertion_site)
                })

    # Method 2
    for hotspot_name, ctx in _alignment_ctx.items():
        insertion_site = ctx["insertion_site"]
        window_start = ctx["window_start"]
        window_seq = ctx["window_seq"]
        best_aln = ctx["best_aln"]
        best_strand = ctx["best_strand"]
        search_seq = ctx["search_seq"]

        target_coords = best_aln.coordinates[1]
        target_start = int(target_coords[0])
        target_end = int(target_coords[-1])

        if best_strand == "+":
            genomic_start = window_start + target_start
            genomic_end = window_start + target_end
        else:
            genomic_start = window_start + (len(window_seq) - target_end)
            genomic_end = window_start + (len(window_seq) - target_start)

        coords_q = best_aln.coordinates[0]
        coords_t = best_aln.coordinates[1]

        query_seq = best_aln.query
        target_seq = best_aln.target

        first_match_query_pos = None
        first_match_target_pos = None
        query_pos = 0
        target_pos = 0
        for q, t in zip(query_seq, target_seq):
            if q != "-" and t != "-" and q == t:
                first_match_query_pos = query_pos
                first_match_target_pos = target_pos
                break
            if q != "-":
                query_pos += 1
            if t != "-":
                target_pos += 1

        if first_match_query_pos is not None:
            first_match_genomic = genomic_start + first_match_target_pos
            new_guide_start = first_match_genomic - first_match_query_pos
            new_guide_end = new_guide_start + 20
            if 0 <= new_guide_start and new_guide_end <= len(genome_sequence):
                if best_strand == "+":
                    new_guide = genome_sequence[new_guide_start:new_guide_end]
                    new_guide_gstart = new_guide_start
                    new_guide_gend = new_guide_end
                else:
                    new_guide = revcomp(genome_sequence[new_guide_start:new_guide_end])
                    new_guide_gstart = new_guide_start
                    new_guide_gend = new_guide_end

                if best_strand == "+":
                    five_prime_start = target_start - 3
                    five_prime_end = target_start
                    five_prime_seq = window_seq[five_prime_start:five_prime_end] if five_prime_start >= 0 else ""
                    distance_to_mcv = abs(new_guide_gstart - insertion_site)
                else:
                    five_prime_start = target_end
                    five_prime_end = target_end + 3
                    five_prime_seq = revcomp(window_seq)[five_prime_start:five_prime_end] if five_prime_end <= len(window_seq) else ""
                    distance_to_mcv = abs(new_guide_gend - insertion_site)

                pam_type = None
                pam_seq = five_prime_seq
                if len(pam_seq) == 3:
                    if pam_seq[1:3] == "GG":
                        pam_type = "NGG"
                    elif pam_seq[1:3] == "AG":
                        pam_type = "NAG"
                    elif pam_seq[1:3] == "GA":
                        pam_type = "NGA"

                if pam_type:
                    mismatch_count = sum(a != b for a, b in zip(original_guide, new_guide))
                    try:
                        aln_score = php.local_align(original_guide, new_guide).score
                    except Exception:
                        aln_score = None

                    rows.append({
                        "hotspot": hotspot_name,
                        "method": 2,
                        "pam_type": pam_type,
                        "pam_seq": pam_seq,
                        "guide_seq": new_guide,
                        "guide_start": int(new_guide_gstart),
                        "guide_end": int(new_guide_gend),
                        "strand": best_strand,
                        "mismatch_count": int(mismatch_count),
                        "alignment_score": aln_score,
                        "distance_to_mcv": int(distance_to_mcv),
                        "insertion_site": int(insertion_site)
                    })

    # Method 3
    for hotspot_name, ctx in _alignment_ctx.items():
        insertion_site = ctx["insertion_site"]
        window_start = ctx["window_start"]
        window_seq = ctx["window_seq"]
        best_aln = ctx["best_aln"]
        best_strand = ctx["best_strand"]

        target_coords = best_aln.coordinates[1]
        target_start = int(target_coords[0])
        target_end = int(target_coords[-1])

        if best_strand == "+":
            genomic_start = window_start + target_start
            genomic_end = window_start + target_end
        else:
            genomic_start = window_start + (len(window_seq) - target_end)
            genomic_end = window_start + (len(window_seq) - target_start)

        alignment_center = (genomic_start + genomic_end) // 2
        pam_search_start = max(0, alignment_center - 25)
        pam_search_end = min(len(genome_sequence), alignment_center + 25)
        pam_search_seq = genome_sequence[pam_search_start:pam_search_end]

        for i in range(len(pam_search_seq) - 2):
            pam_motif = pam_search_seq[i:i+3]
            pam_type = None
            if pam_motif[1:3] == "GG":
                pam_type = "NGG"
            elif pam_motif[1:3] == "AG":
                pam_type = "NAG"
            elif pam_motif[1:3] == "GA":
                pam_type = "NGA"
            if not pam_type:
                continue

            pam_genomic_start = pam_search_start + i
            pam_genomic_end = pam_genomic_start + 3

            guide_start = pam_genomic_start - 20
            guide_end = pam_genomic_start
            if guide_start >= 0:
                guide_seq = genome_sequence[guide_start:guide_end]
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                distance_to_mcv = abs(pam_genomic_end - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 3,
                    "pam_type": pam_type,
                    "pam_seq": genome_sequence[pam_genomic_start:pam_genomic_end],
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "+",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(distance_to_mcv),
                    "insertion_site": int(insertion_site)
                })

        for i in range(len(pam_search_seq) - 2):
            pam_motif = pam_search_seq[i:i+3]
            pam_type = None
            if pam_motif[0:2] == "CC":
                pam_type = "NGG"
            elif pam_motif[0:2] == "CT":
                pam_type = "NAG"
            elif pam_motif[0:2] == "TC":
                pam_type = "NGA"
            if not pam_type:
                continue

            pam_genomic_start = pam_search_start + i
            pam_genomic_end = pam_genomic_start + 3

            guide_start = pam_genomic_end
            guide_end = guide_start + 20
            if guide_end <= len(genome_sequence):
                guide_seq = revcomp(genome_sequence[guide_start:guide_end])
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                distance_to_mcv = abs(pam_genomic_start - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 3,
                    "pam_type": pam_type,
                    "pam_seq": revcomp(genome_sequence[pam_genomic_start:pam_genomic_end]),
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "-",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(distance_to_mcv),
                    "insertion_site": int(insertion_site)
                })

    # assemble DataFrame and compute PAM coords
    def compute_pam_coords(row):
        try:
            gs = int(row['guide_start']); ge = int(row['guide_end']); strand = row['strand']
        except Exception:
            return pd.Series([None, None])
        if strand == "+":
            return pd.Series([ge, ge + 3])
        else:
            return pd.Series([gs - 3, gs])

    df = pd.DataFrame(rows)
    if df.empty:
        skipped.append((sample_id, str(tsv_path), "No candidates generated"))
        continue

    df[['pam_start', 'pam_end']] = df.apply(compute_pam_coords, axis=1)
    df = df.dropna(subset=['pam_start','pam_end']).reset_index(drop=True)
    df['pam_start'] = df['pam_start'].astype(int)
    df['pam_end'] = df['pam_end'].astype(int)

    pams_unique = df[['hotspot','pam_start','pam_end','pam_type']].drop_duplicates().reset_index(drop=True)
    def overlap(a_s, a_e, b_s, b_e):
        return (a_s < b_e) and (b_s < a_e)

    pams_unique['overlap_any'] = False
    pams_unique['overlap_noncanonical'] = False
    pams_unique['adj_left_any'] = False
    pams_unique['adj_left_noncanonical'] = False
    pams_unique['adj_right_any'] = False
    pams_unique['adj_right_noncanonical'] = False

    for idx, p in pams_unique.iterrows():
        ps, pe, ptype, hotspot = int(p.pam_start), int(p.pam_end), p.pam_type, p.hotspot
        partners = pams_unique[(pams_unique.hotspot == hotspot) & ~((pams_unique.pam_start == ps) & (pams_unique.pam_end == pe))]
        for _, q in partners.iterrows():
            qs, qe, qtype = int(q.pam_start), int(q.pam_end), q.pam_type
            if overlap(ps,pe,qs,qe):
                pams_unique.at[idx,'overlap_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'overlap_noncanonical'] = True
            if qe == ps:
                pams_unique.at[idx,'adj_left_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'adj_left_noncanonical'] = True
            if qs == pe:
                pams_unique.at[idx,'adj_right_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'adj_right_noncanonical'] = True

    df = df.merge(pams_unique, on=['hotspot','pam_start','pam_end','pam_type'], how='left', suffixes=('','_u'))
    
    # Keep only NGG rows and then further filter 66-76 bp
    df_ngg = df[df['pam_type'] == 'NGG'].copy()
    df_ngg_filtered = df_ngg[df_ngg['distance_to_mcv'].between(66, 76)].copy()

    if df_ngg_filtered.empty:
        skipped.append((sample_id, str(tsv_path), "No NGG candidates 66-76 bp"))
        continue

    # Add two new columns: strand_distribution and integration_frequency
    # strand_distribution: "#+ vs #-" format showing insertion counts at that hotspot by strand
    # integration_frequency: sum of all insertions in the cluster / total sample insertions
    def calc_integration_freq(pos):
        cluster = cluster_lookup.get(pos)
        if cluster:
            cluster_total = cluster['total']
            if cluster_total > 0 and total_insertions > 0:
                freq = 100.0 * cluster_total / total_insertions
                return f"{freq:.2f}%"
            elif cluster.get('contains_target', False):
                # This is the target site with no actual integration reads
                return "Target (0%)"
        return "0.00%"
    
    def calc_strand_dist(pos):
        cluster = cluster_lookup.get(pos)
        if cluster:
            plus_total = 0
            minus_total = 0
            for member_pos in cluster['members']:
                strands = insertion_strands.get(member_pos, {'+': 0, '-': 0})
                plus_total += strands.get('+', 0)
                minus_total += strands.get('-', 0)
            if plus_total == 0 and minus_total == 0 and cluster.get('contains_target', False):
                return "Target (0/0)"
            return f"{plus_total}/{minus_total}"
        return "0/0"
    
    df_ngg_filtered['strand_distribution'] = df_ngg_filtered['insertion_site'].apply(calc_strand_dist)
    df_ngg_filtered['integration_frequency'] = df_ngg_filtered['insertion_site'].apply(calc_integration_freq)
    
    # Rename 'strand' column to 'pam_strand' for clarity
    df_ngg_filtered = df_ngg_filtered.rename(columns={'strand': 'pam_strand'})
    
    # relabel hotspot with sample prefix: [sample]_mcv[n]
    df_ngg_filtered['hotspot'] = df_ngg_filtered['hotspot'].apply(lambda h: f"{sample_id}_{h}")

    # collect rows for global aggregation
    all_rows.append(df_ngg_filtered)

# combine all samples and write one CSV
if not all_rows:
    print("No candidates across samples after filtering.")
else:
    combined = pd.concat(all_rows, ignore_index=True)
    out_name = output_csv_dir / "CandidateSpacers_AllSamples_filtered_combined.csv"
    combined.to_csv(out_name, index=False)
    print(f"Wrote combined CSV: {out_name}  (rows: {len(combined)})")

if skipped:
    print(f"Skipped {len(skipped)} samples (no candidates after filtering).")
# Out:
# Wrote combined CSV: /Users/ecreed/Desktop/KelloggRotation/02052026_TagmentatioAnalysis_251218_260117_260203_combined/FilteredCandidateSpacersBulk/CandidateSpacers_AllSamples_filtered_combined.csv  (rows: 5230)

# %%
# v2 filtered candidate spacers single csv with insertion strand distribution and frequency collumns 
# bulk run + filtering by NGG and distance
# Bulk: write per-sample CSVs but only include NGG guides 66-76 bp from their mcv
# ENHANCED: add strand distribution and hotspot frequency columns

import re
import pandas as pd
from collections import Counter
from pathlib import Path

def revcomp(seq):
    comp = str.maketrans("ACGTacgt", "TGCAtgca")
    return seq.translate(comp)[::-1]

def _sample_id_from_name(p: Path):
    m = re.match(r"(\d+)_S\1_", p.name)
    return int(m.group(1)) if m else None

written = []
skipped = []
all_rows = []

for nn, tsv_path in enumerate(tsv_files):
    sample_id = _sample_id_from_name(tsv_path) or (nn + 1)

    # load + basic filter (min_mapq expected in notebook)
    tsv = pd.read_csv(tsv_path, sep="\t")
    tsv = tsv[tsv["mapq"] >= min_mapq]
    
    # Calculate total insertions in sample and strand counts per insertion position
    total_insertions = len(tsv)
    insertion_strands = {}  # {position: {'+': count, '-': count}}
    for _, row in tsv.iterrows():
        pos = row["ins0"]
        strand = row.get("strand", "+")  # default to + if not present
        if pos not in insertion_strands:
            insertion_strands[pos] = {'+': 0, '-': 0}
        insertion_strands[pos][strand] = insertion_strands[pos].get(strand, 0) + 1

    # collapse hotspots (same logic as before)
    collapse_bp = 5
    min_reads = 500

    counts = Counter(tsv["ins0"])
    gmap = php.map_guide_to_genome(guideRNA["protospacer"][nn], genome_sequence)
    target_position = gmap[0]["start"]
    counts[target_position] = counts.get(target_position, 0)

    clusters = [{"members": {pos: freq}, "total": freq} for pos, freq in counts.items()]
    merged = True
    while merged:
        merged = False
        new_clusters = []
        while clusters:
            c = clusters.pop(0)
            i = 0
            while i < len(clusters):
                other = clusters[i]
                close = any(abs(p - q) <= collapse_bp for p in c["members"] for q in other["members"])
                if close:
                    for p, f in other["members"].items():
                        c["members"][p] = c["members"].get(p, 0) + f
                    c["total"] += other["total"]
                    clusters.pop(i)
                    merged = True
                else:
                    i += 1
            new_clusters.append(c)
        clusters = new_clusters

    clusters_info = []
    for c in clusters:
        rep_pos, rep_count = max(c["members"].items(), key=lambda x: x[1])
        clusters_info.append({
            "rep_pos": int(rep_pos),
            "rep_count": int(rep_count),
            "total": int(c["total"]),
            "members": sorted(c["members"].keys()),
            "contains_target": (target_position in c["members"])
        })

    filtered = [c for c in clusters_info if c["total"] > min_reads]
    if not any(c["contains_target"] for c in filtered):
        for c in clusters_info:
            if c["contains_target"]:
                filtered.append(c)
                break

    filtered.sort(key=lambda x: x["total"], reverse=True)
    for idx, c in enumerate(filtered, start=1):
        c["mcv_id"] = idx

    mcv_list = [c["rep_pos"] for c in filtered]
    hotspots = {f"mcv{idx}": pos for idx, pos in enumerate(mcv_list, start=1)}
    for idx, pos in enumerate(mcv_list, start=1):
        globals()[f"mcv{idx}"] = pos

    # Generate guides (methods 1,2,3) exactly as before
    original_guide = guideRNA["protospacer"][nn]
    hotspots_dict = hotspots if (isinstance(hotspots, dict) and hotspots) else ({f"mcv{i+1}": pos for i,pos in enumerate(mcv_list)} if "mcv_list" in globals() else {})
    _alignment_ctx = {}
    for hotspot_name, insertion_site in hotspots_dict.items():
        window_start = max(0, insertion_site - 120)
        window_end = min(len(genome_sequence), insertion_site + 120)
        window_seq = genome_sequence[window_start:window_end]

        aln_fwd = php.local_align(original_guide, window_seq)
        aln_rev = php.local_align(original_guide, revcomp(window_seq))

        if aln_fwd.score >= aln_rev.score:
            best_aln = aln_fwd
            best_strand = "+"
            search_seq = window_seq
        else:
            best_aln = aln_rev
            best_strand = "-"
            search_seq = revcomp(window_seq)

        _alignment_ctx[hotspot_name] = {
            "insertion_site": insertion_site,
            "window_start": window_start,
            "window_end": window_end,
            "window_seq": window_seq,
            "best_aln": best_aln,
            "best_strand": best_strand,
            "search_seq": search_seq,
        }

    rows = []

    window_radius = 120
    # Method 1
    for hotspot_name, insertion_site in hotspots_dict.items():
        win_start = max(0, insertion_site - window_radius)
        win_end = min(len(genome_sequence), insertion_site + window_radius)
        win_seq = genome_sequence[win_start:win_end]

        for i in range(len(win_seq) - 2):
            pam = win_seq[i:i+3]
            if pam[1:3] == "GG":
                pam_genomic_start = win_start + i
                pam_genomic_end = pam_genomic_start + 3
                guide_start = pam_genomic_start - 20
                guide_end = pam_genomic_start
                if guide_start < 0:
                    continue
                guide_seq = genome_sequence[guide_start:guide_end]
                dist = abs((pam_genomic_end - 1) - insertion_site)
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 1,
                    "pam_type": "NGG",
                    "pam_seq": pam,
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "+",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(dist),
                    "insertion_site": int(insertion_site)
                })

        for i in range(len(win_seq) - 2):
            motif = win_seq[i:i+3]
            if motif[0:2] == "CC":
                pam_genomic_start = win_start + i
                pam_genomic_end = pam_genomic_start + 3
                guide_start = pam_genomic_end
                guide_end = guide_start + 20
                if guide_end > len(genome_sequence):
                    continue
                guide_seq = revcomp(genome_sequence[guide_start:guide_end])
                dist = abs(pam_genomic_start - insertion_site)
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 1,
                    "pam_type": "NGG",
                    "pam_seq": revcomp(motif),
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "-",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(dist),
                    "insertion_site": int(insertion_site)
                })

    # Method 2
    for hotspot_name, ctx in _alignment_ctx.items():
        insertion_site = ctx["insertion_site"]
        window_start = ctx["window_start"]
        window_seq = ctx["window_seq"]
        best_aln = ctx["best_aln"]
        best_strand = ctx["best_strand"]
        search_seq = ctx["search_seq"]

        target_coords = best_aln.coordinates[1]
        target_start = int(target_coords[0])
        target_end = int(target_coords[-1])

        if best_strand == "+":
            genomic_start = window_start + target_start
            genomic_end = window_start + target_end
        else:
            genomic_start = window_start + (len(window_seq) - target_end)
            genomic_end = window_start + (len(window_seq) - target_start)

        coords_q = best_aln.coordinates[0]
        coords_t = best_aln.coordinates[1]

        query_seq = best_aln.query
        target_seq = best_aln.target

        first_match_query_pos = None
        first_match_target_pos = None
        query_pos = 0
        target_pos = 0
        for q, t in zip(query_seq, target_seq):
            if q != "-" and t != "-" and q == t:
                first_match_query_pos = query_pos
                first_match_target_pos = target_pos
                break
            if q != "-":
                query_pos += 1
            if t != "-":
                target_pos += 1

        if first_match_query_pos is not None:
            first_match_genomic = genomic_start + first_match_target_pos
            new_guide_start = first_match_genomic - first_match_query_pos
            new_guide_end = new_guide_start + 20
            if 0 <= new_guide_start and new_guide_end <= len(genome_sequence):
                if best_strand == "+":
                    new_guide = genome_sequence[new_guide_start:new_guide_end]
                    new_guide_gstart = new_guide_start
                    new_guide_gend = new_guide_end
                else:
                    new_guide = revcomp(genome_sequence[new_guide_start:new_guide_end])
                    new_guide_gstart = new_guide_start
                    new_guide_gend = new_guide_end

                if best_strand == "+":
                    five_prime_start = target_start - 3
                    five_prime_end = target_start
                    five_prime_seq = window_seq[five_prime_start:five_prime_end] if five_prime_start >= 0 else ""
                    distance_to_mcv = abs(new_guide_gstart - insertion_site)
                else:
                    five_prime_start = target_end
                    five_prime_end = target_end + 3
                    five_prime_seq = revcomp(window_seq)[five_prime_start:five_prime_end] if five_prime_end <= len(window_seq) else ""
                    distance_to_mcv = abs(new_guide_gend - insertion_site)

                pam_type = None
                pam_seq = five_prime_seq
                if len(pam_seq) == 3:
                    if pam_seq[1:3] == "GG":
                        pam_type = "NGG"
                    elif pam_seq[1:3] == "AG":
                        pam_type = "NAG"
                    elif pam_seq[1:3] == "GA":
                        pam_type = "NGA"

                if pam_type:
                    mismatch_count = sum(a != b for a, b in zip(original_guide, new_guide))
                    try:
                        aln_score = php.local_align(original_guide, new_guide).score
                    except Exception:
                        aln_score = None

                    rows.append({
                        "hotspot": hotspot_name,
                        "method": 2,
                        "pam_type": pam_type,
                        "pam_seq": pam_seq,
                        "guide_seq": new_guide,
                        "guide_start": int(new_guide_gstart),
                        "guide_end": int(new_guide_gend),
                        "strand": best_strand,
                        "mismatch_count": int(mismatch_count),
                        "alignment_score": aln_score,
                        "distance_to_mcv": int(distance_to_mcv),
                        "insertion_site": int(insertion_site)
                    })

    # Method 3
    for hotspot_name, ctx in _alignment_ctx.items():
        insertion_site = ctx["insertion_site"]
        window_start = ctx["window_start"]
        window_seq = ctx["window_seq"]
        best_aln = ctx["best_aln"]
        best_strand = ctx["best_strand"]

        target_coords = best_aln.coordinates[1]
        target_start = int(target_coords[0])
        target_end = int(target_coords[-1])

        if best_strand == "+":
            genomic_start = window_start + target_start
            genomic_end = window_start + target_end
        else:
            genomic_start = window_start + (len(window_seq) - target_end)
            genomic_end = window_start + (len(window_seq) - target_start)

        alignment_center = (genomic_start + genomic_end) // 2
        pam_search_start = max(0, alignment_center - 25)
        pam_search_end = min(len(genome_sequence), alignment_center + 25)
        pam_search_seq = genome_sequence[pam_search_start:pam_search_end]

        for i in range(len(pam_search_seq) - 2):
            pam_motif = pam_search_seq[i:i+3]
            pam_type = None
            if pam_motif[1:3] == "GG":
                pam_type = "NGG"
            elif pam_motif[1:3] == "AG":
                pam_type = "NAG"
            elif pam_motif[1:3] == "GA":
                pam_type = "NGA"
            if not pam_type:
                continue

            pam_genomic_start = pam_search_start + i
            pam_genomic_end = pam_genomic_start + 3

            guide_start = pam_genomic_start - 20
            guide_end = pam_genomic_start
            if guide_start >= 0:
                guide_seq = genome_sequence[guide_start:guide_end]
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                distance_to_mcv = abs(pam_genomic_end - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 3,
                    "pam_type": pam_type,
                    "pam_seq": genome_sequence[pam_genomic_start:pam_genomic_end],
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "+",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(distance_to_mcv),
                    "insertion_site": int(insertion_site)
                })

        for i in range(len(pam_search_seq) - 2):
            pam_motif = pam_search_seq[i:i+3]
            pam_type = None
            if pam_motif[0:2] == "CC":
                pam_type = "NGG"
            elif pam_motif[0:2] == "CT":
                pam_type = "NAG"
            elif pam_motif[0:2] == "TC":
                pam_type = "NGA"
            if not pam_type:
                continue

            pam_genomic_start = pam_search_start + i
            pam_genomic_end = pam_genomic_start + 3

            guide_start = pam_genomic_end
            guide_end = guide_start + 20
            if guide_end <= len(genome_sequence):
                guide_seq = revcomp(genome_sequence[guide_start:guide_end])
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                distance_to_mcv = abs(pam_genomic_start - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 3,
                    "pam_type": pam_type,
                    "pam_seq": revcomp(genome_sequence[pam_genomic_start:pam_genomic_end]),
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "-",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(distance_to_mcv),
                    "insertion_site": int(insertion_site)
                })

    # assemble DataFrame and compute PAM coords
    def compute_pam_coords(row):
        try:
            gs = int(row['guide_start']); ge = int(row['guide_end']); strand = row['strand']
        except Exception:
            return pd.Series([None, None])
        if strand == "+":
            return pd.Series([ge, ge + 3])
        else:
            return pd.Series([gs - 3, gs])

    df = pd.DataFrame(rows)
    if df.empty:
        skipped.append((sample_id, str(tsv_path), "No candidates generated"))
        continue

    df[['pam_start', 'pam_end']] = df.apply(compute_pam_coords, axis=1)
    df = df.dropna(subset=['pam_start','pam_end']).reset_index(drop=True)
    df['pam_start'] = df['pam_start'].astype(int)
    df['pam_end'] = df['pam_end'].astype(int)

    pams_unique = df[['hotspot','pam_start','pam_end','pam_type']].drop_duplicates().reset_index(drop=True)
    def overlap(a_s, a_e, b_s, b_e):
        return (a_s < b_e) and (b_s < a_e)

    pams_unique['overlap_any'] = False
    pams_unique['overlap_noncanonical'] = False
    pams_unique['adj_left_any'] = False
    pams_unique['adj_left_noncanonical'] = False
    pams_unique['adj_right_any'] = False
    pams_unique['adj_right_noncanonical'] = False

    for idx, p in pams_unique.iterrows():
        ps, pe, ptype, hotspot = int(p.pam_start), int(p.pam_end), p.pam_type, p.hotspot
        partners = pams_unique[(pams_unique.hotspot == hotspot) & ~((pams_unique.pam_start == ps) & (pams_unique.pam_end == pe))]
        for _, q in partners.iterrows():
            qs, qe, qtype = int(q.pam_start), int(q.pam_end), q.pam_type
            if overlap(ps,pe,qs,qe):
                pams_unique.at[idx,'overlap_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'overlap_noncanonical'] = True
            if qe == ps:
                pams_unique.at[idx,'adj_left_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'adj_left_noncanonical'] = True
            if qs == pe:
                pams_unique.at[idx,'adj_right_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'adj_right_noncanonical'] = True

    df = df.merge(pams_unique, on=['hotspot','pam_start','pam_end','pam_type'], how='left', suffixes=('','_u'))
    
    # Keep only NGG rows and then further filter 66-76 bp
    df_ngg = df[df['pam_type'] == 'NGG'].copy()
    df_ngg_filtered = df_ngg[df_ngg['distance_to_mcv'].between(66, 76)].copy()

    if df_ngg_filtered.empty:
        skipped.append((sample_id, str(tsv_path), "No NGG candidates 66-76 bp"))
        continue

    # Add two new columns: strand_distribution and integration_frequency
    # strand_distribution: "#+ vs #-" format showing insertion counts at that hotspot by strand
    # integration_frequency: percentage of total sample insertions at this hotspot
    df_ngg_filtered['strand_distribution'] = df_ngg_filtered['insertion_site'].apply(
        lambda pos: f"{insertion_strands.get(pos, {'+': 0, '-': 0})['+']}/{insertion_strands.get(pos, {'+': 0, '-': 0})['-']}"
    )
    df_ngg_filtered['integration_frequency'] = df_ngg_filtered['insertion_site'].apply(
        lambda pos: f"{100.0 * (insertion_strands.get(pos, {'+': 0, '-': 0})['+'] + insertion_strands.get(pos, {'+': 0, '-': 0})['-']) / total_insertions:.2f}%"
    )
    
    # Rename 'strand' column to 'pam_strand' for clarity
    df_ngg_filtered = df_ngg_filtered.rename(columns={'strand': 'pam_strand'})
    
    # relabel hotspot with sample prefix: [sample]_mcv[n]
    df_ngg_filtered['hotspot'] = df_ngg_filtered['hotspot'].apply(lambda h: f"{sample_id}_{h}")

    # collect rows for global aggregation
    all_rows.append(df_ngg_filtered)

# combine all samples and write one CSV
if not all_rows:
    print("No candidates across samples after filtering.")
else:
    combined = pd.concat(all_rows, ignore_index=True)
    out_name = output_csv_dir / "CandidateSpacers_AllSamples_filtered_combined.csv"
    combined.to_csv(out_name, index=False)
    print(f"Wrote combined CSV: {out_name}  (rows: {len(combined)})")

if skipped:
    print(f"Skipped {len(skipped)} samples (no candidates after filtering).")
# Out:
# Wrote combined CSV: /Users/ecreed/Desktop/KelloggRotation/02052026_TagmentatioAnalysis_251218_260117_260203_combined/FilteredCandidateSpacersBulk/CandidateSpacers_AllSamples_filtered_combined.csv  (rows: 5230)

# %%
# v1 filtered candidate spacers on single csv
# formatted as [sampleID]_mcv[n]
# Aggregate all samples: write single CSV containing only NGG guides 66-76 bp from each sample's MCVs
import re
import pandas as pd
from collections import Counter
from pathlib import Path

def revcomp(seq):
    comp = str.maketrans("ACGTacgt", "TGCAtgca")
    return seq.translate(comp)[::-1]

def _sample_id_from_name(p: Path):
    m = re.match(r"(\d+)_S\1_", p.name)
    return int(m.group(1)) if m else None

all_rows = []
skipped = []

for nn, tsv_path in enumerate(tsv_files):
    sample_id = _sample_id_from_name(tsv_path) or (nn + 1)

    # load + basic filter
    tsv = pd.read_csv(tsv_path, sep="\t")
    tsv = tsv[tsv["mapq"] >= min_mapq]

    # collapse hotspots (same logic as before)
    collapse_bp = 5
    min_reads = 1000

    counts = Counter(tsv["ins0"])
    gmap = php.map_guide_to_genome(guideRNA["protospacer"][nn], genome_sequence)
    target_position = gmap[0]["start"]
    counts[target_position] = counts.get(target_position, 0)

    clusters = [{"members": {pos: freq}, "total": freq} for pos, freq in counts.items()]
    merged = True
    while merged:
        merged = False
        new_clusters = []
        while clusters:
            c = clusters.pop(0)
            i = 0
            while i < len(clusters):
                other = clusters[i]
                close = any(abs(p - q) <= collapse_bp for p in c["members"] for q in other["members"])
                if close:
                    for p, f in other["members"].items():
                        c["members"][p] = c["members"].get(p, 0) + f
                    c["total"] += other["total"]
                    clusters.pop(i)
                    merged = True
                else:
                    i += 1
            new_clusters.append(c)
        clusters = new_clusters

    clusters_info = []
    for c in clusters:
        rep_pos, rep_count = max(c["members"].items(), key=lambda x: x[1])
        clusters_info.append({
            "rep_pos": int(rep_pos),
            "rep_count": int(rep_count),
            "total": int(c["total"]),
            "members": sorted(c["members"].keys()),
            "contains_target": (target_position in c["members"])
        })

    filtered = [c for c in clusters_info if c["total"] > min_reads]
    if not any(c["contains_target"] for c in filtered):
        for c in clusters_info:
            if c["contains_target"]:
                filtered.append(c)
                break

    filtered.sort(key=lambda x: x["total"], reverse=True)
    for idx, c in enumerate(filtered, start=1):
        c["mcv_id"] = idx

    if not filtered:
        skipped.append((sample_id, str(tsv_path), "no MCVs passing filter"))
        continue

    mcv_list = [c["rep_pos"] for c in filtered]
    hotspots = {f"mcv{idx}": pos for idx, pos in enumerate(mcv_list, start=1)}

    # build alignment context
    original_guide = guideRNA["protospacer"][nn]
    _alignment_ctx = {}
    for hotspot_name, insertion_site in hotspots.items():
        window_start = max(0, insertion_site - 120)
        window_end = min(len(genome_sequence), insertion_site + 120)
        window_seq = genome_sequence[window_start:window_end]

        aln_fwd = php.local_align(original_guide, window_seq)
        aln_rev = php.local_align(original_guide, revcomp(window_seq))

        if aln_fwd.score >= aln_rev.score:
            best_aln = aln_fwd
            best_strand = "+"
            search_seq = window_seq
        else:
            best_aln = aln_rev
            best_strand = "-"
            search_seq = revcomp(window_seq)

        _alignment_ctx[hotspot_name] = {
            "insertion_site": insertion_site,
            "window_start": window_start,
            "window_end": window_end,
            "window_seq": window_seq,
            "best_aln": best_aln,
            "best_strand": best_strand,
            "search_seq": search_seq,
        }

    # generate all method candidates (same logic)
    rows = []
    window_radius = 120

    # Method 1
    for hotspot_name, insertion_site in hotspots.items():
        win_start = max(0, insertion_site - window_radius)
        win_end = min(len(genome_sequence), insertion_site + window_radius)
        win_seq = genome_sequence[win_start:win_end]

        for i in range(len(win_seq) - 2):
            pam = win_seq[i:i+3]
            if pam[1:3] == "GG":
                pam_genomic_start = win_start + i
                pam_genomic_end = pam_genomic_start + 3
                guide_start = pam_genomic_start - 20
                guide_end = pam_genomic_start
                if guide_start < 0:
                    continue
                guide_seq = genome_sequence[guide_start:guide_end]
                dist = abs((pam_genomic_end - 1) - insertion_site)
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 1,
                    "pam_type": "NGG",
                    "pam_seq": pam,
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "+",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(dist),
                    "insertion_site": int(insertion_site)
                })

        for i in range(len(win_seq) - 2):
            motif = win_seq[i:i+3]
            if motif[0:2] == "CC":
                pam_genomic_start = win_start + i
                pam_genomic_end = pam_genomic_start + 3
                guide_start = pam_genomic_end
                guide_end = guide_start + 20
                if guide_end > len(genome_sequence):
                    continue
                guide_seq = revcomp(genome_sequence[guide_start:guide_end])
                dist = abs(pam_genomic_start - insertion_site)
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 1,
                    "pam_type": "NGG",
                    "pam_seq": revcomp(motif),
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "-",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(dist),
                    "insertion_site": int(insertion_site)
                })

    # Method 2
    for hotspot_name, ctx in _alignment_ctx.items():
        insertion_site = ctx["insertion_site"]
        window_start = ctx["window_start"]
        window_seq = ctx["window_seq"]
        best_aln = ctx["best_aln"]
        best_strand = ctx["best_strand"]
        search_seq = ctx["search_seq"]

        target_coords = best_aln.coordinates[1]
        target_start = int(target_coords[0])
        target_end = int(target_coords[-1])

        if best_strand == "+":
            genomic_start = window_start + target_start
            genomic_end = window_start + target_end
        else:
            genomic_start = window_start + (len(window_seq) - target_end)
            genomic_end = window_start + (len(window_seq) - target_start)

        query_seq = best_aln.query
        target_seq = best_aln.target

        first_match_query_pos = None
        first_match_target_pos = None
        query_pos = 0
        target_pos = 0
        for q, t in zip(query_seq, target_seq):
            if q != '-' and t != '-' and q == t:
                first_match_query_pos = query_pos
                first_match_target_pos = target_pos
                break
            if q != '-':
                query_pos += 1
            if t != '-':
                target_pos += 1

        if first_match_query_pos is not None:
            first_match_genomic = genomic_start + first_match_target_pos
            new_guide_start = first_match_genomic - first_match_query_pos
            new_guide_end = new_guide_start + 20
            if 0 <= new_guide_start and new_guide_end <= len(genome_sequence):
                if best_strand == "+":
                    new_guide = genome_sequence[new_guide_start:new_guide_end]
                    new_guide_gstart = new_guide_start
                    new_guide_gend = new_guide_end
                else:
                    new_guide = revcomp(genome_sequence[new_guide_start:new_guide_end])
                    new_guide_gstart = new_guide_start
                    new_guide_gend = new_guide_end

                if best_strand == "+":
                    five_prime_start = target_start - 3
                    five_prime_end = target_start
                    five_prime_seq = window_seq[five_prime_start:five_prime_end] if five_prime_start >= 0 else ""
                    distance_to_mcv = abs(new_guide_gstart - insertion_site)
                else:
                    five_prime_start = target_end
                    five_prime_end = target_end + 3
                    five_prime_seq = revcomp(window_seq)[five_prime_start:five_prime_end] if five_prime_end <= len(window_seq) else ""
                    distance_to_mcv = abs(new_guide_gend - insertion_site)

                pam_type = None
                pam_seq = five_prime_seq
                if len(pam_seq) == 3:
                    if pam_seq[1:3] == "GG":
                        pam_type = "NGG"
                    elif pam_seq[1:3] == "AG":
                        pam_type = "NAG"
                    elif pam_seq[1:3] == "GA":
                        pam_type = "NGA"

                if pam_type:
                    mismatch_count = sum(a != b for a, b in zip(original_guide, new_guide))
                    try:
                        aln_score = php.local_align(original_guide, new_guide).score
                    except Exception:
                        aln_score = None

                    rows.append({
                        "hotspot": hotspot_name,
                        "method": 2,
                        "pam_type": pam_type,
                        "pam_seq": pam_seq,
                        "guide_seq": new_guide,
                        "guide_start": int(new_guide_gstart),
                        "guide_end": int(new_guide_gend),
                        "strand": best_strand,
                        "mismatch_count": int(mismatch_count),
                        "alignment_score": aln_score,
                        "distance_to_mcv": int(distance_to_mcv),
                        "insertion_site": int(insertion_site)
                    })

    # Method 3
    for hotspot_name, ctx in _alignment_ctx.items():
        insertion_site = ctx["insertion_site"]
        window_start = ctx["window_start"]
        window_seq = ctx["window_seq"]
        best_aln = ctx["best_aln"]
        best_strand = ctx["best_strand"]

        target_coords = best_aln.coordinates[1]
        target_start = int(target_coords[0])
        target_end = int(target_coords[-1])

        if best_strand == "+":
            genomic_start = window_start + target_start
            genomic_end = window_start + target_end
        else:
            genomic_start = window_start + (len(window_seq) - target_end)
            genomic_end = window_start + (len(window_seq) - target_start)

        alignment_center = (genomic_start + genomic_end) // 2
        pam_search_start = max(0, alignment_center - 25)
        pam_search_end = min(len(genome_sequence), alignment_center + 25)
        pam_search_seq = genome_sequence[pam_search_start:pam_search_end]

        for i in range(len(pam_search_seq) - 2):
            pam_motif = pam_search_seq[i:i+3]
            pam_type = None
            if pam_motif[1:3] == "GG":
                pam_type = "NGG"
            elif pam_motif[1:3] == "AG":
                pam_type = "NAG"
            elif pam_motif[1:3] == "GA":
                pam_type = "NGA"
            if not pam_type:
                continue

            pam_genomic_start = pam_search_start + i
            pam_genomic_end = pam_genomic_start + 3

            guide_start = pam_genomic_start - 20
            guide_end = pam_genomic_start
            if guide_start >= 0:
                guide_seq = genome_sequence[guide_start:guide_end]
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                distance_to_mcv = abs(pam_genomic_end - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 3,
                    "pam_type": pam_type,
                    "pam_seq": genome_sequence[pam_genomic_start:pam_genomic_end],
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "+",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(distance_to_mcv),
                    "insertion_site": int(insertion_site)
                })

        for i in range(len(pam_search_seq) - 2):
            pam_motif = pam_search_seq[i:i+3]
            pam_type = None
            if pam_motif[0:2] == "CC":
                pam_type = "NGG"
            elif pam_motif[0:2] == "CT":
                pam_type = "NAG"
            elif pam_motif[0:2] == "TC":
                pam_type = "NGA"
            if not pam_type:
                continue

            pam_genomic_start = pam_search_start + i
            pam_genomic_end = pam_genomic_start + 3

            guide_start = pam_genomic_end
            guide_end = guide_start + 20
            if guide_end <= len(genome_sequence):
                guide_seq = revcomp(genome_sequence[guide_start:guide_end])
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                distance_to_mcv = abs(pam_genomic_start - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 3,
                    "pam_type": pam_type,
                    "pam_seq": revcomp(genome_sequence[pam_genomic_start:pam_genomic_end]),
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "-",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(distance_to_mcv),
                    "insertion_site": int(insertion_site)
                })

    # assemble DataFrame and compute PAM coords and overlap/adjacency flags per sample
    def compute_pam_coords(row):
        try:
            gs = int(row['guide_start']); ge = int(row['guide_end']); strand = row['strand']
        except Exception:
            return pd.Series([None, None])
        if strand == "+":
            return pd.Series([ge, ge + 3])
        else:
            return pd.Series([gs - 3, gs])

    df = pd.DataFrame(rows)
    if df.empty:
        skipped.append((sample_id, str(tsv_path), "No candidates generated"))
        continue

    df[['pam_start', 'pam_end']] = df.apply(compute_pam_coords, axis=1)
    df = df.dropna(subset=['pam_start','pam_end']).reset_index(drop=True)
    df['pam_start'] = df['pam_start'].astype(int)
    df['pam_end'] = df['pam_end'].astype(int)

    pams_unique = df[['hotspot','pam_start','pam_end','pam_type']].drop_duplicates().reset_index(drop=True)
    def overlap(a_s, a_e, b_s, b_e):
        return (a_s < b_e) and (b_s < a_e)

    pams_unique['overlap_any'] = False
    pams_unique['overlap_noncanonical'] = False
    pams_unique['adj_left_any'] = False
    pams_unique['adj_left_noncanonical'] = False
    pams_unique['adj_right_any'] = False
    pams_unique['adj_right_noncanonical'] = False

    for idx, p in pams_unique.iterrows():
        ps, pe, ptype, hotspot = int(p.pam_start), int(p.pam_end), p.pam_type, p.hotspot
        partners = pams_unique[(pams_unique.hotspot == hotspot) & ~((pams_unique.pam_start == ps) & (pams_unique.pam_end == pe))]
        for _, q in partners.iterrows():
            qs, qe, qtype = int(q.pam_start), int(q.pam_end), q.pam_type
            if overlap(ps,pe,qs,qe):
                pams_unique.at[idx,'overlap_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'overlap_noncanonical'] = True
            if qe == ps:
                pams_unique.at[idx,'adj_left_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'adj_left_noncanonical'] = True
            if qs == pe:
                pams_unique.at[idx,'adj_right_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'adj_right_noncanonical'] = True

    df = df.merge(pams_unique, on=['hotspot','pam_start','pam_end','pam_type'], how='left', suffixes=('','_u'))

    # Keep only NGG rows and then further filter 66-76 bp
    df_ngg = df[df['pam_type'] == 'NGG'].copy()
    df_ngg_filtered = df_ngg[df_ngg['distance_to_mcv'].between(66, 76)].copy()

    if df_ngg_filtered.empty:
        skipped.append((sample_id, str(tsv_path), "No NGG candidates 66-76 bp"))
        continue

    # relabel hotspot with sample prefix: [sample]_mcv[n]
    df_ngg_filtered['hotspot'] = df_ngg_filtered['hotspot'].apply(lambda h: f"{sample_id}_{h}")

    # collect rows for global aggregation
    all_rows.append(df_ngg_filtered)

# combine all samples and write one CSV
if not all_rows:
    print("No candidates across samples after filtering.")
else:
    combined = pd.concat(all_rows, ignore_index=True)
    out_name = output_csv_dir / "CandidateSpacers_AllSamples_filtered_combined.csv"
    combined.to_csv(out_name, index=False)
    print(f"Wrote combined CSV: {out_name}  (rows: {len(combined)})")

if skipped:
    print(f"Skipped {len(skipped)} samples (no candidates after filtering).")
# Out:
# Wrote combined CSV: /Users/ecreed/Desktop/KelloggRotation/02052026_TagmentatioAnalysis_251218_260117_260203_combined/FilteredCandidateSpacersBulk/CandidateSpacers_AllSamples_filtered_combined.csv  (rows: 3425)

# %%
# go through each sample ID, for each sample does every mcv[n] have a reasonable candidate spacer?
# reasonable if has NGG PAM site adjacent to it and is 66-76 bp from mcv[n]
# Re-scan all samples and MCVs to check coverage
coverage_info = {}  # {sample_id: {mcv_name: [candidate_rows], ...}, ...}
missing_mcvs = []

for nn, tsv_path in enumerate(tsv_files):
    sample_id = _sample_id_from_name(tsv_path) or (nn + 1)
    
    # Load + filter TSV
    tsv = pd.read_csv(tsv_path, sep="\t")
    tsv = tsv[tsv["mapq"] >= min_mapq]
    
    # Collapse hotspots (exact copy of logic from bulk run)
    collapse_bp = 5
    min_reads = 1000
    
    counts = Counter(tsv["ins0"])
    gmap = php.map_guide_to_genome(guideRNA["protospacer"][nn], genome_sequence)
    target_position = gmap[0]["start"]
    counts[target_position] = counts.get(target_position, 0)
    
    clusters = [{"members": {pos: freq}, "total": freq} for pos, freq in counts.items()]
    merged = True
    while merged:
        merged = False
        new_clusters = []
        while clusters:
            c = clusters.pop(0)
            i = 0
            while i < len(clusters):
                other = clusters[i]
                close = any(abs(p - q) <= collapse_bp for p in c["members"] for q in other["members"])
                if close:
                    for p, f in other["members"].items():
                        c["members"][p] = c["members"].get(p, 0) + f
                    c["total"] += other["total"]
                    clusters.pop(i)
                    merged = True
                else:
                    i += 1
            new_clusters.append(c)
        clusters = new_clusters
    
    clusters_info = []
    for c in clusters:
        rep_pos, rep_count = max(c["members"].items(), key=lambda x: x[1])
        clusters_info.append({
            "rep_pos": int(rep_pos),
            "rep_count": int(rep_count),
            "total": int(c["total"]),
            "members": sorted(c["members"].keys()),
            "contains_target": (target_position in c["members"])
        })
    
    filtered = [c for c in clusters_info if c["total"] > min_reads]
    if not any(c["contains_target"] for c in filtered):
        for c in clusters_info:
            if c["contains_target"]:
                filtered.append(c)
                break
    
    filtered.sort(key=lambda x: x["total"], reverse=True)
    for idx, c in enumerate(filtered, start=1):
        c["mcv_id"] = idx
    
    mcv_list = [c["rep_pos"] for c in filtered]
    hotspots_dict = {f"mcv{idx}": pos for idx, pos in enumerate(mcv_list, start=1)}
    
    coverage_info[sample_id] = {}
    
    # Generate candidates (methods 1,2,3) — collect all rows per MCV
    original_guide = guideRNA["protospacer"][nn]
    
    _alignment_ctx = {}
    for hotspot_name, insertion_site in hotspots_dict.items():
        window_start = max(0, insertion_site - 120)
        window_end = min(len(genome_sequence), insertion_site + 120)
        window_seq = genome_sequence[window_start:window_end]
        
        aln_fwd = php.local_align(original_guide, window_seq)
        aln_rev = php.local_align(original_guide, revcomp(window_seq))
        
        if aln_fwd.score >= aln_rev.score:
            best_aln = aln_fwd
            best_strand = "+"
        else:
            best_aln = aln_rev
            best_strand = "-"
        
        _alignment_ctx[hotspot_name] = {
            "insertion_site": insertion_site,
            "window_start": window_start,
            "window_seq": window_seq,
            "best_aln": best_aln,
            "best_strand": best_strand,
        }
    
    rows = []
    window_radius = 120
    
    # Method 1 forward
    for hotspot_name, insertion_site in hotspots_dict.items():
        win_start = max(0, insertion_site - window_radius)
        win_end = min(len(genome_sequence), insertion_site + window_radius)
        win_seq = genome_sequence[win_start:win_end]
        
        for i in range(len(win_seq) - 2):
            pam = win_seq[i:i+3]
            if pam[1:3] == "GG":
                pam_genomic_start = win_start + i
                pam_genomic_end = pam_genomic_start + 3
                guide_start = pam_genomic_start - 20
                guide_end = pam_genomic_start
                if guide_start < 0:
                    continue
                guide_seq = genome_sequence[guide_start:guide_end]
                dist = abs((pam_genomic_end - 1) - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 1,
                    "pam_type": "NGG",
                    "pam_seq": pam,
                    "guide_seq": guide_seq,
                    "distance_to_mcv": int(dist),
                    "insertion_site": int(insertion_site)
                })
    
    # Method 1 reverse
    for hotspot_name, insertion_site in hotspots_dict.items():
        win_start = max(0, insertion_site - window_radius)
        win_end = min(len(genome_sequence), insertion_site + window_radius)
        win_seq = genome_sequence[win_start:win_end]
        
        for i in range(len(win_seq) - 2):
            motif = win_seq[i:i+3]
            if motif[0:2] == "CC":
                pam_genomic_start = win_start + i
                pam_genomic_end = pam_genomic_start + 3
                guide_start = pam_genomic_end
                guide_end = guide_start + 20
                if guide_end > len(genome_sequence):
                    continue
                guide_seq = revcomp(genome_sequence[guide_start:guide_end])
                dist = abs(pam_genomic_start - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 1,
                    "pam_type": "NGG",
                    "pam_seq": revcomp(motif),
                    "guide_seq": guide_seq,
                    "distance_to_mcv": int(dist),
                    "insertion_site": int(insertion_site)
                })
    
    # Method 2
    for hotspot_name, ctx in _alignment_ctx.items():
        insertion_site = ctx["insertion_site"]
        window_start = ctx["window_start"]
        window_seq = ctx["window_seq"]
        best_aln = ctx["best_aln"]
        best_strand = ctx["best_strand"]
        
        target_coords = best_aln.coordinates[1]
        target_start = int(target_coords[0])
        target_end = int(target_coords[-1])
        
        if best_strand == "+":
            genomic_start = window_start + target_start
        else:
            genomic_start = window_start + (len(window_seq) - target_end)
        
        query_seq = best_aln.query
        target_seq = best_aln.target
        
        first_match_query_pos = None
        first_match_target_pos = None
        query_pos = 0
        target_pos = 0
        for q, t in zip(query_seq, target_seq):
            if q != '-' and t != '-' and q == t:
                first_match_query_pos = query_pos
                first_match_target_pos = target_pos
                break
            if q != '-':
                query_pos += 1
            if t != '-':
                target_pos += 1
        
        if first_match_query_pos is not None:
            first_match_genomic = genomic_start + first_match_target_pos
            new_guide_start = first_match_genomic - first_match_query_pos
            new_guide_end = new_guide_start + 20
            if 0 <= new_guide_start and new_guide_end <= len(genome_sequence):
                if best_strand == "+":
                    new_guide = genome_sequence[new_guide_start:new_guide_end]
                    distance_to_mcv = abs(new_guide_start - insertion_site)
                    five_prime_start = target_start - 3
                    five_prime_end = target_start
                    five_prime_seq = window_seq[five_prime_start:five_prime_end] if five_prime_start >= 0 else ""
                else:
                    new_guide = revcomp(genome_sequence[new_guide_start:new_guide_end])
                    distance_to_mcv = abs(new_guide_end - insertion_site)
                    five_prime_start = target_end
                    five_prime_end = target_end + 3
                    five_prime_seq = revcomp(window_seq)[five_prime_start:five_prime_end] if five_prime_end <= len(window_seq) else ""
                
                pam_type = None
                pam_seq = five_prime_seq
                if len(pam_seq) == 3:
                    if pam_seq[1:3] == "GG":
                        pam_type = "NGG"
                
                if pam_type:
                    rows.append({
                        "hotspot": hotspot_name,
                        "method": 2,
                        "pam_type": pam_type,
                        "pam_seq": pam_seq,
                        "guide_seq": new_guide,
                        "distance_to_mcv": int(distance_to_mcv),
                        "insertion_site": int(insertion_site)
                    })
    
    # Method 3
    for hotspot_name, ctx in _alignment_ctx.items():
        insertion_site = ctx["insertion_site"]
        window_start = ctx["window_start"]
        window_seq = ctx["window_seq"]
        best_aln = ctx["best_aln"]
        best_strand = ctx["best_strand"]
        
        target_coords = best_aln.coordinates[1]
        target_start = int(target_coords[0])
        target_end = int(target_coords[-1])
        
        if best_strand == "+":
            genomic_start = window_start + target_start
            genomic_end = window_start + target_end
        else:
            genomic_start = window_start + (len(window_seq) - target_end)
            genomic_end = window_start + (len(window_seq) - target_start)
        
        alignment_center = (genomic_start + genomic_end) // 2
        pam_search_start = max(0, alignment_center - 25)
        pam_search_end = min(len(genome_sequence), alignment_center + 25)
        pam_search_seq = genome_sequence[pam_search_start:pam_search_end]
        
        for i in range(len(pam_search_seq) - 2):
            pam_motif = pam_search_seq[i:i+3]
            pam_type = None
            if pam_motif[1:3] == "GG":
                pam_type = "NGG"
            if not pam_type:
                continue
            
            pam_genomic_start = pam_search_start + i
            pam_genomic_end = pam_genomic_start + 3
            
            guide_start = pam_genomic_start - 20
            guide_end = pam_genomic_start
            if guide_start >= 0:
                guide_seq = genome_sequence[guide_start:guide_end]
                distance_to_mcv = abs(pam_genomic_end - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 3,
                    "pam_type": pam_type,
                    "pam_seq": genome_sequence[pam_genomic_start:pam_genomic_end],
                    "guide_seq": guide_seq,
                    "distance_to_mcv": int(distance_to_mcv),
                    "insertion_site": int(insertion_site)
                })
        
        for i in range(len(pam_search_seq) - 2):
            pam_motif = pam_search_seq[i:i+3]
            pam_type = None
            if pam_motif[0:2] == "CC":
                pam_type = "NGG"
            if not pam_type:
                continue
            
            pam_genomic_start = pam_search_start + i
            pam_genomic_end = pam_genomic_start + 3
            
            guide_start = pam_genomic_end
            guide_end = guide_start + 20
            if guide_end <= len(genome_sequence):
                guide_seq = revcomp(genome_sequence[guide_start:guide_end])
                distance_to_mcv = abs(pam_genomic_start - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 3,
                    "pam_type": pam_type,
                    "pam_seq": revcomp(genome_sequence[pam_genomic_start:pam_genomic_end]),
                    "guide_seq": guide_seq,
                    "distance_to_mcv": int(distance_to_mcv),
                    "insertion_site": int(insertion_site)
                })
    
    df = pd.DataFrame(rows)
    if not df.empty:
        # Filter to NGG and 66-76 bp
        df_ngg = df[df['pam_type'] == 'NGG'].copy()
        df_filtered = df_ngg[df_ngg['distance_to_mcv'].between(66, 76)].copy()
        
        # Store best candidate per MCV (highest alignment score or first method)
        for mcv_name in hotspots_dict.keys():
            mcv_rows = df_filtered[df_filtered['hotspot'] == mcv_name]
            if len(mcv_rows) > 0:
                coverage_info[sample_id][mcv_name] = mcv_rows
            else:
                missing_mcvs.append(f"{sample_id}_{mcv_name}")

# === REPORT ===
print("=" * 100)
print("MCV COVERAGE REPORT: NGG PAM, 66-76 bp from MCV")
print("=" * 100)

# Overall YES/NO
all_have_candidates = len(missing_mcvs) == 0
status = "YES - All samples/MCVs have reasonable candidates" if all_have_candidates else "NO - Some samples/MCVs missing candidates"
print(f"\nOVERALL STATUS: {status}\n")

# List missing MCVs
if missing_mcvs:
    print(f"MISSING CANDIDATE SPACERS ({len(missing_mcvs)}):")
    for m in sorted(missing_mcvs):
        print(f"  - {m}")
    print()

# Detailed summary per sample and per MCV
print("\nDETAILED SUMMARY BY SAMPLE:")
print("-" * 100)

for sample_id in sorted(coverage_info.keys()):
    sample_coverage = coverage_info[sample_id]
    num_mcvs = len(sample_coverage)
    has_all = (len(sample_coverage) > 0)
    
    print(f"\nSAMPLE {sample_id} ({num_mcvs} MCVs with candidates):")
    
    for mcv_name in sorted(sample_coverage.keys(), key=lambda x: int(x.replace('mcv',''))):
        mcv_rows = sample_coverage[mcv_name]
        print(f"  {mcv_name}:")
        
        for idx, (_, row) in enumerate(mcv_rows.iterrows(), 1):
            guide_seq = row['guide_seq']
            distance = row['distance_to_mcv']
            pam = row['pam_seq']
            method = row['method']
            
            print(f"    [{idx}] Method {method}: guide={guide_seq}  distance={distance}bp  PAM={pam}")
        
        if len(mcv_rows) == 0:
            print(f"    [MISSING] No NGG PAM 66-76 bp candidate")

print("\n" + "=" * 100)
# Out:
# ====================================================================================================
# MCV COVERAGE REPORT: NGG PAM, 66-76 bp from MCV
# ====================================================================================================
#
# OVERALL STATUS: NO - Some samples/MCVs missing candidates
#
# MISSING CANDIDATE SPACERS (7):
#   - 116_mcv10
#   - 25_mcv3
#   - 26_mcv4
#   - 37_mcv5
#   - 42_mcv7
#   - 48_mcv11
#   - 72_mcv5
#
#
# DETAILED SUMMARY BY SAMPLE:
# ----------------------------------------------------------------------------------------------------
#
# SAMPLE 1 (4 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=GGGATTTCAGGTCATCCCAG  distance=71bp  PAM=CGG
#     [2] Method 1: guide=GAAGCGGAATACCTGCCGGA  distance=67bp  PAM=AGG
#     [3] Method 1: guide=CACAATGAACAATAACGATC  distance=72bp  PAM=TGG
#     [4] Method 3: guide=GGGATTTCAGGTCATCCCAG  distance=70bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=ATCTCACCAATCAATACCTC  distance=76bp  PAM=TGG
#     [2] Method 1: guide=GACCACAATCAAGATCCCAG  distance=70bp  PAM=AGG
#     [3] Method 3: guide=GACCACAATCAAGATCCCAG  distance=70bp  PAM=AGG
#   mcv3:
#     [1] Method 1: guide=TGCAGCGGGTTAGTTCCCAG  distance=70bp  PAM=CGG
#     [2] Method 1: guide=CGAGCCGTTTGAAACGCCGC  distance=76bp  PAM=TGG
#     [3] Method 1: guide=CGGCACTAAGTGGACCGGCT  distance=71bp  PAM=GGG
#     [4] Method 1: guide=ACGGCACTAAGTGGACCGGC  distance=72bp  PAM=TGG
#     [5] Method 1: guide=TGGGACGGCACTAAGTGGAC  distance=76bp  PAM=CGG
#     [6] Method 3: guide=GGAGGCGCTGCGCTGTAGTC  distance=66bp  PAM=CGG
#     [7] Method 3: guide=CGGCACTAAGTGGACCGGCT  distance=71bp  PAM=GGG
#     [8] Method 3: guide=ACGGCACTAAGTGGACCGGC  distance=72bp  PAM=TGG
#     [9] Method 3: guide=TGGGACGGCACTAAGTGGAC  distance=76bp  PAM=CGG
#   mcv4:
#     [1] Method 1: guide=AAGTCGCCGCGCCACTGGTG  distance=72bp  PAM=TGG
#     [2] Method 1: guide=AGTCGCCGCGCCACTGGTGT  distance=71bp  PAM=GGG
#     [3] Method 1: guide=CGGTCGGGATAGTTTTCTTG  distance=66bp  PAM=CGG
#     [4] Method 1: guide=GGGACGCGCGAATTGAATTA  distance=70bp  PAM=TGG
#     [5] Method 1: guide=GGGTAAACTGGCTCGGATTA  distance=67bp  PAM=GGG
#     [6] Method 1: guide=CGGGTAAACTGGCTCGGATT  distance=68bp  PAM=AGG
#     [7] Method 1: guide=GCAGAGCGGGTAAACTGGCT  distance=74bp  PAM=CGG
#
# SAMPLE 2 (4 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=CTGACTAAACCGATTCACAG  distance=70bp  PAM=AGG
#     [2] Method 1: guide=GATGGATAAGCCGGTTAAGC  distance=71bp  PAM=TGG
#   mcv2:
#     [1] Method 1: guide=TCGCACAGCGTGTACCACAG  distance=72bp  PAM=CGG
#     [2] Method 1: guide=ACAGCGTGTACCACAGCGGA  distance=68bp  PAM=TGG
#     [3] Method 1: guide=TTAACGCCTCGAATCAGCAA  distance=72bp  PAM=CGG
#     [4] Method 3: guide=TCGCACAGCGTGTACCACAG  distance=71bp  PAM=CGG
#     [5] Method 3: guide=ACAGCGTGTACCACAGCGGA  distance=67bp  PAM=TGG
#   mcv3:
#     [1] Method 1: guide=CTTGCCATGCCAGCACCAAC  distance=71bp  PAM=AGG
#     [2] Method 1: guide=TTGCCATGCCAGCACCAACA  distance=70bp  PAM=GGG
#     [3] Method 1: guide=TGCCATGCCAGCACCAACAG  distance=69bp  PAM=GGG
#     [4] Method 1: guide=AAGTTCAGATACAACAAAGC  distance=72bp  PAM=CGG
#     [5] Method 1: guide=AGTTCAGATACAACAAAGCC  distance=73bp  PAM=GGG
#     [6] Method 1: guide=TAACAAAGCCGGGTAATTCC  distance=69bp  PAM=CGG
#   mcv4:
#     [1] Method 1: guide=CGGTAGCCAGCGCGGATCAT  distance=72bp  PAM=CGG
#
# SAMPLE 3 (4 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=ACTCCACAAACGCAGCGTGT  distance=76bp  PAM=TGG
#     [2] Method 1: guide=ACGCAGCGTGTTGGTCGCGT  distance=67bp  PAM=CGG
#     [3] Method 1: guide=TTGTGGCGTTTGAATTCCCA  distance=75bp  PAM=CGG
#     [4] Method 1: guide=TGTGGCGTTTGAATTCCCAC  distance=76bp  PAM=GGG
#     [5] Method 1: guide=GCTGGAATACGGTAACCCGT  distance=69bp  PAM=GGG
#     [6] Method 1: guide=GGCTGGAATACGGTAACCCG  distance=70bp  PAM=TGG
#   mcv2:
#     [1] Method 1: guide=GGCAGATGGCAACAGCCCGT  distance=71bp  PAM=CGG
#     [2] Method 1: guide=TTCGCGCCCGGCACCGGTGT  distance=71bp  PAM=CGG
#     [3] Method 3: guide=GGCAGATGGCAACAGCCCGT  distance=70bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=CCCGATTGTGGTGACGCCGC  distance=66bp  PAM=TGG
#     [2] Method 1: guide=CGGCACAGGCGAGTTCCCAG  distance=72bp  PAM=CGG
#     [3] Method 1: guide=TTTTCTAACAACCTGTGGGG  distance=68bp  PAM=GGG
#     [4] Method 1: guide=CTTTTCTAACAACCTGTGGG  distance=69bp  PAM=GGG
#     [5] Method 1: guide=ACTTTTCTAACAACCTGTGG  distance=70bp  PAM=GGG
#     [6] Method 1: guide=CACTTTTCTAACAACCTGTG  distance=71bp  PAM=GGG
#     [7] Method 1: guide=GCACTTTTCTAACAACCTGT  distance=72bp  PAM=GGG
#     [8] Method 1: guide=CGCACTTTTCTAACAACCTG  distance=73bp  PAM=TGG
#     [9] Method 3: guide=TTTTCTAACAACCTGTGGGG  distance=68bp  PAM=GGG
#     [10] Method 3: guide=CTTTTCTAACAACCTGTGGG  distance=69bp  PAM=GGG
#     [11] Method 3: guide=ACTTTTCTAACAACCTGTGG  distance=70bp  PAM=GGG
#     [12] Method 3: guide=CACTTTTCTAACAACCTGTG  distance=71bp  PAM=GGG
#     [13] Method 3: guide=GCACTTTTCTAACAACCTGT  distance=72bp  PAM=GGG
#     [14] Method 3: guide=CGCACTTTTCTAACAACCTG  distance=73bp  PAM=TGG
#   mcv4:
#     [1] Method 1: guide=CGGATTGACCGTAATGGGAT  distance=66bp  PAM=AGG
#     [2] Method 1: guide=CGTAATGGGATAGGTCACGT  distance=75bp  PAM=TGG
#     [3] Method 1: guide=TATTTTTGATGGCGTTAACT  distance=68bp  PAM=CGG
#
# SAMPLE 4 (3 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=GCGACTGTGTGCGAGCTGAA  distance=67bp  PAM=CGG
#     [2] Method 1: guide=CGACTGTGTGCGAGCTGAAC  distance=66bp  PAM=GGG
#     [3] Method 1: guide=GATATTGGCGCGGGCCAGTG  distance=70bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=GATTGAAGAGCAAGAACGGA  distance=72bp  PAM=TGG
#     [2] Method 1: guide=AGGTGATTGAAGAGCAAGAA  distance=68bp  PAM=CGG
#     [3] Method 1: guide=CCTGTGTCTGGTATTCAGTG  distance=69bp  PAM=TGG
#   mcv3:
#     [1] Method 1: guide=CAGACGTAGTGTGACGCGAT  distance=74bp  PAM=CGG
#     [2] Method 1: guide=CTGCGATGTCGGTTTCCGCG  distance=72bp  PAM=AGG
#
# SAMPLE 5 (4 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=ACGGCTGTTTTTAATGCCGC  distance=76bp  PAM=TGG
#     [2] Method 1: guide=CAGCACCAGCCCGGTAGCGC  distance=76bp  PAM=GGG
#     [3] Method 1: guide=CCAGCACCAGCCCGGTAGCG  distance=75bp  PAM=CGG
#     [4] Method 1: guide=GGTGGCTTCCAGCACCAGCC  distance=67bp  PAM=CGG
#     [5] Method 1: guide=ACACCTTCGACTTCCTCCAG  distance=70bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=GCAAAAATCTTCCAGTCCAG  distance=70bp  PAM=AGG
#     [2] Method 1: guide=AAAATCTTCCAGTCCAGAGG  distance=67bp  PAM=CGG
#     [3] Method 1: guide=CGGGCTGATGGCTGACCGGC  distance=67bp  PAM=TGG
#     [4] Method 1: guide=ATAGATAATTTCACCGCCTC  distance=76bp  PAM=TGG
#     [5] Method 3: guide=GCAAAAATCTTCCAGTCCAG  distance=69bp  PAM=AGG
#     [6] Method 3: guide=AAAATCTTCCAGTCCAGAGG  distance=66bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=GCCACCCAAAAATCAGCCTC  distance=76bp  PAM=TGG
#     [2] Method 1: guide=ATTCTGGAAAAAGTGCGTGA  distance=75bp  PAM=AGG
#     [3] Method 1: guide=TGCCCGCCGTTTACTTCCAG  distance=70bp  PAM=AGG
#     [4] Method 3: guide=TGCCCGCCGTTTACTTCCAG  distance=70bp  PAM=AGG
#   mcv4:
#     [1] Method 1: guide=GCACTGCAACAACGCTGCTT  distance=69bp  PAM=CGG
#     [2] Method 1: guide=GAAGGCGGCGGGCCATTACC  distance=68bp  PAM=AGG
#     [3] Method 1: guide=TTTCTTTCACAGATGTGGAT  distance=72bp  PAM=TGG
#
# SAMPLE 6 (3 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=AGATGACGCGGTGCGGGCGC  distance=73bp  PAM=AGG
#     [2] Method 1: guide=GATGACGCGGTGCGGGCGCA  distance=72bp  PAM=GGG
#     [3] Method 1: guide=ATGACGCGGTGCGGGCGCAG  distance=71bp  PAM=GGG
#     [4] Method 1: guide=CGCGGTGCGGGCGCAGGGGC  distance=67bp  PAM=TGG
#     [5] Method 3: guide=CGCGGTGCGGGCGCAGGGGC  distance=66bp  PAM=TGG
#   mcv2:
#     [1] Method 1: guide=ATACCATTAGCACTGGAAGT  distance=74bp  PAM=TGG
#     [2] Method 1: guide=TCAAACTATACCATTAGCAC  distance=67bp  PAM=TGG
#     [3] Method 1: guide=GTAAGGTCTTTGCGCAGAGG  distance=66bp  PAM=TGG
#     [4] Method 1: guide=CTGGTAAGGTCTTTGCGCAG  distance=69bp  PAM=AGG
#     [5] Method 3: guide=GTAAGGTCTTTGCGCAGAGG  distance=66bp  PAM=TGG
#     [6] Method 3: guide=CTGGTAAGGTCTTTGCGCAG  distance=69bp  PAM=AGG
#   mcv3:
#     [1] Method 1: guide=CTAACGCCTGGGTCGAACGC  distance=73bp  PAM=TGG
#     [2] Method 1: guide=TGGCAATTTAACCGCCAGTC  distance=69bp  PAM=AGG
#
# SAMPLE 7 (4 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=TCCAGCGGGTAGCACCCATG  distance=70bp  PAM=AGG
#     [2] Method 1: guide=AGCGGGTAGCACCCATGAGG  distance=67bp  PAM=CGG
#     [3] Method 1: guide=GATGGCCGTTAATCCAAGAG  distance=74bp  PAM=TGG
#   mcv2:
#     [1] Method 1: guide=GTGCCCGGCTTCTGACCATG  distance=69bp  PAM=CGG
#     [2] Method 1: guide=TGCAACCGAACGCGACCGCA  distance=76bp  PAM=TGG
#     [3] Method 1: guide=CACTGGATGGTGGCGCTGGA  distance=69bp  PAM=TGG
#     [4] Method 1: guide=CCTGCACTGGATGGTGGCGC  distance=73bp  PAM=TGG
#     [5] Method 3: guide=GTGCCCGGCTTCTGACCATG  distance=68bp  PAM=CGG
#     [6] Method 3: guide=TGCAACCGAACGCGACCGCA  distance=76bp  PAM=TGG
#   mcv3:
#     [1] Method 1: guide=GGTTGCGCACCGCCGGAGTA  distance=71bp  PAM=AGG
#     [2] Method 1: guide=GCCCTAACCGTTATACTATG  distance=70bp  PAM=GGG
#     [3] Method 1: guide=CGCCCTAACCGTTATACTAT  distance=71bp  PAM=GGG
#     [4] Method 1: guide=TCGCCCTAACCGTTATACTA  distance=72bp  PAM=TGG
#     [5] Method 3: guide=GCCCTAACCGTTATACTATG  distance=70bp  PAM=GGG
#     [6] Method 3: guide=CGCCCTAACCGTTATACTAT  distance=71bp  PAM=GGG
#     [7] Method 3: guide=TCGCCCTAACCGTTATACTA  distance=72bp  PAM=TGG
#   mcv4:
#     [1] Method 1: guide=ATTTCGCTGGTGGTCAGATG  distance=73bp  PAM=CGG
#     [2] Method 1: guide=TTTCGCTGGTGGTCAGATGC  distance=72bp  PAM=GGG
#     [3] Method 1: guide=GCTGGTGGTCAGATGCGGGA  distance=68bp  PAM=TGG
#     [4] Method 1: guide=TACTGTGAGCCAGAGTTGCC  distance=67bp  PAM=CGG
#     [5] Method 1: guide=ACTGCCTGAACTACCGCAGC  distance=74bp  PAM=CGG
#
# SAMPLE 8 (4 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=GTGTAAACGATCCTGCCGCG  distance=74bp  PAM=AGG
#     [2] Method 1: guide=TAAACGATCCTGCCGCGAGG  distance=71bp  PAM=CGG
#     [3] Method 1: guide=AAACGATCCTGCCGCGAGGC  distance=70bp  PAM=GGG
#     [4] Method 1: guide=CTCCACCCGGCGCGCCATGC  distance=66bp  PAM=TGG
#     [5] Method 1: guide=CGCGCCATGCTGGTTTCCAC  distance=76bp  PAM=TGG
#     [6] Method 1: guide=AATGTACGACCTCACACCAG  distance=70bp  PAM=TGG
#     [7] Method 3: guide=GTGTAAACGATCCTGCCGCG  distance=73bp  PAM=AGG
#     [8] Method 3: guide=TAAACGATCCTGCCGCGAGG  distance=70bp  PAM=CGG
#     [9] Method 3: guide=AAACGATCCTGCCGCGAGGC  distance=69bp  PAM=GGG
#   mcv2:
#     [1] Method 1: guide=AGCGCAGCACCATCACCGCG  distance=73bp  PAM=AGG
#     [2] Method 1: guide=GCAGCACCATCACCGCGAGG  distance=70bp  PAM=CGG
#     [3] Method 1: guide=GATGAAAGCTGGCTACAGGA  distance=66bp  PAM=AGG
#     [4] Method 1: guide=TGTTGATGAAAGCTGGCTAC  distance=70bp  PAM=AGG
#     [5] Method 3: guide=AGCGCAGCACCATCACCGCG  distance=72bp  PAM=AGG
#     [6] Method 3: guide=GCAGCACCATCACCGCGAGG  distance=69bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=CCGGTGCAGACTGAAATCAA  distance=71bp  PAM=CGG
#     [2] Method 1: guide=TTCCCAGCGTTGCTGCGAGG  distance=70bp  PAM=CGG
#     [3] Method 1: guide=TTCTTCCCAGCGTTGCTGCG  distance=73bp  PAM=AGG
#     [4] Method 3: guide=TTCCCAGCGTTGCTGCGAGG  distance=70bp  PAM=CGG
#     [5] Method 3: guide=TTCTTCCCAGCGTTGCTGCG  distance=73bp  PAM=AGG
#   mcv4:
#     [1] Method 1: guide=GCGCTCAGGTCAAATTCAGA  distance=66bp  PAM=CGG
#
# SAMPLE 9 (4 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=ATTACCGCCGTAACGCCCGC  distance=70bp  PAM=AGG
#     [2] Method 1: guide=ACATGCTGTTGAATTACCTG  distance=76bp  PAM=CGG
#     [3] Method 1: guide=TTCTTCTCATCGTCGCGTGG  distance=71bp  PAM=TGG
#     [4] Method 1: guide=ACTTTCTTCTCATCGTCGCG  distance=74bp  PAM=TGG
#   mcv2:
#     [1] Method 1: guide=AATCTGGAAATTTTTCGGCG  distance=73bp  PAM=TGG
#     [2] Method 1: guide=CTGGAAATTTTTCGGCGTGG  distance=70bp  PAM=TGG
#     [3] Method 1: guide=GCCGAAAAACTGAAAAATAA  distance=67bp  PAM=CGG
#     [4] Method 1: guide=GATGGGCGCGTTCACCTCTA  distance=72bp  PAM=CGG
#     [5] Method 3: guide=AATCTGGAAATTTTTCGGCG  distance=72bp  PAM=TGG
#     [6] Method 3: guide=CTGGAAATTTTTCGGCGTGG  distance=69bp  PAM=TGG
#     [7] Method 3: guide=GCCGAAAAACTGAAAAATAA  distance=67bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=CGGTCAGTTGATTGTGGTGG  distance=70bp  PAM=TGG
#     [2] Method 1: guide=GAGCGGTCAGTTGATTGTGG  distance=73bp  PAM=TGG
#     [3] Method 1: guide=GCCGAGCGGTCAGTTGATTG  distance=76bp  PAM=TGG
#   mcv4:
#     [1] Method 1: guide=ACCACCGCACGATAGAGATT  distance=68bp  PAM=CGG
#     [2] Method 1: guide=CCACCGCACGATAGAGATTC  distance=67bp  PAM=GGG
#
# SAMPLE 10 (3 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=TTATTGTGTTCATCACCGCG  distance=70bp  PAM=TGG
#     [2] Method 1: guide=CAGCAGTACGCCTGCCGCGA  distance=75bp  PAM=CGG
#     [3] Method 1: guide=ATTCTCACGCGTTACCGTCG  distance=67bp  PAM=CGG
#     [4] Method 3: guide=TTATTGTGTTCATCACCGCG  distance=69bp  PAM=TGG
#   mcv2:
#     [1] Method 1: guide=CGGTTATATCGGTCCGGTGC  distance=72bp  PAM=CGG
#     [2] Method 1: guide=GCGCAGAAAATGGCGGTCAA  distance=67bp  PAM=CGG
#     [3] Method 1: guide=CCCAGTTGCAGCGCACGTTC  distance=75bp  PAM=CGG
#     [4] Method 1: guide=GGAACGCTTCTTCTGCCGCG  distance=71bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=GCGCTCAGGTCAAATTCAGA  distance=69bp  PAM=CGG
#
# SAMPLE 11 (2 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=CGGGATCGGCGTCACCCTGT  distance=70bp  PAM=GGG
#     [2] Method 1: guide=GCGGGATCGGCGTCACCCTG  distance=71bp  PAM=TGG
#     [3] Method 3: guide=CGGGATCGGCGTCACCCTGT  distance=70bp  PAM=GGG
#     [4] Method 3: guide=GCGGGATCGGCGTCACCCTG  distance=71bp  PAM=TGG
#   mcv2:
#     [1] Method 1: guide=TCGAGCTGGGTAATAAGCGT  distance=71bp  PAM=TGG
#     [2] Method 1: guide=TGCAACCGAACGCGACCGCA  distance=73bp  PAM=TGG
#
# SAMPLE 12 (5 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=GCATTTTTTTACGCAGACGA  distance=72bp  PAM=CGG
#     [2] Method 1: guide=TTTTACGCAGACGACGGCTA  distance=66bp  PAM=CGG
#     [3] Method 1: guide=GAAGTGATGTCTTCTATTGA  distance=75bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=CTGCAGATTGTGGCAGACGA  distance=70bp  PAM=CGG
#     [2] Method 1: guide=TCGTAGCGCGCCATTTGCCC  distance=67bp  PAM=CGG
#     [3] Method 1: guide=TAGCGCGCCATTTGCCCCGG  distance=70bp  PAM=CGG
#     [4] Method 1: guide=TGCCGGTGATTTTCATCTTC  distance=75bp  PAM=GGG
#     [5] Method 1: guide=ATGCCGGTGATTTTCATCTT  distance=76bp  PAM=CGG
#     [6] Method 3: guide=CTGCAGATTGTGGCAGACGA  distance=69bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=CAATATTGAAACCCACGGCA  distance=75bp  PAM=TGG
#     [2] Method 1: guide=GAAGCCAATATTGAAACCCA  distance=70bp  PAM=CGG
#     [3] Method 1: guide=GGTCATGGATGAGCAGACGA  distance=69bp  PAM=TGG
#     [4] Method 3: guide=GGTCATGGATGAGCAGACGA  distance=69bp  PAM=TGG
#   mcv4:
#     [1] Method 1: guide=AAATTATCGAGAAATATTTC  distance=67bp  PAM=TGG
#     [2] Method 1: guide=TATGCCTGCGTGAATGACGA  distance=69bp  PAM=GGG
#     [3] Method 1: guide=GTATGCCTGCGTGAATGACG  distance=70bp  PAM=AGG
#     [4] Method 3: guide=AAATTATCGAGAAATATTTC  distance=67bp  PAM=TGG
#   mcv5:
#     [1] Method 1: guide=TCGCACAGCGTGTACCACAG  distance=72bp  PAM=CGG
#     [2] Method 1: guide=ACAGCGTGTACCACAGCGGA  distance=68bp  PAM=TGG
#     [3] Method 1: guide=TTAACGCCTCGAATCAGCAA  distance=72bp  PAM=CGG
#
# SAMPLE 13 (3 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=CATTTTCAATCCGCACCTCG  distance=71bp  PAM=CGG
#     [2] Method 1: guide=CAGACGTAGTGTGACGCGAT  distance=68bp  PAM=CGG
#     [3] Method 1: guide=GAAGCAGAAGCCTGCGATGT  distance=67bp  PAM=CGG
#     [4] Method 1: guide=GAAATTATCGATGAGCGTGG  distance=74bp  PAM=TGG
#     [5] Method 3: guide=CATTTTCAATCCGCACCTCG  distance=70bp  PAM=CGG
#     [6] Method 3: guide=GAAGCAGAAGCCTGCGATGT  distance=67bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=CTGTTTCATGCCGCACCTCG  distance=70bp  PAM=CGG
#     [2] Method 1: guide=TGTTTCATGCCGCACCTCGC  distance=69bp  PAM=GGG
#     [3] Method 1: guide=CGACGAAGTGCTGGAAAACC  distance=67bp  PAM=CGG
#     [4] Method 1: guide=ATGCCGCGCGGCATTCCGGT  distance=73bp  PAM=GGG
#     [5] Method 1: guide=AATGCCGCGCGGCATTCCGG  distance=74bp  PAM=TGG
#     [6] Method 3: guide=CTGTTTCATGCCGCACCTCG  distance=69bp  PAM=CGG
#     [7] Method 3: guide=TGTTTCATGCCGCACCTCGC  distance=68bp  PAM=GGG
#     [8] Method 3: guide=CGACGAAGTGCTGGAAAACC  distance=67bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=TTCAATCAGCGTGCCGTCGG  distance=68bp  PAM=CGG
#     [2] Method 1: guide=CACGAGCATCATCCTCTGCA  distance=73bp  PAM=TGG
#
# SAMPLE 14 (4 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=GCCGATTTCTTATTTCACGA  distance=71bp  PAM=AGG
#     [2] Method 1: guide=CCGATTTCTTATTTCACGAA  distance=70bp  PAM=GGG
#     [3] Method 1: guide=CGATTTCTTATTTCACGAAG  distance=69bp  PAM=GGG
#     [4] Method 1: guide=AGCGAAAAATGAGGTGATTA  distance=66bp  PAM=TGG
#     [5] Method 1: guide=TAAAATTTGCCTTTCACATG  distance=66bp  PAM=AGG
#   mcv2:
#     [1] Method 1: guide=CACCGGCGATAGCGGCGAAG  distance=71bp  PAM=TGG
#     [2] Method 1: guide=ACCAACCGTTACGTGTTGTT  distance=67bp  PAM=TGG
#     [3] Method 1: guide=GATCGTGGTCGCCTCTGTAT  distance=72bp  PAM=CGG
#     [4] Method 3: guide=CACCGGCGATAGCGGCGAAG  distance=70bp  PAM=TGG
#     [5] Method 3: guide=ACCAACCGTTACGTGTTGTT  distance=67bp  PAM=TGG
#   mcv3:
#     [1] Method 1: guide=CAACCAGTCATAACCAGAAG  distance=70bp  PAM=TGG
#     [2] Method 1: guide=CCAGTCATAACCAGAAGTGG  distance=67bp  PAM=CGG
#     [3] Method 1: guide=TATTTAATGATGTGCCACGT  distance=73bp  PAM=CGG
#   mcv4:
#     [1] Method 1: guide=CAGCTTTCCGGCACCGCTTC  distance=75bp  PAM=TGG
#     [2] Method 1: guide=TCCGGCACCGCTTCTGGTGC  distance=69bp  PAM=CGG
#     [3] Method 1: guide=CGATTAAGTTGGGTAACGCC  distance=66bp  PAM=AGG
#     [4] Method 1: guide=GATTAAGTTGGGTAACGCCA  distance=67bp  PAM=GGG
#     [5] Method 1: guide=ATGGCGCTTTGCCTGGTTTC  distance=72bp  PAM=CGG
#     [6] Method 1: guide=CGTTTTACAACGTCGTGACT  distance=72bp  PAM=GGG
#     [7] Method 1: guide=TCGTTTTACAACGTCGTGAC  distance=73bp  PAM=TGG
#
# SAMPLE 15 (5 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=GATTAACCATAACCACACTC  distance=70bp  PAM=CGG
#     [2] Method 1: guide=GACAGTCTGTTCGGCACGCC  distance=68bp  PAM=AGG
#     [3] Method 1: guide=GAGGGGCAGAATAACCACAC  distance=73bp  PAM=CGG
#     [4] Method 3: guide=GATTAACCATAACCACACTC  distance=69bp  PAM=CGG
#     [5] Method 3: guide=GAGGGGCAGAATAACCACAC  distance=73bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=TGGCAGGTTTCCAGTACATC  distance=66bp  PAM=CGG
#     [2] Method 1: guide=CAATTGTAATAAAACTTCGC  distance=72bp  PAM=CGG
#     [3] Method 1: guide=GATTAACAAATATTTTGTCC  distance=69bp  PAM=CGG
#     [4] Method 1: guide=CAGTATTGATACCGGCACTC  distance=69bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=CGAAATGGCGTATGTGAATG  distance=71bp  PAM=CGG
#     [2] Method 1: guide=ACAGATTCGGATGGATGAAC  distance=67bp  PAM=TGG
#     [3] Method 1: guide=GATGGATGAACTGGCGAAAC  distance=76bp  PAM=TGG
#   mcv4:
#     [1] Method 1: guide=CCGGCACGATGATCACTCTC  distance=71bp  PAM=TGG
#     [2] Method 3: guide=CCGGCACGATGATCACTCTC  distance=70bp  PAM=TGG
#   mcv5:
#     [1] Method 1: guide=CCGCCGCCTTCATACTGCAC  distance=75bp  PAM=CGG
#     [2] Method 1: guide=CGCCGCCTTCATACTGCACC  distance=74bp  PAM=GGG
#     [3] Method 1: guide=CGCCTTCATACTGCACCGGG  distance=71bp  PAM=CGG
#     [4] Method 1: guide=GCCTTCATACTGCACCGGGC  distance=70bp  PAM=GGG
#     [5] Method 1: guide=TCATACTGCACCGGGCGGGA  distance=66bp  PAM=AGG
#     [6] Method 1: guide=GTTACGCGTTCGCTCATCGC  distance=72bp  PAM=CGG
#     [7] Method 1: guide=CGATGATCCGCGCTGGCTAC  distance=69bp  PAM=CGG
#     [8] Method 1: guide=GTCTGACCGATGATCCGCGC  distance=76bp  PAM=TGG
#
# SAMPLE 16 (3 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=TGAAGCCCTTTCGCTATGGC  distance=76bp  PAM=TGG
#     [2] Method 1: guide=AACGTGAAGCCCTTTCGCTA  distance=72bp  PAM=TGG
#     [3] Method 1: guide=AAATACGTAGTCATTCGTGA  distance=70bp  PAM=GGG
#     [4] Method 1: guide=TAAATACGTAGTCATTCGTG  distance=71bp  PAM=AGG
#   mcv2:
#     [1] Method 1: guide=ATGGGCGGAGTTTCAGGCGC  distance=73bp  PAM=TGG
#     [2] Method 1: guide=CGCAGCATGGGCGGAGTTTC  distance=67bp  PAM=AGG
#     [3] Method 1: guide=TCGACCGGGATAATCCGTGA  distance=70bp  PAM=CGG
#     [4] Method 3: guide=ATGGGCGGAGTTTCAGGCGC  distance=73bp  PAM=TGG
#     [5] Method 3: guide=CGCAGCATGGGCGGAGTTTC  distance=67bp  PAM=AGG
#   mcv3:
#     [1] Method 1: guide=CGGATAATGCGAACAGCGCA  distance=70bp  PAM=CGG
#     [2] Method 1: guide=CGCGAGGTGCGGATTGAAAA  distance=68bp  PAM=TGG
#
# SAMPLE 17 (4 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=GTCAGGAAATAGGTCACGAT  distance=71bp  PAM=CGG
#     [2] Method 1: guide=ATAATGGAGATGACATCGAA  distance=67bp  PAM=CGG
#     [3] Method 1: guide=TAATGGAGATGACATCGAAC  distance=68bp  PAM=GGG
#     [4] Method 1: guide=GCCGCTATTGGCGTTAAACC  distance=75bp  PAM=CGG
#     [5] Method 3: guide=GTCAGGAAATAGGTCACGAT  distance=70bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=TCGACATGCTGCTGGAACGC  distance=68bp  PAM=CGG
#     [2] Method 1: guide=CATGTAGTAAGTCACGTTGG  distance=68bp  PAM=TGG
#     [3] Method 1: guide=CAACATGTAGTAAGTCACGT  distance=71bp  PAM=TGG
#     [4] Method 3: guide=CATGTAGTAAGTCACGTTGG  distance=68bp  PAM=TGG
#     [5] Method 3: guide=CAACATGTAGTAAGTCACGT  distance=71bp  PAM=TGG
#   mcv3:
#     [1] Method 1: guide=GCGCCGCAATCAAGTCACGT  distance=71bp  PAM=TGG
#     [2] Method 1: guide=ATCATCTCTTGCGGCGAACG  distance=66bp  PAM=CGG
#   mcv4:
#     [1] Method 1: guide=CGTGCATCTGCCAGTTTGAG  distance=66bp  PAM=GGG
#     [2] Method 1: guide=CATTTAATGTTGATGAAAGC  distance=75bp  PAM=TGG
#
# SAMPLE 18 (6 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=TTCTGGAGCCACGATATCGG  distance=69bp  PAM=CGG
#     [2] Method 1: guide=GGCTTCTGGAGCCACGATAT  distance=72bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=GCCGTCCATACTGTCAAGCA  distance=73bp  PAM=CGG
#     [2] Method 1: guide=CGGTAACTGACCAAGCCCGG  distance=71bp  PAM=TGG
#     [3] Method 1: guide=TGCCGGTAACTGACCAAGCC  distance=74bp  PAM=CGG
#     [4] Method 3: guide=TGCCGGTAACTGACCAAGCC  distance=74bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=ACTGGCTTCGATGAAGATAT  distance=72bp  PAM=CGG
#     [2] Method 1: guide=GGCTTCGATGAAGATATCGG  distance=69bp  PAM=TGG
#     [3] Method 1: guide=AATGGGGCGCGGAAGTTATC  distance=68bp  PAM=TGG
#   mcv4:
#     [1] Method 1: guide=GCGAAGCATCAGAGAATTGA  distance=72bp  PAM=CGG
#     [2] Method 1: guide=TCTGGCAGGCCTGGGATCGG  distance=71bp  PAM=TGG
#     [3] Method 1: guide=GTCTCTGGCAGGCCTGGGAT  distance=74bp  PAM=CGG
#     [4] Method 3: guide=TCTGGCAGGCCTGGGATCGG  distance=71bp  PAM=TGG
#     [5] Method 3: guide=GTCTCTGGCAGGCCTGGGAT  distance=74bp  PAM=CGG
#   mcv5:
#     [1] Method 1: guide=CTGCCGGAGATAATCGAGAT  distance=72bp  PAM=CGG
#     [2] Method 1: guide=CCGGAGATAATCGAGATCGG  distance=69bp  PAM=CGG
#     [3] Method 1: guide=CGGAGATAATCGAGATCGGC  distance=68bp  PAM=GGG
#     [4] Method 1: guide=GGAGATAATCGAGATCGGCG  distance=67bp  PAM=GGG
#     [5] Method 1: guide=GAGATAATCGAGATCGGCGG  distance=66bp  PAM=GGG
#     [6] Method 1: guide=GTATCGAGCAATGCCAGTTC  distance=76bp  PAM=AGG
#     [7] Method 1: guide=TCAGGGGTTAGATCCTGAAC  distance=67bp  PAM=TGG
#   mcv6:
#     [1] Method 1: guide=ATCAGCGGGCGCGTCTCTCC  distance=73bp  PAM=AGG
#     [2] Method 1: guide=TCATACTGCACCGGGCGGGA  distance=68bp  PAM=AGG
#
# SAMPLE 19 (6 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=GCTGCCATCGGGATCTCTTG  distance=70bp  PAM=CGG
#     [2] Method 1: guide=TATCTCCCGTGGTACGGGGA  distance=66bp  PAM=AGG
#     [3] Method 1: guide=TCATTATCTCCCGTGGTACG  distance=70bp  PAM=GGG
#     [4] Method 1: guide=TTCATTATCTCCCGTGGTAC  distance=71bp  PAM=GGG
#     [5] Method 1: guide=TTTCATTATCTCCCGTGGTA  distance=72bp  PAM=CGG
#     [6] Method 3: guide=GCTGCCATCGGGATCTCTTG  distance=69bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=GTGACGTGTTGACGAAAGTG  distance=73bp  PAM=AGG
#     [2] Method 1: guide=GAGGTGATCATCAACGTACG  distance=72bp  PAM=TGG
#     [3] Method 3: guide=GAGGTGATCATCAACGTACG  distance=72bp  PAM=TGG
#   mcv3:
#     [1] Method 1: guide=GTCACGATCAGGTTTACGTA  distance=72bp  PAM=CGG
#     [2] Method 1: guide=TCACGATCAGGTTTACGTAC  distance=71bp  PAM=GGG
#     [3] Method 1: guide=CACGATCAGGTTTACGTACG  distance=70bp  PAM=GGG
#     [4] Method 3: guide=GTCACGATCAGGTTTACGTA  distance=71bp  PAM=CGG
#     [5] Method 3: guide=TCACGATCAGGTTTACGTAC  distance=70bp  PAM=GGG
#     [6] Method 3: guide=CACGATCAGGTTTACGTACG  distance=69bp  PAM=GGG
#   mcv4:
#     [1] Method 1: guide=CGAGAGCGACTGGTGTCAGA  distance=71bp  PAM=TGG
#     [2] Method 1: guide=CAGCGCATTGTTGTACGCGG  distance=66bp  PAM=TGG
#     [3] Method 1: guide=TTTCAGCGCATTGTTGTACG  distance=69bp  PAM=CGG
#     [4] Method 3: guide=TTTCAGCGCATTGTTGTACG  distance=69bp  PAM=CGG
#   mcv5:
#     [1] Method 1: guide=ACAAGGATCGGAGACGTACA  distance=70bp  PAM=CGG
#     [2] Method 3: guide=ACAAGGATCGGAGACGTACA  distance=69bp  PAM=CGG
#   mcv6:
#     [1] Method 1: guide=ATCCCAGCGGTCAAAACAGG  distance=67bp  PAM=CGG
#     [2] Method 1: guide=GGTCAAAACAGGCGGCAGTA  distance=75bp  PAM=AGG
#
# SAMPLE 20 (5 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=ACACGTTTCAACGATCCTGA  distance=71bp  PAM=AGG
#     [2] Method 1: guide=CACGTTTCAACGATCCTGAA  distance=70bp  PAM=GGG
#     [3] Method 1: guide=GTTTCAACGATCCTGAAGGG  distance=67bp  PAM=TGG
#   mcv2:
#     [1] Method 1: guide=TGTTGGGAACTGCTGATGAA  distance=70bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=GGTCAGAATTACGTGCTGAA  distance=71bp  PAM=CGG
#     [2] Method 1: guide=CAGAATTACGTGCTGAACGG  distance=68bp  PAM=CGG
#     [3] Method 1: guide=AACGTTTACGACGATCATCC  distance=67bp  PAM=CGG
#   mcv4:
#     [1] Method 1: guide=GATCCAGTAACTTCGCTGAA  distance=72bp  PAM=CGG
#     [2] Method 1: guide=GTAACTTCGCTGAACGGCAG  distance=66bp  PAM=CGG
#   mcv5:
#     [1] Method 1: guide=TCCTCTGCATGGTCAGGTCA  distance=68bp  PAM=TGG
#     [2] Method 1: guide=GTTGAACTGCACACCGCCGA  distance=75bp  PAM=CGG
#
# SAMPLE 21 (5 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=TTGTGTTGATATGCGCCACC  distance=74bp  PAM=AGG
#     [2] Method 1: guide=TGTGTTGATATGCGCCACCA  distance=75bp  PAM=GGG
#     [3] Method 1: guide=CTGGCAAAAACCGGAGCTGG  distance=67bp  PAM=TGG
#     [4] Method 1: guide=GAAGCACTGGAAAACCCTGG  distance=67bp  PAM=TGG
#     [5] Method 1: guide=GTTGAAGCACTGGAAAACCC  distance=70bp  PAM=TGG
#     [6] Method 3: guide=CTGGCAAAAACCGGAGCTGG  distance=67bp  PAM=TGG
#   mcv2:
#     [1] Method 1: guide=ATGTTACATTTTGGACTCAA  distance=66bp  PAM=AGG
#     [2] Method 1: guide=TGTTACATTTTGGACTCAAA  distance=67bp  PAM=GGG
#     [3] Method 1: guide=TTTGGACTCAAAGGGTTACC  distance=75bp  PAM=TGG
#     [4] Method 1: guide=TTGGACTCAAAGGGTTACCT  distance=76bp  PAM=GGG
#     [5] Method 1: guide=AACTGCCAATAATGCCCGGT  distance=67bp  PAM=AGG
#     [6] Method 1: guide=GCAAGTGAGTTTACTAACCC  distance=71bp  PAM=AGG
#   mcv3:
#     [1] Method 1: guide=CGTCTGCAACGGTTCCTTAA  distance=73bp  PAM=GGG
#     [2] Method 1: guide=TCGTCTGCAACGGTTCCTTA  distance=72bp  PAM=AGG
#     [3] Method 1: guide=AGAAGAGGGGAAAACCATGG  distance=69bp  PAM=TGG
#     [4] Method 1: guide=GGCAGAAGAGGGGAAAACCA  distance=72bp  PAM=TGG
#     [5] Method 3: guide=AGAAGAGGGGAAAACCATGG  distance=69bp  PAM=TGG
#     [6] Method 3: guide=GGCAGAAGAGGGGAAAACCA  distance=72bp  PAM=TGG
#   mcv4:
#     [1] Method 1: guide=TGTCGATAAATTTGAAACCC  distance=70bp  PAM=AGG
#     [2] Method 1: guide=TCTTATGGTCTGGGTAGCCT  distance=75bp  PAM=GGG
#     [3] Method 1: guide=TTCTTATGGTCTGGGTAGCC  distance=74bp  PAM=TGG
#     [4] Method 1: guide=GCTATCGGTTCTTATGGTCT  distance=66bp  PAM=GGG
#     [5] Method 3: guide=TGTCGATAAATTTGAAACCC  distance=69bp  PAM=AGG
#     [6] Method 3: guide=TCTTATGGTCTGGGTAGCCT  distance=75bp  PAM=GGG
#     [7] Method 3: guide=TTCTTATGGTCTGGGTAGCC  distance=74bp  PAM=TGG
#     [8] Method 3: guide=GCTATCGGTTCTTATGGTCT  distance=66bp  PAM=GGG
#   mcv5:
#     [1] Method 1: guide=CAACTGTTGGGAAGGGCGAT  distance=75bp  PAM=CGG
#     [2] Method 1: guide=GTTGGGAAGGGCGATCGGTG  distance=70bp  PAM=CGG
#     [3] Method 1: guide=TTGGGAAGGGCGATCGGTGC  distance=69bp  PAM=GGG
#     [4] Method 1: guide=CAGCTGGCGTAATAGCGAAG  distance=68bp  PAM=AGG
#     [5] Method 1: guide=AGCGGATAACAATTTCACAC  distance=67bp  PAM=AGG
#
# SAMPLE 22 (7 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=GGAATGCTGGCGGACCGTTA  distance=73bp  PAM=TGG
#     [2] Method 1: guide=ACCCGCGGCTTCAGACGTCA  distance=71bp  PAM=GGG
#     [3] Method 1: guide=GACCCGCGGCTTCAGACGTC  distance=72bp  PAM=AGG
#     [4] Method 3: guide=ACCCGCGGCTTCAGACGTCA  distance=71bp  PAM=GGG
#     [5] Method 3: guide=GACCCGCGGCTTCAGACGTC  distance=72bp  PAM=AGG
#   mcv2:
#     [1] Method 1: guide=CTGTGAGTCGGTTAGCTGTC  distance=71bp  PAM=AGG
#     [2] Method 1: guide=TGTGAGTCGGTTAGCTGTCA  distance=70bp  PAM=GGG
#     [3] Method 1: guide=ACACCATAGAGGTTTCCTGA  distance=69bp  PAM=TGG
#     [4] Method 1: guide=ATAGAGGTTTCCTGATGGAT  distance=74bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=AGAGTGATCATCGTGCCGGA  distance=69bp  PAM=TGG
#     [2] Method 1: guide=CATGGGGGTGTCCCGCGTCA  distance=70bp  PAM=CGG
#     [3] Method 3: guide=CATGGGGGTGTCCCGCGTCA  distance=70bp  PAM=CGG
#   mcv4:
#     [1] Method 1: guide=ATTAAAGGAGCTGCTCGAGA  distance=74bp  PAM=TGG
#     [2] Method 1: guide=GGCTGCAAACATGCGTCAGG  distance=67bp  PAM=GGG
#     [3] Method 1: guide=AGGCTGCAAACATGCGTCAG  distance=68bp  PAM=GGG
#     [4] Method 1: guide=CAGGCTGCAAACATGCGTCA  distance=69bp  PAM=GGG
#     [5] Method 1: guide=TCAGGCTGCAAACATGCGTC  distance=70bp  PAM=AGG
#     [6] Method 3: guide=GGCTGCAAACATGCGTCAGG  distance=67bp  PAM=GGG
#     [7] Method 3: guide=AGGCTGCAAACATGCGTCAG  distance=68bp  PAM=GGG
#     [8] Method 3: guide=CAGGCTGCAAACATGCGTCA  distance=69bp  PAM=GGG
#     [9] Method 3: guide=TCAGGCTGCAAACATGCGTC  distance=70bp  PAM=AGG
#   mcv5:
#     [1] Method 1: guide=TGCATTTAATTGCCGTAATC  distance=67bp  PAM=AGG
#     [2] Method 1: guide=TGAGAAACATGCCTGCGTCA  distance=70bp  PAM=CGG
#   mcv6:
#     [1] Method 1: guide=GCCGGGCAACGGCTCGCTGC  distance=66bp  PAM=TGG
#     [2] Method 1: guide=CATCGCGATATCCAGCGTCA  distance=70bp  PAM=TGG
#     [3] Method 3: guide=GGCCTGTCGCAGCCGGGCAA  distance=76bp  PAM=CGG
#   mcv7:
#     [1] Method 1: guide=TTTCAGCCGCGCTGTACTGG  distance=75bp  PAM=AGG
#     [2] Method 1: guide=TGATTTCAGCCGCGCTGTAC  distance=72bp  PAM=TGG
#     [3] Method 1: guide=ATGGTGCTGCGCTGGAGTGA  distance=68bp  PAM=CGG
#     [4] Method 1: guide=TCGCGGTGATGGTGCTGCGC  distance=76bp  PAM=TGG
#
# SAMPLE 23 (3 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=GTTGGCATCCTGGTCGCCTG  distance=70bp  PAM=CGG
#     [2] Method 1: guide=ATGGGGATGATCGAAATCTT  distance=68bp  PAM=TGG
#     [3] Method 1: guide=AATCAGGATCGAGGAGCCGC  distance=76bp  PAM=AGG
#     [4] Method 1: guide=GCCAGGAATAATCAGGATCG  distance=67bp  PAM=AGG
#     [5] Method 3: guide=GTTGGCATCCTGGTCGCCTG  distance=69bp  PAM=CGG
#     [6] Method 3: guide=AATCAGGATCGAGGAGCCGC  distance=76bp  PAM=AGG
#     [7] Method 3: guide=GCCAGGAATAATCAGGATCG  distance=67bp  PAM=AGG
#   mcv2:
#     [1] Method 1: guide=GGTAAATGAACTGGAAGCTG  distance=70bp  PAM=CGG
#     [2] Method 1: guide=GCAGCTATGGGCGCGATTGC  distance=74bp  PAM=AGG
#     [3] Method 1: guide=ACAGACCGAAATGCTGGTAT  distance=66bp  PAM=CGG
#     [4] Method 1: guide=TGCGATAAGTGGTTTATTAA  distance=75bp  PAM=AGG
#   mcv3:
#     [1] Method 1: guide=CCGCCGCCTTCATACTGCAC  distance=73bp  PAM=CGG
#     [2] Method 1: guide=CGCCGCCTTCATACTGCACC  distance=72bp  PAM=GGG
#     [3] Method 1: guide=CGCCTTCATACTGCACCGGG  distance=69bp  PAM=CGG
#     [4] Method 1: guide=GCCTTCATACTGCACCGGGC  distance=68bp  PAM=GGG
#     [5] Method 1: guide=GTTACGCGTTCGCTCATCGC  distance=74bp  PAM=CGG
#     [6] Method 1: guide=ATCTGTCGATCCTTCCCGCC  distance=76bp  PAM=CGG
#     [7] Method 1: guide=CGATGATCCGCGCTGGCTAC  distance=71bp  PAM=CGG
#
# SAMPLE 24 (3 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=TCATCGCCCCGCTCACGCAG  distance=70bp  PAM=CGG
#     [2] Method 1: guide=TCGCCCCGCTCACGCAGCGG  distance=67bp  PAM=CGG
#     [3] Method 3: guide=TCATCGCCCCGCTCACGCAG  distance=69bp  PAM=CGG
#     [4] Method 3: guide=TCGCCCCGCTCACGCAGCGG  distance=66bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=GCGGGCGATTTGCTCACGCG  distance=70bp  PAM=CGG
#     [2] Method 1: guide=TGATTATGCCCATCTGGAAC  distance=69bp  PAM=AGG
#     [3] Method 1: guide=TGGCGTTGATTATGCCCATC  distance=75bp  PAM=TGG
#     [4] Method 3: guide=GCGGGCGATTTGCTCACGCG  distance=69bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=GCACTGCAACAACGCTGCTT  distance=70bp  PAM=CGG
#     [2] Method 1: guide=GCAACAACGCTGCTTCGGCC  distance=75bp  PAM=TGG
#     [3] Method 1: guide=GATTGATGGTAGTGGTCAAA  distance=70bp  PAM=TGG
#     [4] Method 1: guide=GAAGGCGGCGGGCCATTACC  distance=71bp  PAM=AGG
#
# SAMPLE 25 (2 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=CCCAGGCGTTAGGGTCAATG  distance=71bp  PAM=CGG
#     [2] Method 1: guide=CCAGGCGTTAGGGTCAATGC  distance=70bp  PAM=GGG
#     [3] Method 1: guide=ATGGATTTTTGCATCGAGCT  distance=71bp  PAM=GGG
#     [4] Method 1: guide=AATGGATTTTTGCATCGAGC  distance=72bp  PAM=TGG
#     [5] Method 3: guide=CCCAGGCGTTAGGGTCAATG  distance=70bp  PAM=CGG
#     [6] Method 3: guide=CCAGGCGTTAGGGTCAATGC  distance=69bp  PAM=GGG
#   mcv2:
#     [1] Method 1: guide=GCTGGAAACCGTGCAACTGG  distance=74bp  PAM=CGG
#     [2] Method 1: guide=AACCGTGCAACTGGCGGAGC  distance=68bp  PAM=TGG
#     [3] Method 1: guide=AGTACCGGAGTCAATGCTGG  distance=68bp  PAM=CGG
#     [4] Method 1: guide=TTCAGTACCGGAGTCAATGC  distance=71bp  PAM=TGG
#     [5] Method 3: guide=GGCGCTGGAAACCGTGCAAC  distance=76bp  PAM=TGG
#     [6] Method 3: guide=GCTGGAAACCGTGCAACTGG  distance=73bp  PAM=CGG
#     [7] Method 3: guide=AACCGTGCAACTGGCGGAGC  distance=67bp  PAM=TGG
#
# SAMPLE 26 (3 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=TTATTACTGCCTATACCTAC  distance=71bp  PAM=TGG
#     [2] Method 1: guide=TGCTGTTCGCCTTCTCCACC  distance=70bp  PAM=TGG
#     [3] Method 1: guide=GCTGTTCGCCTTCTCCACCT  distance=71bp  PAM=GGG
#     [4] Method 1: guide=CGCCCCGTTGGTGGAAACCC  distance=66bp  PAM=AGG
#     [5] Method 1: guide=CAACATTTTCGCCCCGTTGG  distance=75bp  PAM=TGG
#     [6] Method 3: guide=TTATTACTGCCTATACCTAC  distance=70bp  PAM=TGG
#   mcv2:
#     [1] Method 1: guide=GGACGTCAATCATCATCATC  distance=69bp  PAM=AGG
#     [2] Method 1: guide=GCCGCCGGGCCAAAAGGGTA  distance=68bp  PAM=TGG
#     [3] Method 1: guide=TGGCGACTACCGTACAGGCA  distance=66bp  PAM=TGG
#     [4] Method 1: guide=TGATATGGCGACTACCGTAC  distance=71bp  PAM=AGG
#     [5] Method 3: guide=TGGCGACTACCGTACAGGCA  distance=66bp  PAM=TGG
#     [6] Method 3: guide=TGATATGGCGACTACCGTAC  distance=71bp  PAM=AGG
#   mcv3:
#     [1] Method 1: guide=GCCTGGAAGTACTGCTACGC  distance=67bp  PAM=TGG
#     [2] Method 1: guide=AGAATTAGAAAAAGTGCTGC  distance=72bp  PAM=CGG
#     [3] Method 1: guide=TTAGAAAAAGTGCTGCCGGT  distance=76bp  PAM=AGG
#     [4] Method 1: guide=ATACCAAATTTGACGCCTAC  distance=69bp  PAM=CGG
#     [5] Method 3: guide=GCCTGGAAGTACTGCTACGC  distance=66bp  PAM=TGG
#
# SAMPLE 27 (2 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=CGAAATGGCGTATGTGAATG  distance=71bp  PAM=CGG
#     [2] Method 1: guide=ACAGATTCGGATGGATGAAC  distance=67bp  PAM=TGG
#     [3] Method 1: guide=GATGGATGAACTGGCGAAAC  distance=76bp  PAM=TGG
#     [4] Method 3: guide=CGAAATGGCGTATGTGAATG  distance=70bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=CACCGCATTTATATTTCGCC  distance=75bp  PAM=TGG
#     [2] Method 1: guide=TGACCCGTCCACCACGATGC  distance=76bp  PAM=AGG
#
# SAMPLE 28 (6 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=CATAACAAATCCGTGGTCGG  distance=66bp  PAM=TGG
#     [2] Method 1: guide=CAGCATAACAAATCCGTGGT  distance=69bp  PAM=CGG
#     [3] Method 1: guide=CCACCAGCATAACAAATCCG  distance=73bp  PAM=TGG
#   mcv2:
#     [1] Method 1: guide=GATGGATGAACTGGCGAAAC  distance=74bp  PAM=TGG
#     [2] Method 1: guide=GATGAACTGGCGAAACTGGT  distance=70bp  PAM=CGG
#     [3] Method 1: guide=ATTCTTCGACTCCATTCAAG  distance=72bp  PAM=GGG
#     [4] Method 1: guide=CATTCTTCGACTCCATTCAA  distance=73bp  PAM=GGG
#     [5] Method 1: guide=GCATTCTTCGACTCCATTCA  distance=74bp  PAM=AGG
#     [6] Method 3: guide=GATGGATGAACTGGCGAAAC  distance=73bp  PAM=TGG
#     [7] Method 3: guide=GATGAACTGGCGAAACTGGT  distance=69bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=GACGGCGGGTACGGTGCGTC  distance=74bp  PAM=TGG
#     [2] Method 1: guide=GCGGGTACGGTGCGTCTGGT  distance=70bp  PAM=AGG
#     [3] Method 1: guide=TGGAAGCGTTAAAAAATAAT  distance=72bp  PAM=CGG
#   mcv4:
#     [1] Method 1: guide=GCGAGGCTTCCCGTTGTGCC  distance=73bp  PAM=TGG
#     [2] Method 1: guide=GGCTTCCCGTTGTGCCTGGT  distance=69bp  PAM=CGG
#     [3] Method 1: guide=CATTTCTTGCGCCGCGGTAC  distance=69bp  PAM=TGG
#     [4] Method 1: guide=CGCGTCAGGAACATCAACCG  distance=74bp  PAM=TGG
#   mcv5:
#     [1] Method 1: guide=GAACGAGACGCTGGCGAAGC  distance=74bp  PAM=TGG
#     [2] Method 1: guide=GAGACGCTGGCGAAGCTGGT  distance=70bp  PAM=CGG
#     [3] Method 1: guide=AGACGCTGGCGAAGCTGGTC  distance=69bp  PAM=GGG
#     [4] Method 1: guide=GCAGACATGCCGATGTTCCT  distance=68bp  PAM=CGG
#     [5] Method 1: guide=GGCAGGAGATAAGTGATCAT  distance=68bp  PAM=CGG
#     [6] Method 3: guide=GAACGAGACGCTGGCGAAGC  distance=73bp  PAM=TGG
#     [7] Method 3: guide=GAGACGCTGGCGAAGCTGGT  distance=69bp  PAM=CGG
#     [8] Method 3: guide=AGACGCTGGCGAAGCTGGTC  distance=68bp  PAM=GGG
#     [9] Method 3: guide=GGCAGGAGATAAGTGATCAT  distance=68bp  PAM=CGG
#   mcv6:
#     [1] Method 1: guide=TGACCCGTCCACCACGATGC  distance=75bp  PAM=AGG
#     [2] Method 1: guide=GTTAAGTGCCTATGGCGATC  distance=69bp  PAM=AGG
#     [3] Method 1: guide=TTAAGTGCCTATGGCGATCA  distance=70bp  PAM=GGG
#     [4] Method 1: guide=AGTGCCTATGGCGATCAGGG  distance=73bp  PAM=CGG
#     [5] Method 1: guide=GAATCAGGCGCAGCATCGGG  distance=67bp  PAM=CGG
#
# SAMPLE 29 (4 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=TTGCGTTGATTTTCTAAGCA  distance=70bp  PAM=TGG
#     [2] Method 1: guide=GGCTTTCTGAAAATCTTCAG  distance=69bp  PAM=CGG
#     [3] Method 1: guide=TCTGAAAATCTTCAGCGGAC  distance=74bp  PAM=CGG
#     [4] Method 1: guide=CTTTCTTCAGGTATACTCGC  distance=71bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=TAATTATTCTTGCAGAAAGC  distance=72bp  PAM=AGG
#     [2] Method 1: guide=AATTATTCTTGCAGAAAGCA  distance=71bp  PAM=GGG
#     [3] Method 1: guide=GCGCTTTACCACCACGCGTT  distance=75bp  PAM=TGG
#     [4] Method 3: guide=TAATTATTCTTGCAGAAAGC  distance=71bp  PAM=AGG
#     [5] Method 3: guide=AATTATTCTTGCAGAAAGCA  distance=70bp  PAM=GGG
#   mcv3:
#     [1] Method 1: guide=GAGTGGTTTATGCGCCAGCA  distance=70bp  PAM=GGG
#     [2] Method 1: guide=GGAGTGGTTTATGCGCCAGC  distance=71bp  PAM=AGG
#   mcv4:
#     [1] Method 1: guide=GGCGTATGTGAATGCGGTGC  distance=74bp  PAM=AGG
#     [2] Method 1: guide=GATGGATGAACTGGCGAAAC  distance=67bp  PAM=TGG
#     [3] Method 1: guide=GATGAACTGGCGAAACTGGT  distance=71bp  PAM=CGG
#
# SAMPLE 30 (5 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=AATATCCATTGCAAATACCG  distance=69bp  PAM=AGG
#     [2] Method 1: guide=AGGGTGTTATTTCCCGGCCT  distance=74bp  PAM=CGG
#     [3] Method 1: guide=CGAGAAAGGGTGTTATTTCC  distance=68bp  PAM=CGG
#     [4] Method 1: guide=GCGGGGTAGCGCCTTTACGC  distance=70bp  PAM=AGG
#   mcv2:
#     [1] Method 1: guide=GCCGAGATGGCCTAATGCCG  distance=66bp  PAM=CGG
#     [2] Method 1: guide=CTGAGCGAAATAATCCGCCA  distance=75bp  PAM=CGG
#     [3] Method 1: guide=CGGCCCCAGCGATCTGGCCG  distance=71bp  PAM=CGG
#     [4] Method 1: guide=CAATATGTTTGGCACCGTGG  distance=67bp  PAM=CGG
#     [5] Method 1: guide=CGCCAATATGTTTGGCACCG  distance=70bp  PAM=TGG
#   mcv3:
#     [1] Method 1: guide=AGCTTCACGAATTTGTGCCA  distance=75bp  PAM=CGG
#     [2] Method 1: guide=TATTGAGGAGCCGGTGCTGG  distance=71bp  PAM=CGG
#     [3] Method 1: guide=GTTTATTGAGGAGCCGGTGC  distance=68bp  PAM=TGG
#     [4] Method 1: guide=AGATGCGGCGGTTAACACCG  distance=70bp  PAM=TGG
#   mcv4:
#     [1] Method 1: guide=TTCCACCACCATAATAATAC  distance=71bp  PAM=CGG
#     [2] Method 1: guide=TCCACCACCATAATAATACC  distance=70bp  PAM=GGG
#     [3] Method 1: guide=CCACCACCATAATAATACCG  distance=69bp  PAM=GGG
#     [4] Method 1: guide=CACCACCATAATAATACCGG  distance=68bp  PAM=GGG
#     [5] Method 1: guide=GAGGTACTGAAAAAGACCCC  distance=74bp  PAM=CGG
#     [6] Method 1: guide=TTTTGCCGCAAAGCGGTAGA  distance=75bp  PAM=GGG
#     [7] Method 1: guide=GTTTTGCCGCAAAGCGGTAG  distance=76bp  PAM=AGG
#     [8] Method 3: guide=TTCCACCACCATAATAATAC  distance=70bp  PAM=CGG
#     [9] Method 3: guide=TCCACCACCATAATAATACC  distance=69bp  PAM=GGG
#     [10] Method 3: guide=CCACCACCATAATAATACCG  distance=68bp  PAM=GGG
#     [11] Method 3: guide=CACCACCATAATAATACCGG  distance=67bp  PAM=GGG
#     [12] Method 3: guide=GAGGTACTGAAAAAGACCCC  distance=74bp  PAM=CGG
#   mcv5:
#     [1] Method 1: guide=TTTAGCGCCTATTTTTTTAT  distance=67bp  PAM=TGG
#     [2] Method 1: guide=CACCGCATTGATTGCCGCAC  distance=71bp  PAM=TGG
#
# SAMPLE 31 (3 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=GCGACTGTGTGCGAGCTGAA  distance=67bp  PAM=CGG
#     [2] Method 1: guide=CGACTGTGTGCGAGCTGAAC  distance=66bp  PAM=GGG
#     [3] Method 1: guide=GATATTGGCGCGGGCCAGTG  distance=70bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=ATCCTGATAACAGGCTTTCG  distance=69bp  PAM=CGG
#     [2] Method 1: guide=CTGAGCGAAGCAGGCCAGTG  distance=71bp  PAM=CGG
#     [3] Method 3: guide=ATCCTGATAACAGGCTTTCG  distance=69bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=CAGACTATTTCGCCTGGGGC  distance=66bp  PAM=GGG
#     [2] Method 1: guide=CGCCTGGGGCGGGATTGCAC  distance=76bp  PAM=TGG
#
# SAMPLE 32 (4 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=ATGTGCAAGGATCAGCGCCG  distance=71bp  PAM=AGG
#     [2] Method 1: guide=AGCGATAAAAATAAACGCCT  distance=76bp  PAM=CGG
#     [3] Method 1: guide=TTTTTACAAAGCCAGCTCAC  distance=70bp  PAM=GGG
#     [4] Method 1: guide=ATTTTTACAAAGCCAGCTCA  distance=71bp  PAM=CGG
#     [5] Method 3: guide=TTTTTACAAAGCCAGCTCAC  distance=70bp  PAM=GGG
#     [6] Method 3: guide=ATTTTTACAAAGCCAGCTCA  distance=71bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=TTACAGAATATTACCCGCCG  distance=70bp  PAM=TGG
#     [2] Method 1: guide=ATGCCAGCTTTCGCTAACCA  distance=75bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=AAGAGTGGACTCAACCGCGT  distance=74bp  PAM=TGG
#     [2] Method 1: guide=AGAGTGGACTCAACCGCGTT  distance=73bp  PAM=GGG
#     [3] Method 1: guide=TGGACTCAACCGCGTTGGGA  distance=69bp  PAM=AGG
#     [4] Method 1: guide=AAAGGCTACATCAACAGCCT  distance=75bp  PAM=CGG
#     [5] Method 1: guide=GACCGCCAGTCAGTGCGCCG  distance=70bp  PAM=AGG
#     [6] Method 3: guide=AAAGGCTACATCAACAGCCT  distance=76bp  PAM=CGG
#     [7] Method 3: guide=GACCGCCAGTCAGTGCGCCG  distance=70bp  PAM=AGG
#   mcv4:
#     [1] Method 1: guide=TTTTTTTATTGGCGTGGCTA  distance=76bp  PAM=TGG
#     [2] Method 1: guide=ATCCAGTGCGGCAATCAATG  distance=71bp  PAM=CGG
#
# SAMPLE 33 (4 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=GCCGTCCATACTGTCAAGCA  distance=73bp  PAM=CGG
#     [2] Method 1: guide=CGGTAACTGACCAAGCCCGG  distance=71bp  PAM=TGG
#     [3] Method 1: guide=TGCCGGTAACTGACCAAGCC  distance=74bp  PAM=CGG
#     [4] Method 3: guide=GCCGTCCATACTGTCAAGCA  distance=73bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=CAGAGCGCCACTCACTACGG  distance=69bp  PAM=CGG
#     [2] Method 1: guide=CGCCAGAGCGCCACTCACTA  distance=72bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=ATCGCGCGGGCATTGATGAA  distance=73bp  PAM=CGG
#     [2] Method 1: guide=GCGCGGGCATTGATGAACGG  distance=70bp  PAM=TGG
#     [3] Method 1: guide=CGATCCGCAGGTCGCTGCTC  distance=70bp  PAM=AGG
#     [4] Method 1: guide=GCGAATTTCGATCACCCGCT  distance=71bp  PAM=CGG
#     [5] Method 2: guide=TCGGCCTGAGCAGCGACCTG  distance=75bp  PAM=CGG
#     [6] Method 3: guide=CGATCCGCAGGTCGCTGCTC  distance=71bp  PAM=AGG
#     [7] Method 3: guide=GCGAATTTCGATCACCCGCT  distance=71bp  PAM=CGG
#   mcv4:
#     [1] Method 1: guide=GGCAAAACATCTTGGCGTTG  distance=68bp  PAM=AGG
#
# SAMPLE 34 (8 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=ACTGCCGAGTCCGATATTCT  distance=67bp  PAM=CGG
#     [2] Method 1: guide=TATTTTACCCATCAACGGGG  distance=67bp  PAM=GGG
#     [3] Method 1: guide=CTATTTTACCCATCAACGGG  distance=68bp  PAM=GGG
#     [4] Method 1: guide=GCTATTTTACCCATCAACGG  distance=69bp  PAM=GGG
#     [5] Method 1: guide=GGCTATTTTACCCATCAACG  distance=70bp  PAM=GGG
#     [6] Method 1: guide=CGGCTATTTTACCCATCAAC  distance=71bp  PAM=GGG
#     [7] Method 1: guide=GCGGCTATTTTACCCATCAA  distance=72bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=CCCTGCATCAGGGATCAACG  distance=71bp  PAM=CGG
#     [2] Method 3: guide=CCCTGCATCAGGGATCAACG  distance=71bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=TATTGAAAACCCATACCGTC  distance=69bp  PAM=CGG
#     [2] Method 1: guide=CTAAATAACCTTGTCGATAA  distance=70bp  PAM=AGG
#     [3] Method 1: guide=TAACCTTGTCGATAAAGGCC  distance=75bp  PAM=TGG
#     [4] Method 1: guide=AATAATCAAATGTCACCGGA  distance=76bp  PAM=CGG
#     [5] Method 1: guide=ATTAAATAATCAAATGTCAC  distance=72bp  PAM=CGG
#     [6] Method 1: guide=CCGCATACAGACGATCAACC  distance=71bp  PAM=AGG
#     [7] Method 3: guide=CTAAATAACCTTGTCGATAA  distance=71bp  PAM=AGG
#     [8] Method 3: guide=TAACCTTGTCGATAAAGGCC  distance=76bp  PAM=TGG
#     [9] Method 3: guide=CCGCATACAGACGATCAACC  distance=71bp  PAM=AGG
#   mcv4:
#     [1] Method 1: guide=CAAACCGCCGCTAATCAACG  distance=70bp  PAM=CGG
#     [2] Method 1: guide=AAACCGCCGCTAATCAACGC  distance=69bp  PAM=GGG
#     [3] Method 1: guide=GTGGTGATTGGCACCAACGT  distance=71bp  PAM=GGG
#     [4] Method 1: guide=GGTGGTGATTGGCACCAACG  distance=72bp  PAM=TGG
#     [5] Method 3: guide=CAAACCGCCGCTAATCAACG  distance=69bp  PAM=CGG
#     [6] Method 3: guide=AAACCGCCGCTAATCAACGC  distance=68bp  PAM=GGG
#   mcv5:
#     [1] Method 1: guide=GGCCAGCGGCAATTTATGTA  distance=73bp  PAM=CGG
#     [2] Method 1: guide=TATGAGATCCACGACATAGA  distance=69bp  PAM=AGG
#     [3] Method 1: guide=TTCCCAGTGTCGGATCAACG  distance=70bp  PAM=CGG
#     [4] Method 3: guide=TATGAGATCCACGACATAGA  distance=70bp  PAM=AGG
#     [5] Method 3: guide=TTCCCAGTGTCGGATCAACG  distance=70bp  PAM=CGG
#   mcv6:
#     [1] Method 1: guide=GCGCCGCCAGACGATCAACG  distance=70bp  PAM=AGG
#     [2] Method 1: guide=AAAACAGCCGATGATCTGAA  distance=66bp  PAM=AGG
#     [3] Method 3: guide=GCGCCGCCAGACGATCAACG  distance=69bp  PAM=AGG
#   mcv7:
#     [1] Method 1: guide=TCCACCTGGGTTTCCACCAA  distance=72bp  PAM=CGG
#     [2] Method 1: guide=CCACCTGGGTTTCCACCAAC  distance=71bp  PAM=GGG
#     [3] Method 1: guide=CACCTGGGTTTCCACCAACG  distance=70bp  PAM=GGG
#     [4] Method 1: guide=GGAACGCCCAGTTGAAGTTC  distance=67bp  PAM=GGG
#     [5] Method 1: guide=AGGAACGCCCAGTTGAAGTT  distance=68bp  PAM=CGG
#   mcv8:
#     [1] Method 1: guide=CGCAGATCCTGATATTTGGT  distance=66bp  PAM=CGG
#     [2] Method 1: guide=GCAGATCCTGATATTTGGTC  distance=67bp  PAM=GGG
#     [3] Method 1: guide=CTCCCGTCAGGAGTCTGGCG  distance=75bp  PAM=TGG
#     [4] Method 1: guide=GCATTCTCCCGTCAGGAGTC  distance=70bp  PAM=TGG
#
# SAMPLE 35 (8 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=CGGTATTGGCGCTTCGGGTC  distance=73bp  PAM=TGG
#     [2] Method 1: guide=TATTGGCGCTTCGGGTCTGG  distance=70bp  PAM=TGG
#   mcv2:
#     [1] Method 1: guide=TGTGGTGTTGGCGGTGGTCC  distance=73bp  PAM=TGG
#     [2] Method 1: guide=GGTGTTGGCGGTGGTCCTGG  distance=70bp  PAM=TGG
#     [3] Method 1: guide=CAAGGCCATCCGCTGCGGTA  distance=72bp  PAM=AGG
#     [4] Method 3: guide=TGTGGTGTTGGCGGTGGTCC  distance=72bp  PAM=TGG
#     [5] Method 3: guide=GGTGTTGGCGGTGGTCCTGG  distance=69bp  PAM=TGG
#   mcv3:
#     [1] Method 1: guide=ATCGCGAATATCGCCGCCAT  distance=66bp  PAM=TGG
#     [2] Method 1: guide=CGCAAAAGGTATTGCGCTGG  distance=70bp  PAM=TGG
#     [3] Method 1: guide=CTGCGCAAAAGGTATTGCGC  distance=73bp  PAM=TGG
#   mcv4:
#     [1] Method 1: guide=CAAGCCTTCGCCCAGGGTTT  distance=67bp  PAM=TGG
#     [2] Method 1: guide=TCTGCCGTTTGTGAAGAGCG  distance=73bp  PAM=CGG
#     [3] Method 1: guide=TTTTGAGCGCCAGGGTCTGG  distance=71bp  PAM=TGG
#     [4] Method 1: guide=GAGTTTTGAGCGCCAGGGTC  distance=74bp  PAM=TGG
#   mcv5:
#     [1] Method 1: guide=AAAGCCCGGCAGCACGCGTC  distance=75bp  PAM=TGG
#     [2] Method 1: guide=GCCCGGCAGCACGCGTCTGG  distance=72bp  PAM=AGG
#   mcv6:
#     [1] Method 1: guide=ATTGCGGAAATGCAAAAAGA  distance=76bp  PAM=TGG
#     [2] Method 1: guide=CGTTGATCGTCTGGCGGCGC  distance=66bp  PAM=TGG
#     [3] Method 1: guide=GATCCTCGTTGATCGTCTGG  distance=72bp  PAM=CGG
#     [4] Method 1: guide=TGCGATCCTCGTTGATCGTC  distance=75bp  PAM=TGG
#     [5] Method 3: guide=CGTTGATCGTCTGGCGGCGC  distance=66bp  PAM=TGG
#     [6] Method 3: guide=GATCCTCGTTGATCGTCTGG  distance=72bp  PAM=CGG
#     [7] Method 3: guide=TGCGATCCTCGTTGATCGTC  distance=75bp  PAM=TGG
#   mcv7:
#     [1] Method 1: guide=GCGTCAACTGAGTAATCGTC  distance=73bp  PAM=TGG
#     [2] Method 1: guide=TCAACTGAGTAATCGTCTGG  distance=70bp  PAM=TGG
#     [3] Method 3: guide=GCGTCAACTGAGTAATCGTC  distance=72bp  PAM=TGG
#     [4] Method 3: guide=TCAACTGAGTAATCGTCTGG  distance=69bp  PAM=TGG
#   mcv8:
#     [1] Method 1: guide=TTTGGTCGGGTCATCATCAT  distance=74bp  PAM=AGG
#     [2] Method 1: guide=GCATTCTCCCGTCAGGAGTC  distance=76bp  PAM=TGG
#     [3] Method 1: guide=CGGTGAAGCATTCTCCCGTC  distance=69bp  PAM=AGG
#
# SAMPLE 36 (4 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=GGGCTGGATAGTTGGCTGGC  distance=74bp  PAM=AGG
#     [2] Method 1: guide=GGATAGTTGGCTGGCAGGTC  distance=69bp  PAM=AGG
#     [3] Method 1: guide=GGCGGGGGCTATTCGTATGA  distance=72bp  PAM=CGG
#     [4] Method 1: guide=GCGGGGGCTATTCGTATGAC  distance=73bp  PAM=GGG
#     [5] Method 1: guide=CGGGGGCTATTCGTATGACG  distance=74bp  PAM=GGG
#     [6] Method 1: guide=GGGGGCTATTCGTATGACGG  distance=75bp  PAM=GGG
#     [7] Method 3: guide=GGCGGGGGCTATTCGTATGA  distance=73bp  PAM=CGG
# ...
#   mcv14:
#     [1] Method 1: guide=CCCAGACCGCCCATATCCTG  distance=75bp  PAM=CGG
#     [2] Method 1: guide=CGACTACAGCCGTAAAGAGG  distance=69bp  PAM=GGG
#     [3] Method 1: guide=GCGACTACAGCCGTAAAGAG  distance=70bp  PAM=GGG
#     [4] Method 1: guide=CGCGACTACAGCCGTAAAGA  distance=71bp  PAM=GGG
#     [5] Method 1: guide=TCGCGACTACAGCCGTAAAG  distance=72bp  PAM=AGG
#     [6] Method 3: guide=CGACTACAGCCGTAAAGAGG  distance=69bp  PAM=GGG
#     [7] Method 3: guide=GCGACTACAGCCGTAAAGAG  distance=70bp  PAM=GGG
#     [8] Method 3: guide=CGCGACTACAGCCGTAAAGA  distance=71bp  PAM=GGG
#     [9] Method 3: guide=TCGCGACTACAGCCGTAAAG  distance=72bp  PAM=AGG
#   mcv15:
#     [1] Method 1: guide=CAGCCAGCCACTGCATAAAC  distance=74bp  PAM=AGG
#     [2] Method 1: guide=CTATTATCCAACGGCTTAAT  distance=74bp  PAM=CGG
#
# SAMPLE 115 (7 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=TACCGGCATTTCTTGCGCCG  distance=75bp  PAM=CGG
#     [2] Method 1: guide=TCGCGCCGACCAGGCACAAC  distance=74bp  PAM=GGG
#     [3] Method 1: guide=TTCGCGCCGACCAGGCACAA  distance=73bp  PAM=CGG
#     [4] Method 1: guide=ACCGTGGCATGCCAGTACCG  distance=70bp  PAM=CGG
#     [5] Method 3: guide=TACCGGCATTTCTTGCGCCG  distance=76bp  PAM=CGG
#     [6] Method 3: guide=ACCGTGGCATGCCAGTACCG  distance=70bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=CGTACCGTGGAATCAGGTAC  distance=72bp  PAM=CGG
#     [2] Method 1: guide=GTACCGTGGAATCAGGTACC  distance=71bp  PAM=GGG
#     [3] Method 1: guide=TACCGTGGAATCAGGTACCG  distance=70bp  PAM=GGG
#     [4] Method 1: guide=TGCCAGGGGGTGAATGTCCC  distance=75bp  PAM=CGG
#     [5] Method 1: guide=TCAGTTTTTGAATCCACTCA  distance=68bp  PAM=AGG
#   mcv3:
#     [1] Method 1: guide=AGCTTCACGAATTTGTGCCA  distance=75bp  PAM=CGG
#     [2] Method 1: guide=TATTGAGGAGCCGGTGCTGG  distance=71bp  PAM=CGG
#     [3] Method 1: guide=GTTTATTGAGGAGCCGGTGC  distance=68bp  PAM=TGG
#     [4] Method 1: guide=AGATGCGGCGGTTAACACCG  distance=70bp  PAM=TGG
#     [5] Method 3: guide=TATTGAGGAGCCGGTGCTGG  distance=71bp  PAM=CGG
#     [6] Method 3: guide=GTTTATTGAGGAGCCGGTGC  distance=68bp  PAM=TGG
#   mcv4:
#     [1] Method 1: guide=CACGGCCTGGGCAAACGCCA  distance=75bp  PAM=CGG
#     [2] Method 1: guide=GACAGTGATTCGTTGTACCG  distance=70bp  PAM=TGG
#     [3] Method 3: guide=CACGGCCTGGGCAAACGCCA  distance=76bp  PAM=CGG
#     [4] Method 3: guide=GACAGTGATTCGTTGTACCG  distance=70bp  PAM=TGG
#   mcv5:
#     [1] Method 1: guide=GCCGAGATGGCCTAATGCCG  distance=66bp  PAM=CGG
#     [2] Method 1: guide=CTGAGCGAAATAATCCGCCA  distance=75bp  PAM=CGG
#     [3] Method 1: guide=CGGCCCCAGCGATCTGGCCG  distance=71bp  PAM=CGG
#     [4] Method 1: guide=CAATATGTTTGGCACCGTGG  distance=67bp  PAM=CGG
#     [5] Method 1: guide=CGCCAATATGTTTGGCACCG  distance=70bp  PAM=TGG
#   mcv6:
#     [1] Method 1: guide=CTCGGCGGGTTAACCGAGAA  distance=69bp  PAM=CGG
#     [2] Method 1: guide=ACCGCCGAAACCATTCGCTT  distance=75bp  PAM=CGG
#     [3] Method 3: guide=ACCGCCGAAACCATTCGCTT  distance=76bp  PAM=CGG
#   mcv7:
#     [1] Method 1: guide=AATATTAGCATTAAGTAATG  distance=71bp  PAM=CGG
#     [2] Method 1: guide=TAGCATTAAGTAATGCGGCA  distance=76bp  PAM=AGG
#
# SAMPLE 116 (9 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=AATGACGAGAACTTCCAGCA  distance=71bp  PAM=TGG
#     [2] Method 1: guide=GACGAGAACTTCCAGCATGG  distance=68bp  PAM=TGG
#     [3] Method 1: guide=GTCCATTTTTTGTCCCTGAT  distance=73bp  PAM=GGG
#     [4] Method 1: guide=TGTCCATTTTTTGTCCCTGA  distance=74bp  PAM=TGG
#   mcv2:
#     [1] Method 1: guide=CAGACAGGTAGTGACGAAGA  distance=75bp  PAM=CGG
#     [2] Method 1: guide=GGTAGTGACGAAGACGGCGC  distance=69bp  PAM=TGG
#     [3] Method 1: guide=CCACCCAGACTTCTGGTCAG  distance=71bp  PAM=GGG
#     [4] Method 1: guide=ACCACCCAGACTTCTGGTCA  distance=72bp  PAM=GGG
#     [5] Method 1: guide=TACCACCCAGACTTCTGGTC  distance=73bp  PAM=AGG
#   mcv3:
#     [1] Method 1: guide=AGTCACTACCGCCGTTGGCC  distance=72bp  PAM=CGG
#     [2] Method 1: guide=CAATACGTTCCAGCACAACC  distance=76bp  PAM=GGG
#     [3] Method 1: guide=GCAATACGTTCCAGCACAAC  distance=75bp  PAM=CGG
#     [4] Method 1: guide=CGCTTTGGCGTCTTCCGGCA  distance=70bp  PAM=GGG
#     [5] Method 1: guide=ACGCTTTGGCGTCTTCCGGC  distance=71bp  PAM=AGG
#     [6] Method 1: guide=ACCCACGCTTTGGCGTCTTC  distance=75bp  PAM=CGG
#   mcv4:
#     [1] Method 1: guide=TTGTAATGAGCCTCATCTTC  distance=75bp  PAM=TGG
#     [2] Method 1: guide=ATGAGCCTCATCTTCTGGCA  distance=70bp  PAM=CGG
#     [3] Method 1: guide=TGAGCCTCATCTTCTGGCAC  distance=69bp  PAM=GGG
#     [4] Method 1: guide=CCTCCGTTGATTATTGCCGC  distance=76bp  PAM=AGG
#     [5] Method 1: guide=TGCCTCGCTGGTCTCTCCTG  distance=70bp  PAM=CGG
#     [6] Method 3: guide=TTGTAATGAGCCTCATCTTC  distance=74bp  PAM=TGG
#     [7] Method 3: guide=ATGAGCCTCATCTTCTGGCA  distance=69bp  PAM=CGG
#     [8] Method 3: guide=TGAGCCTCATCTTCTGGCAC  distance=68bp  PAM=GGG
#   mcv5:
#     [1] Method 1: guide=CCTTGTTCTGGGGATTCTTC  distance=76bp  PAM=TGG
#     [2] Method 1: guide=TTCTGGGGATTCTTCTGGCA  distance=71bp  PAM=TGG
#     [3] Method 1: guide=GATAGAGGAACAAAATAGGG  distance=70bp  PAM=CGG
#     [4] Method 1: guide=GTAGATAGAGGAACAAAATA  distance=73bp  PAM=GGG
#     [5] Method 1: guide=AGTAGATAGAGGAACAAAAT  distance=74bp  PAM=AGG
#     [6] Method 3: guide=GATAGAGGAACAAAATAGGG  distance=70bp  PAM=CGG
#     [7] Method 3: guide=GTAGATAGAGGAACAAAATA  distance=73bp  PAM=GGG
#     [8] Method 3: guide=AGTAGATAGAGGAACAAAAT  distance=74bp  PAM=AGG
#   mcv6:
#     [1] Method 1: guide=GCATCGTCGATCACCATGCG  distance=71bp  PAM=TGG
#     [2] Method 1: guide=TTGTGACTAACATCTGGCAC  distance=69bp  PAM=GGG
#     [3] Method 1: guide=ATTGTGACTAACATCTGGCA  distance=70bp  PAM=CGG
#     [4] Method 1: guide=CGGAGATTGTGACTAACATC  distance=75bp  PAM=TGG
#     [5] Method 3: guide=TTGTGACTAACATCTGGCAC  distance=69bp  PAM=GGG
#     [6] Method 3: guide=ATTGTGACTAACATCTGGCA  distance=70bp  PAM=CGG
#     [7] Method 3: guide=CGGAGATTGTGACTAACATC  distance=75bp  PAM=TGG
#   mcv7:
#     [1] Method 1: guide=TGATCAGCGTCTTCTGGCTA  distance=72bp  PAM=TGG
#     [2] Method 3: guide=TGATCAGCGTCTTCTGGCTA  distance=72bp  PAM=TGG
#   mcv8:
#     [1] Method 1: guide=CCAGCGAGGACTTTCTGGCA  distance=72bp  PAM=CGG
#     [2] Method 3: guide=ATCAGCCAGCGAGGACTTTC  distance=76bp  PAM=TGG
#     [3] Method 3: guide=CCAGCGAGGACTTTCTGGCA  distance=71bp  PAM=CGG
#   mcv9:
#     [1] Method 1: guide=TTCCAGAATACGGTTTTGCT  distance=70bp  PAM=CGG
#     [2] Method 1: guide=TGTTGTGGTTTCGGCATTTC  distance=66bp  PAM=CGG
#     [3] Method 1: guide=CGCTGCGGGCGCAGGTGGCA  distance=70bp  PAM=CGG
#     [4] Method 1: guide=CGAAGCGCTGCGGGCGCAGG  distance=75bp  PAM=TGG
#
# SAMPLE 117 (7 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=ATGCGCACGCCCCCTTGCCC  distance=70bp  PAM=TGG
#     [2] Method 1: guide=AGCCGGGGATTTATTTGCCA  distance=75bp  PAM=GGG
#     [3] Method 1: guide=GAGCCGGGGATTTATTTGCC  distance=74bp  PAM=AGG
#     [4] Method 1: guide=CGCCGGGTCATTACAGAAGC  distance=67bp  PAM=AGG
#   mcv2:
#     [1] Method 1: guide=ACCGCACTTGCCCCTTTCAC  distance=70bp  PAM=CGG
#     [2] Method 1: guide=CTTCTTTTTTCACTTCGCCA  distance=66bp  PAM=CGG
#     [3] Method 1: guide=TAAACCGCAATCTTTTGCTC  distance=73bp  PAM=CGG
#     [4] Method 3: guide=ACCGCACTTGCCCCTTTCAC  distance=69bp  PAM=CGG
#     [5] Method 3: guide=TAAACCGCAATCTTTTGCTC  distance=73bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=TTCAGAATCACCCCTTTCAC  distance=69bp  PAM=CGG
#     [2] Method 1: guide=TCGGTCACTGCCAGAATCGG  distance=66bp  PAM=CGG
#     [3] Method 1: guide=CTTTGAGCAAAACGGTATTC  distance=72bp  PAM=CGG
#     [4] Method 3: guide=TTCAGAATCACCCCTTTCAC  distance=68bp  PAM=CGG
#     [5] Method 3: guide=CTTTGAGCAAAACGGTATTC  distance=72bp  PAM=CGG
#   mcv4:
#     [1] Method 1: guide=TGCACAACTAACCCTTACAC  distance=70bp  PAM=CGG
#     [2] Method 1: guide=CGCAGCAGCAGGCGCAGCTC  distance=67bp  PAM=TGG
#     [3] Method 1: guide=GCAGCAGCAGGCGCAGCTCT  distance=68bp  PAM=GGG
#     [4] Method 1: guide=GCAGCAGGCGCAGCTCTGGG  distance=71bp  PAM=CGG
#     [5] Method 1: guide=GCAGGCGCAGCTCTGGGCGG  distance=74bp  PAM=CGG
#     [6] Method 1: guide=TTTACCTGCTTCGCGTTCGC  distance=73bp  PAM=CGG
#     [7] Method 3: guide=TGCACAACTAACCCTTACAC  distance=69bp  PAM=CGG
#     [8] Method 3: guide=TTTACCTGCTTCGCGTTCGC  distance=73bp  PAM=CGG
#   mcv5:
#     [1] Method 1: guide=TACATAAGAGCCCCTTGCAC  distance=69bp  PAM=TGG
#     [2] Method 1: guide=GATCTTTTGATTCCGGGTTA  distance=72bp  PAM=CGG
#     [3] Method 3: guide=TACATAAGAGCCCCTTGCAC  distance=68bp  PAM=TGG
#   mcv6:
#     [1] Method 1: guide=TTTATTTGTACCCCTTACCC  distance=71bp  PAM=TGG
#     [2] Method 1: guide=TTATTTGTACCCCTTACCCT  distance=70bp  PAM=GGG
#     [3] Method 1: guide=TATTTGTACCCCTTACCCTG  distance=69bp  PAM=GGG
#     [4] Method 1: guide=CGTGGCTACCGGCCTGACCA  distance=67bp  PAM=TGG
#     [5] Method 1: guide=CAGCAAAAAAATCAGCCCCA  distance=76bp  PAM=GGG
#     [6] Method 1: guide=CCAGCAAAAAAATCAGCCCC  distance=75bp  PAM=AGG
#     [7] Method 3: guide=TTTATTTGTACCCCTTACCC  distance=70bp  PAM=TGG
#     [8] Method 3: guide=TTATTTGTACCCCTTACCCT  distance=69bp  PAM=GGG
#     [9] Method 3: guide=TATTTGTACCCCTTACCCTG  distance=68bp  PAM=GGG
#   mcv7:
#     [1] Method 1: guide=TGACTGGCGCGATTTTCTCA  distance=68bp  PAM=AGG
#     [2] Method 1: guide=CCAGGCTGTTAGTCCGTTTA  distance=68bp  PAM=GGG
#     [3] Method 1: guide=TCCAGGCTGTTAGTCCGTTT  distance=67bp  PAM=AGG
#
# SAMPLE 118 (2 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=CAACAAGTCAGGTTGCGAGA  distance=70bp  PAM=CGG
#     [2] Method 1: guide=TGCCAGAAGAGATAATCAAC  distance=66bp  PAM=CGG
#     [3] Method 3: guide=CAACAAGTCAGGTTGCGAGA  distance=69bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=GTGGCGATGCTGGCGTCCGC  distance=71bp  PAM=GGG
#     [2] Method 1: guide=GGTGGCGATGCTGGCGTCCG  distance=70bp  PAM=CGG
#     [3] Method 1: guide=TGTTTAGTGAAATGAAACAG  distance=66bp  PAM=TGG
#
# SAMPLE 119 (16 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=TTGATCCAGCAGCGGGAAAT  distance=75bp  PAM=TGG
#     [2] Method 1: guide=GCGATGTTTGATCCAGCAGC  distance=68bp  PAM=GGG
#     [3] Method 1: guide=AGCGATGTTTGATCCAGCAG  distance=67bp  PAM=CGG
#     [4] Method 1: guide=TGGCCTGATTCTGGTGACGG  distance=70bp  PAM=GGG
#     [5] Method 1: guide=ATGGCCTGATTCTGGTGACG  distance=71bp  PAM=GGG
#     [6] Method 1: guide=AATGGCCTGATTCTGGTGAC  distance=72bp  PAM=GGG
#     [7] Method 1: guide=GAATGGCCTGATTCTGGTGA  distance=73bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=GCCGTCCATACTGTCAAGCA  distance=73bp  PAM=CGG
#     [2] Method 1: guide=CGGTAACTGACCAAGCCCGG  distance=71bp  PAM=TGG
#     [3] Method 1: guide=TGCCGGTAACTGACCAAGCC  distance=74bp  PAM=CGG
#   mcv3:
#     [1] Method 1: guide=CGTGCGCCCGAAAGCGATGA  distance=73bp  PAM=CGG
#     [2] Method 1: guide=GCGCCCGAAAGCGATGACGG  distance=70bp  PAM=TGG
#     [3] Method 1: guide=CCCGAAAGCGATGACGGTGG  distance=67bp  PAM=CGG
#     [4] Method 3: guide=GTCGCTGTTTATTATCCCGG  distance=66bp  PAM=CGG
#   mcv4:
#     [1] Method 1: guide=TGTGGATTCACTTCCGCTGA  distance=74bp  PAM=CGG
#     [2] Method 1: guide=GGATTCACTTCCGCTGACGG  distance=71bp  PAM=CGG
#     [3] Method 1: guide=TCACTTCCGCTGACGGCGGT  distance=67bp  PAM=CGG
#     [4] Method 1: guide=CACTTCCGCTGACGGCGGTC  distance=66bp  PAM=GGG
#     [5] Method 1: guide=TTCCGCAGAATAAAGTTGAC  distance=73bp  PAM=TGG
#     [6] Method 1: guide=TCCGCAGAATAAAGTTGACT  distance=74bp  PAM=GGG
#     [7] Method 1: guide=CGCGGCACGTTGCGGTTCAA  distance=75bp  PAM=AGG
#     [8] Method 3: guide=TCACTTCCGCTGACGGCGGT  distance=66bp  PAM=CGG
#   mcv5:
#     [1] Method 1: guide=GGTTTTTTCCAGCGTCTGTT  distance=68bp  PAM=TGG
#     [2] Method 1: guide=GCTGCCGGGTGAGGAATTTA  distance=66bp  PAM=CGG
#     [3] Method 1: guide=CAGATCGATGTGGCTGACGG  distance=70bp  PAM=CGG
#     [4] Method 1: guide=GCCCAGATCGATGTGGCTGA  distance=73bp  PAM=CGG
#   mcv6:
#     [1] Method 1: guide=CAGAGCGCCACTCACTACGG  distance=69bp  PAM=CGG
#     [2] Method 1: guide=CGCCAGAGCGCCACTCACTA  distance=72bp  PAM=CGG
#     [3] Method 3: guide=CAGAGCGCCACTCACTACGG  distance=69bp  PAM=CGG
#     [4] Method 3: guide=CGCCAGAGCGCCACTCACTA  distance=72bp  PAM=CGG
#   mcv7:
#     [1] Method 1: guide=GCTTTGGTTCCGGCTGGGCA  distance=76bp  PAM=TGG
#     [2] Method 1: guide=TGGTTCCGGCTGGGCATGGC  distance=72bp  PAM=TGG
#     [3] Method 1: guide=CTTTAATGTAGTCCGGACGG  distance=71bp  PAM=CGG
#     [4] Method 1: guide=ACTCTTTAATGTAGTCCGGA  distance=74bp  PAM=CGG
#     [5] Method 3: guide=CTTTAATGTAGTCCGGACGG  distance=71bp  PAM=CGG
#     [6] Method 3: guide=ACTCTTTAATGTAGTCCGGA  distance=74bp  PAM=CGG
#   mcv8:
#     [1] Method 1: guide=CGCGGCGACAACAGTTGCGA  distance=73bp  PAM=CGG
#     [2] Method 1: guide=GGCGACAACAGTTGCGACGG  distance=70bp  PAM=TGG
#     [3] Method 3: guide=CGCGGCGACAACAGTTGCGA  distance=72bp  PAM=CGG
#     [4] Method 3: guide=GGCGACAACAGTTGCGACGG  distance=69bp  PAM=TGG
#   mcv9:
#     [1] Method 1: guide=GTTGGCCTTTGCTGCCCAGA  distance=74bp  PAM=CGG
#     [2] Method 1: guide=GGCCTTTGCTGCCCAGACGG  distance=71bp  PAM=TGG
#     [3] Method 1: guide=GCTTGATGCGAAAGCGGTAG  distance=66bp  PAM=CGG
#     [4] Method 1: guide=GGCAACGCTTGATGCGAAAG  distance=72bp  PAM=CGG
#   mcv10:
#     [1] Method 1: guide=GGTCTGGTGAGAAAGCTCGA  distance=74bp  PAM=CGG
#     [2] Method 1: guide=CTGGTGAGAAAGCTCGACGG  distance=71bp  PAM=CGG
#     [3] Method 1: guide=TGTGCCTGGTCGGCGCGAAA  distance=68bp  PAM=TGG
#     [4] Method 3: guide=GGTCTGGTGAGAAAGCTCGA  distance=73bp  PAM=CGG
#     [5] Method 3: guide=CTGGTGAGAAAGCTCGACGG  distance=70bp  PAM=CGG
#   mcv11:
#     [1] Method 1: guide=ATCATTATTCAATCGGTTAA  distance=71bp  PAM=CGG
#     [2] Method 1: guide=TCATTATTCAATCGGTTAAC  distance=70bp  PAM=GGG
#     [3] Method 1: guide=ATAAACCTAACAGGCGACGG  distance=71bp  PAM=AGG
#     [4] Method 1: guide=AACATAAACCTAACAGGCGA  distance=74bp  PAM=CGG
#     [5] Method 3: guide=ATAAACCTAACAGGCGACGG  distance=71bp  PAM=AGG
#     [6] Method 3: guide=AACATAAACCTAACAGGCGA  distance=74bp  PAM=CGG
#   mcv12:
#     [1] Method 1: guide=GTTGGCTCTCACTGTGACGG  distance=71bp  PAM=TGG
#     [2] Method 1: guide=CGGGTTGGCTCTCACTGTGA  distance=74bp  PAM=CGG
#   mcv13:
#     [1] Method 1: guide=CGTTGAGAAATCTTTTTCCC  distance=76bp  PAM=CGG
#     [2] Method 1: guide=TGAGAAATCTTTTTCCCCGG  distance=73bp  PAM=CGG
#     [3] Method 1: guide=GCAAACGTGGTGTTCTTTGA  distance=67bp  PAM=TGG
#     [4] Method 1: guide=CTCCGACCAGGGGCCGACGG  distance=69bp  PAM=CGG
#     [5] Method 1: guide=GGACTCCGACCAGGGGCCGA  distance=72bp  PAM=CGG
#   mcv14:
#     [1] Method 1: guide=CTCCAGACGAGCACGGCTAA  distance=72bp  PAM=CGG
#     [2] Method 1: guide=GAGACAACAATTAACGACGG  distance=69bp  PAM=CGG
#     [3] Method 1: guide=AATGAGACAACAATTAACGA  distance=72bp  PAM=CGG
#     [4] Method 3: guide=GAGACAACAATTAACGACGG  distance=69bp  PAM=CGG
#     [5] Method 3: guide=AATGAGACAACAATTAACGA  distance=72bp  PAM=CGG
#   mcv15:
#     [1] Method 1: guide=CCAGCAGATGCCTTCAGATA  distance=67bp  PAM=AGG
#     [2] Method 1: guide=TCGGGGCGCAGGACGGGGGT  distance=67bp  PAM=AGG
#     [3] Method 1: guide=AGCTTCGGGGCGCAGGACGG  distance=71bp  PAM=GGG
#     [4] Method 1: guide=CAGCTTCGGGGCGCAGGACG  distance=72bp  PAM=GGG
#     [5] Method 1: guide=CCAGCTTCGGGGCGCAGGAC  distance=73bp  PAM=GGG
#     [6] Method 1: guide=TCCAGCTTCGGGGCGCAGGA  distance=74bp  PAM=CGG
#   mcv16:
#     [1] Method 1: guide=AAAACAAAAGCCACTGCGAC  distance=66bp  PAM=AGG
#
# SAMPLE 120 (5 MCVs with candidates):
#   mcv1:
#     [1] Method 1: guide=CCCGGTGGTGATGGCACATA  distance=71bp  PAM=CGG
#     [2] Method 1: guide=TTCATCACCAGTTCGCTTTG  distance=67bp  PAM=CGG
#     [3] Method 3: guide=CCCGGTGGTGATGGCACATA  distance=70bp  PAM=CGG
#   mcv2:
#     [1] Method 1: guide=GGAATTATTGACTTAATATA  distance=70bp  PAM=GGG
#     [2] Method 1: guide=AGGAATTATTGACTTAATAT  distance=71bp  PAM=AGG
#     [3] Method 3: guide=GGAATTATTGACTTAATATA  distance=70bp  PAM=GGG
#     [4] Method 3: guide=AGGAATTATTGACTTAATAT  distance=71bp  PAM=AGG
#   mcv3:
#     [1] Method 1: guide=TTTATTGAAACCAACATTGT  distance=75bp  PAM=CGG
#     [2] Method 1: guide=TTATTGAAACCAACATTGTC  distance=74bp  PAM=GGG
#     [3] Method 1: guide=GCTGCTCGGCGCATACGGCG  distance=66bp  PAM=TGG
#     [4] Method 1: guide=TAAGGGCTGCTCGGCGCATA  distance=71bp  PAM=CGG
#   mcv4:
#     [1] Method 1: guide=AATATCACGCTCTAGACATA  distance=70bp  PAM=CGG
#   mcv5:
#     [1] Method 1: guide=TACCACAGCAACGGGCTGGG  distance=72bp  PAM=CGG
#     [2] Method 1: guide=AGTTACCACAGCAACGGGCT  distance=75bp  PAM=GGG
#     [3] Method 1: guide=CAGTTACCACAGCAACGGGC  distance=76bp  PAM=TGG
#
# ====================================================================================================

# %%
# count all mcvs in analysis
# Simple analysis: for each sample, count MCVs and sum total

import pandas as pd
import re
from collections import Counter
from pathlib import Path

def _sample_id_from_name(p: Path):
    m = re.match(r"(\d+)_S\1_", p.name)
    return int(m.group(1)) if m else None

mcv_counts = {}  # {sample_id: num_mcvs}

for nn, tsv_path in enumerate(tsv_files):
    sample_id = _sample_id_from_name(tsv_path) or (nn + 1)
    
    # Load and filter TSV
    tsv = pd.read_csv(tsv_path, sep="\t")
    tsv = tsv[tsv["mapq"] >= min_mapq]
    
    # Collapse hotspots (same logic)
    collapse_bp = 5
    min_reads = 1000
    
    counts = Counter(tsv["ins0"])
    gmap = php.map_guide_to_genome(guideRNA["protospacer"][nn], genome_sequence)
    target_position = gmap[0]["start"]
    counts[target_position] = counts.get(target_position, 0)
    
    clusters = [{"members": {pos: freq}, "total": freq} for pos, freq in counts.items()]
    merged = True
    while merged:
        merged = False
        new_clusters = []
        while clusters:
            c = clusters.pop(0)
            i = 0
            while i < len(clusters):
                other = clusters[i]
                close = any(abs(p - q) <= collapse_bp for p in c["members"] for q in other["members"])
                if close:
                    for p, f in other["members"].items():
                        c["members"][p] = c["members"].get(p, 0) + f
                    c["total"] += other["total"]
                    clusters.pop(i)
                    merged = True
                else:
                    i += 1
            new_clusters.append(c)
        clusters = new_clusters
    
    clusters_info = []
    for c in clusters:
        rep_pos, rep_count = max(c["members"].items(), key=lambda x: x[1])
        clusters_info.append({
            "rep_pos": int(rep_pos),
            "rep_count": int(rep_count),
            "total": int(c["total"]),
            "members": sorted(c["members"].keys()),
            "contains_target": (target_position in c["members"])
        })
    
    filtered = [c for c in clusters_info if c["total"] > min_reads]
    if not any(c["contains_target"] for c in filtered):
        for c in clusters_info:
            if c["contains_target"]:
                filtered.append(c)
                break
    
    mcv_counts[sample_id] = len(filtered)

# Report
print("=" * 60)
print("MCV COUNT SUMMARY")
print("=" * 60)
print()

for sample_id in sorted(mcv_counts.keys()):
    num_mcvs = mcv_counts[sample_id]
    print(f"Sample {sample_id:3d}: {num_mcvs:3d} MCVs")

total_mcvs = sum(mcv_counts.values())
num_samples = len(mcv_counts)

print()
print("-" * 60)
print(f"Total MCVs across {num_samples} samples: {total_mcvs}")
print(f"Average MCVs per sample: {total_mcvs / num_samples:.1f}")
print("=" * 60)
# Out:
# ============================================================
# MCV COUNT SUMMARY
# ============================================================
#
# Sample   1:   4 MCVs
# Sample   2:   4 MCVs
# Sample   3:   4 MCVs
# Sample   4:   3 MCVs
# Sample   5:   4 MCVs
# Sample   6:   3 MCVs
# Sample   7:   4 MCVs
# Sample   8:   4 MCVs
# Sample   9:   4 MCVs
# Sample  10:   3 MCVs
# Sample  11:   2 MCVs
# Sample  12:   5 MCVs
# Sample  13:   3 MCVs
# Sample  14:   4 MCVs
# Sample  15:   5 MCVs
# Sample  16:   3 MCVs
# Sample  17:   4 MCVs
# Sample  18:   6 MCVs
# Sample  19:   6 MCVs
# Sample  20:   5 MCVs
# Sample  21:   5 MCVs
# Sample  22:   7 MCVs
# Sample  23:   3 MCVs
# Sample  24:   3 MCVs
# Sample  25:   3 MCVs
# Sample  26:   4 MCVs
# Sample  27:   2 MCVs
# Sample  28:   6 MCVs
# Sample  29:   4 MCVs
# Sample  30:   5 MCVs
# Sample  31:   3 MCVs
# Sample  32:   4 MCVs
# Sample  33:   4 MCVs
# Sample  34:   8 MCVs
# Sample  35:   8 MCVs
# Sample  36:   4 MCVs
# Sample  37:   5 MCVs
# Sample  38:   5 MCVs
# Sample  39:   2 MCVs
# Sample  40:   4 MCVs
# Sample  41:   7 MCVs
# Sample  42:   7 MCVs
# Sample  43:   3 MCVs
# Sample  44:  11 MCVs
# Sample  45:   5 MCVs
# Sample  46:   5 MCVs
# Sample  47:   6 MCVs
# Sample  48:  11 MCVs
# Sample  49:   5 MCVs
# Sample  50:  11 MCVs
# Sample  51:   8 MCVs
# Sample  52:   7 MCVs
# Sample  53:  12 MCVs
# Sample  54:   7 MCVs
# Sample  55:  13 MCVs
# Sample  56:   6 MCVs
# Sample  57:  14 MCVs
# Sample  58:   8 MCVs
# Sample  59:   7 MCVs
# Sample  60:  12 MCVs
# Sample  61:   9 MCVs
# Sample  62:   9 MCVs
# Sample  63:   8 MCVs
# Sample  64:   9 MCVs
# Sample  65:   4 MCVs
# Sample  66:  11 MCVs
# Sample  67:  10 MCVs
# Sample  68:   7 MCVs
# Sample  69:   9 MCVs
# Sample  70:   2 MCVs
# Sample  71:   6 MCVs
# Sample  72:   6 MCVs
# Sample  73:   8 MCVs
# Sample  74:   8 MCVs
# Sample  75:  10 MCVs
# Sample  76:   7 MCVs
# Sample  77:  11 MCVs
# Sample  78:   6 MCVs
# Sample  79:   6 MCVs
# Sample  80:   5 MCVs
# Sample  81:   9 MCVs
# Sample  82:   6 MCVs
# Sample  83:  10 MCVs
# Sample  84:  12 MCVs
# Sample  85:   7 MCVs
# Sample  86:   6 MCVs
# Sample  87:   4 MCVs
# Sample  88:   7 MCVs
# Sample  89:   7 MCVs
# Sample  90:   9 MCVs
# Sample  91:  11 MCVs
# Sample  92:   2 MCVs
# Sample  93:   6 MCVs
# Sample  94:  10 MCVs
# Sample  95:   7 MCVs
# Sample  96:  11 MCVs
# Sample  97:   4 MCVs
# Sample  98:   5 MCVs
# Sample  99:   4 MCVs
# Sample 100:   6 MCVs
# Sample 101:   3 MCVs
# Sample 102:   5 MCVs
# Sample 103:   6 MCVs
# Sample 104:  12 MCVs
# Sample 105:   8 MCVs
# Sample 106:   9 MCVs
# Sample 107:   9 MCVs
# Sample 108:   2 MCVs
# Sample 109:   8 MCVs
# Sample 110:  11 MCVs
# Sample 111:   6 MCVs
# Sample 112:   5 MCVs
# Sample 113:   9 MCVs
# Sample 114:  15 MCVs
# Sample 115:   7 MCVs
# Sample 116:  10 MCVs
# Sample 117:   7 MCVs
# Sample 118:   2 MCVs
# Sample 119:  16 MCVs
# Sample 120:   5 MCVs
#
# ------------------------------------------------------------
# Total MCVs across 120 samples: 783
# Average MCVs per sample: 6.5
# ============================================================

# %%
# Bulk run: execute the existing per-sample processing for each TSV, writing CSVs to output_csv_dir
# NOTE: This cell does not change any processing logic; it only loops over files and directs CSV output.

import re
import pandas as pd
from collections import Counter

def _sample_id_from_name(p: Path):
    m = re.match(r"(\d+)_S\1_", p.name)
    return int(m.group(1)) if m else None

written = []
skipped = []

for nn, tsv_path in enumerate(tsv_files):
    sample_id = _sample_id_from_name(tsv_path) or (nn + 1)

    # --- existing cell 2 behavior (load + min-mapq filter) ---
    tsv = pd.read_csv(tsv_path, sep="\t")
    tsv = tsv[tsv["mapq"] >= min_mapq]

    # --- existing cell 6 behavior (hotspot collapse) ---
    collapse_bp = 5
    min_reads = 500
    save_csv = False  # unchanged (MCV CSV disabled)

    counts = Counter(tsv["ins0"])

    gmap = php.map_guide_to_genome(guideRNA["protospacer"][nn], genome_sequence)
    target_position = gmap[0]["start"]
    counts[target_position] = counts.get(target_position, 0)

    clusters = [{"members": {pos: freq}, "total": freq} for pos, freq in counts.items()]

    merged = True
    while merged:
        merged = False
        new_clusters = []
        while clusters:
            c = clusters.pop(0)
            i = 0
            while i < len(clusters):
                other = clusters[i]
                close = any(abs(p - q) <= collapse_bp for p in c["members"] for q in other["members"])
                if close:
                    for p, f in other["members"].items():
                        c["members"][p] = c["members"].get(p, 0) + f
                    c["total"] += other["total"]
                    clusters.pop(i)
                    merged = True
                else:
                    i += 1
            new_clusters.append(c)
        clusters = new_clusters

    clusters_info = []
    for c in clusters:
        rep_pos, rep_count = max(c["members"].items(), key=lambda x: x[1])
        clusters_info.append({
            "rep_pos": int(rep_pos),
            "rep_count": int(rep_count),
            "total": int(c["total"]),
            "members": sorted(c["members"].keys()),
            "contains_target": (target_position in c["members"])
        })

    filtered = [c for c in clusters_info if c["total"] > min_reads]
    if not any(c["contains_target"] for c in filtered):
        for c in clusters_info:
            if c["contains_target"]:
                filtered.append(c)
                break

    filtered.sort(key=lambda x: x["total"], reverse=True)
    for idx, c in enumerate(filtered, start=1):
        c["mcv_id"] = idx

    mcv_list = [c["rep_pos"] for c in filtered]
    hotspots = {f"mcv{idx}": pos for idx, pos in enumerate(mcv_list, start=1)}
    for idx, pos in enumerate(mcv_list, start=1):
        globals()[f"mcv{idx}"] = pos

    # --- existing cell 10 behavior (methods 1/2/3 combined output) ---
    def revcomp(seq):
        comp = str.maketrans("ACGTacgt", "TGCAtgca")
        return seq.translate(comp)[::-1]

    original_guide = guideRNA["protospacer"][nn]

    if "hotspots" in globals() and isinstance(hotspots, dict) and hotspots:
        hotspots_dict = hotspots
    elif "mcv_list" in globals():
        hotspots_dict = {f"mcv{i+1}": pos for i, pos in enumerate(mcv_list)}
    else:
        hotspots_dict = {}
        for i in range(1, 101):
            name = f"mcv{i}"
            if name in globals():
                hotspots_dict[name] = globals()[name]
            else:
                break

    _alignment_ctx = {}
    for hotspot_name, insertion_site in hotspots_dict.items():
        window_start = max(0, insertion_site - 120)
        window_end = min(len(genome_sequence), insertion_site + 120)
        window_seq = genome_sequence[window_start:window_end]

        aln_fwd = php.local_align(original_guide, window_seq)
        aln_rev = php.local_align(original_guide, revcomp(window_seq))

        if aln_fwd.score >= aln_rev.score:
            best_aln = aln_fwd
            best_strand = "+"
            search_seq = window_seq
        else:
            best_aln = aln_rev
            best_strand = "-"
            search_seq = revcomp(window_seq)

        _alignment_ctx[hotspot_name] = {
            "insertion_site": insertion_site,
            "window_start": window_start,
            "window_end": window_end,
            "window_seq": window_seq,
            "best_aln": best_aln,
            "best_strand": best_strand,
            "search_seq": search_seq,
        }

    rows = []

    window_radius = 120
    for hotspot_name, insertion_site in hotspots_dict.items():
        win_start = max(0, insertion_site - window_radius)
        win_end = min(len(genome_sequence), insertion_site + window_radius)
        win_seq = genome_sequence[win_start:win_end]

        for i in range(len(win_seq) - 2):
            pam = win_seq[i:i+3]
            if pam[1:3] == "GG":
                pam_genomic_start = win_start + i
                pam_genomic_end = pam_genomic_start + 3
                guide_start = pam_genomic_start - 20
                guide_end = pam_genomic_start
                if guide_start < 0:
                    continue
                guide_seq = genome_sequence[guide_start:guide_end]
                dist = abs((pam_genomic_end - 1) - insertion_site)
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 1,
                    "pam_type": "NGG",
                    "pam_seq": pam,
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "+",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(dist),
                    "insertion_site": int(insertion_site)
                })

        for i in range(len(win_seq) - 2):
            motif = win_seq[i:i+3]
            if motif[0:2] == "CC":
                pam_genomic_start = win_start + i
                pam_genomic_end = pam_genomic_start + 3
                guide_start = pam_genomic_end
                guide_end = guide_start + 20
                if guide_end > len(genome_sequence):
                    continue
                guide_seq = revcomp(genome_sequence[guide_start:guide_end])
                dist = abs(pam_genomic_start - insertion_site)
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 1,
                    "pam_type": "NGG",
                    "pam_seq": revcomp(motif),
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "-",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(dist),
                    "insertion_site": int(insertion_site)
                })

    for hotspot_name, ctx in _alignment_ctx.items():
        insertion_site = ctx["insertion_site"]
        window_start = ctx["window_start"]
        window_seq = ctx["window_seq"]
        best_aln = ctx["best_aln"]
        best_strand = ctx["best_strand"]
        search_seq = ctx["search_seq"]

        target_coords = best_aln.coordinates[1]
        target_start = int(target_coords[0])
        target_end = int(target_coords[-1])

        if best_strand == "+":
            genomic_start = window_start + target_start
            genomic_end = window_start + target_end
        else:
            genomic_start = window_start + (len(window_seq) - target_end)
            genomic_end = window_start + (len(window_seq) - target_start)

        coords_q = best_aln.coordinates[0]
        coords_t = best_aln.coordinates[1]

        query_seq = best_aln.query
        target_seq = best_aln.target

        first_match_query_pos = None
        first_match_target_pos = None
        query_pos = 0
        target_pos = 0
        for q, t in zip(query_seq, target_seq):
            if q != "-" and t != "-" and q == t:
                first_match_query_pos = query_pos
                first_match_target_pos = target_pos
                break
            if q != "-":
                query_pos += 1
            if t != "-":
                target_pos += 1

        if first_match_query_pos is not None:
            first_match_genomic = genomic_start + first_match_target_pos
            new_guide_start = first_match_genomic - first_match_query_pos
            new_guide_end = new_guide_start + 20
            if 0 <= new_guide_start and new_guide_end <= len(genome_sequence):
                if best_strand == "+":
                    new_guide = genome_sequence[new_guide_start:new_guide_end]
                    new_guide_gstart = new_guide_start
                    new_guide_gend = new_guide_end
                else:
                    new_guide = revcomp(genome_sequence[new_guide_start:new_guide_end])
                    new_guide_gstart = new_guide_start
                    new_guide_gend = new_guide_end

                if best_strand == "+":
                    five_prime_start = target_start - 3
                    five_prime_end = target_start
                    five_prime_seq = window_seq[five_prime_start:five_prime_end] if five_prime_start >= 0 else ""
                    distance_to_mcv = abs(new_guide_gstart - insertion_site)
                else:
                    five_prime_start = target_end
                    five_prime_end = target_end + 3
                    five_prime_seq = revcomp(window_seq)[five_prime_start:five_prime_end] if five_prime_end <= len(window_seq) else ""
                    distance_to_mcv = abs(new_guide_gend - insertion_site)

                pam_type = None
                pam_seq = five_prime_seq
                if len(pam_seq) == 3:
                    if pam_seq[1:3] == "GG":
                        pam_type = "NGG"
                    elif pam_seq[1:3] == "AG":
                        pam_type = "NAG"
                    elif pam_seq[1:3] == "GA":
                        pam_type = "NGA"

                if pam_type:
                    mismatch_count = sum(a != b for a, b in zip(original_guide, new_guide))
                    try:
                        aln_score = php.local_align(original_guide, new_guide).score
                    except Exception:
                        aln_score = None

                    rows.append({
                        "hotspot": hotspot_name,
                        "method": 2,
                        "pam_type": pam_type,
                        "pam_seq": pam_seq,
                        "guide_seq": new_guide,
                        "guide_start": int(new_guide_gstart),
                        "guide_end": int(new_guide_gend),
                        "strand": best_strand,
                        "mismatch_count": int(mismatch_count),
                        "alignment_score": aln_score,
                        "distance_to_mcv": int(distance_to_mcv),
                        "insertion_site": int(insertion_site)
                    })

    for hotspot_name, ctx in _alignment_ctx.items():
        insertion_site = ctx["insertion_site"]
        window_start = ctx["window_start"]
        window_seq = ctx["window_seq"]
        best_aln = ctx["best_aln"]
        best_strand = ctx["best_strand"]

        target_coords = best_aln.coordinates[1]
        target_start = int(target_coords[0])
        target_end = int(target_coords[-1])

        if best_strand == "+":
            genomic_start = window_start + target_start
            genomic_end = window_start + target_end
        else:
            genomic_start = window_start + (len(window_seq) - target_end)
            genomic_end = window_start + (len(window_seq) - target_start)

        alignment_center = (genomic_start + genomic_end) // 2
        pam_search_start = max(0, alignment_center - 25)
        pam_search_end = min(len(genome_sequence), alignment_center + 25)
        pam_search_seq = genome_sequence[pam_search_start:pam_search_end]

        for i in range(len(pam_search_seq) - 2):
            pam_motif = pam_search_seq[i:i+3]
            pam_type = None
            if pam_motif[1:3] == "GG":
                pam_type = "NGG"
            elif pam_motif[1:3] == "AG":
                pam_type = "NAG"
            elif pam_motif[1:3] == "GA":
                pam_type = "NGA"
            if not pam_type:
                continue

            pam_genomic_start = pam_search_start + i
            pam_genomic_end = pam_genomic_start + 3

            guide_start = pam_genomic_start - 20
            guide_end = pam_genomic_start
            if guide_start >= 0:
                guide_seq = genome_sequence[guide_start:guide_end]
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                distance_to_mcv = abs(pam_genomic_end - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 3,
                    "pam_type": pam_type,
                    "pam_seq": genome_sequence[pam_genomic_start:pam_genomic_end],
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "+",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(distance_to_mcv),
                    "insertion_site": int(insertion_site)
                })

        for i in range(len(pam_search_seq) - 2):
            pam_motif = pam_search_seq[i:i+3]
            pam_type = None
            if pam_motif[0:2] == "CC":
                pam_type = "NGG"
            elif pam_motif[0:2] == "CT":
                pam_type = "NAG"
            elif pam_motif[0:2] == "TC":
                pam_type = "NGA"
            if not pam_type:
                continue

            pam_genomic_start = pam_search_start + i
            pam_genomic_end = pam_genomic_start + 3

            guide_start = pam_genomic_end
            guide_end = guide_start + 20
            if guide_end <= len(genome_sequence):
                guide_seq = revcomp(genome_sequence[guide_start:guide_end])
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                distance_to_mcv = abs(pam_genomic_start - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 3,
                    "pam_type": pam_type,
                    "pam_seq": revcomp(genome_sequence[pam_genomic_start:pam_genomic_end]),
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "-",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(distance_to_mcv),
                    "insertion_site": int(insertion_site)
                })

    def compute_pam_coords(row):
        try:
            gs = int(row["guide_start"]); ge = int(row["guide_end"]); strand = row["strand"]
        except Exception:
            return pd.Series([None, None])
        if strand == "+":
            return pd.Series([ge, ge + 3])
        else:
            return pd.Series([gs - 3, gs])

    df = pd.DataFrame(rows)
    if df.empty:
        skipped.append((sample_id, str(tsv_path), "No candidates generated"))
        continue

    df[["pam_start", "pam_end"]] = df.apply(compute_pam_coords, axis=1)
    df = df.dropna(subset=["pam_start", "pam_end"]).reset_index(drop=True)
    df["pam_start"] = df["pam_start"].astype(int)
    df["pam_end"] = df["pam_end"].astype(int)

    pams_unique = df[["hotspot","pam_start","pam_end","pam_type"]].drop_duplicates().reset_index(drop=True)

    def overlap(a_s, a_e, b_s, b_e):
        return (a_s < b_e) and (b_s < a_e)

    pams_unique["overlap_any"] = False
    pams_unique["overlap_noncanonical"] = False
    pams_unique["adj_left_any"] = False
    pams_unique["adj_left_noncanonical"] = False
    pams_unique["adj_right_any"] = False
    pams_unique["adj_right_noncanonical"] = False

    for idx, p in pams_unique.iterrows():
        ps, pe, ptype, hotspot = int(p.pam_start), int(p.pam_end), p.pam_type, p.hotspot
        partners = pams_unique[(pams_unique.hotspot == hotspot) & ~((pams_unique.pam_start == ps) & (pams_unique.pam_end == pe))]
        for _, q in partners.iterrows():
            qs, qe, qtype = int(q.pam_start), int(q.pam_end), q.pam_type
            if overlap(ps,pe,qs,qe):
                pams_unique.at[idx,"overlap_any"] = True
                if qtype != "NGG":
                    pams_unique.at[idx,"overlap_noncanonical"] = True
            if qe == ps:
                pams_unique.at[idx,"adj_left_any"] = True
                if qtype != "NGG":
                    pams_unique.at[idx,"adj_left_noncanonical"] = True
            if qs == pe:
                pams_unique.at[idx,"adj_right_any"] = True
                if qtype != "NGG":
                    pams_unique.at[idx,"adj_right_noncanonical"] = True

    df = df.merge(pams_unique, on=["hotspot","pam_start","pam_end","pam_type"], how="left", suffixes=("","_u"))
    df_ngg = df[df["pam_type"] == "NGG"].copy()

    cols = ["hotspot","method","pam_seq","guide_seq","distance_to_mcv", "guide_start","guide_end","strand",
            "pam_start","pam_end","overlap_any","overlap_noncanonical","adj_left_any","adj_left_noncanonical",
            "adj_right_any","adj_right_noncanonical","mismatch_count","alignment_score","insertion_site"]

    out_name = output_csv_dir / f"{sample_id}_guide_candidates_combined_methods.csv"
    df_ngg.to_csv(out_name, index=False)
    written.append((sample_id, str(tsv_path), str(out_name), len(df_ngg)))

print(f"\nDone. Wrote {len(written)} CSVs to: {output_csv_dir}")
if skipped:
    print(f"Skipped {len(skipped)} samples (no candidates):")
    for s in skipped[:10]:
        print("  ", s)
# Out:
# Done. Wrote 120 CSVs to: /Users/ecreed/Desktop/KelloggRotation/02052026_TagmentatioAnalysis_251218_260117_260203_combined/CandidateSpacersBulk

# %%
# bulk run + filtering by NGG and distance
# Bulk: write per-sample CSVs but only include NGG guides 66-76 bp from their mcv
import re
import pandas as pd
from collections import Counter
from pathlib import Path

def revcomp(seq):
    comp = str.maketrans("ACGTacgt", "TGCAtgca")
    return seq.translate(comp)[::-1]

def _sample_id_from_name(p: Path):
    m = re.match(r"(\d+)_S\1_", p.name)
    return int(m.group(1)) if m else None

written = []
skipped = []

for nn, tsv_path in enumerate(tsv_files):
    sample_id = _sample_id_from_name(tsv_path) or (nn + 1)

    # load + basic filter (min_mapq expected in notebook)
    tsv = pd.read_csv(tsv_path, sep="\t")
    tsv = tsv[tsv["mapq"] >= min_mapq]

    # collapse hotspots (same logic as before)
    collapse_bp = 5
    min_reads = 500

    counts = Counter(tsv["ins0"])
    gmap = php.map_guide_to_genome(guideRNA["protospacer"][nn], genome_sequence)
    target_position = gmap[0]["start"]
    counts[target_position] = counts.get(target_position, 0)

    clusters = [{"members": {pos: freq}, "total": freq} for pos, freq in counts.items()]
    merged = True
    while merged:
        merged = False
        new_clusters = []
        while clusters:
            c = clusters.pop(0)
            i = 0
            while i < len(clusters):
                other = clusters[i]
                close = any(abs(p - q) <= collapse_bp for p in c["members"] for q in other["members"])
                if close:
                    for p, f in other["members"].items():
                        c["members"][p] = c["members"].get(p, 0) + f
                    c["total"] += other["total"]
                    clusters.pop(i)
                    merged = True
                else:
                    i += 1
            new_clusters.append(c)
        clusters = new_clusters

    clusters_info = []
    for c in clusters:
        rep_pos, rep_count = max(c["members"].items(), key=lambda x: x[1])
        clusters_info.append({
            "rep_pos": int(rep_pos),
            "rep_count": int(rep_count),
            "total": int(c["total"]),
            "members": sorted(c["members"].keys()),
            "contains_target": (target_position in c["members"])
        })

    filtered = [c for c in clusters_info if c["total"] > min_reads]
    if not any(c["contains_target"] for c in filtered):
        for c in clusters_info:
            if c["contains_target"]:
                filtered.append(c)
                break

    filtered.sort(key=lambda x: x["total"], reverse=True)
    for idx, c in enumerate(filtered, start=1):
        c["mcv_id"] = idx

    mcv_list = [c["rep_pos"] for c in filtered]
    hotspots = {f"mcv{idx}": pos for idx, pos in enumerate(mcv_list, start=1)}
    for idx, pos in enumerate(mcv_list, start=1):
        globals()[f"mcv{idx}"] = pos

    # Generate guides (methods 1,2,3) exactly as before
    original_guide = guideRNA["protospacer"][nn]
    hotspots_dict = hotspots if (isinstance(hotspots, dict) and hotspots) else ({f"mcv{i+1}": pos for i,pos in enumerate(mcv_list)} if "mcv_list" in globals() else {})
    _alignment_ctx = {}
    for hotspot_name, insertion_site in hotspots_dict.items():
        window_start = max(0, insertion_site - 120)
        window_end = min(len(genome_sequence), insertion_site + 120)
        window_seq = genome_sequence[window_start:window_end]

        aln_fwd = php.local_align(original_guide, window_seq)
        aln_rev = php.local_align(original_guide, revcomp(window_seq))

        if aln_fwd.score >= aln_rev.score:
            best_aln = aln_fwd
            best_strand = "+"
            search_seq = window_seq
        else:
            best_aln = aln_rev
            best_strand = "-"
            search_seq = revcomp(window_seq)

        _alignment_ctx[hotspot_name] = {
            "insertion_site": insertion_site,
            "window_start": window_start,
            "window_end": window_end,
            "window_seq": window_seq,
            "best_aln": best_aln,
            "best_strand": best_strand,
            "search_seq": search_seq,
        }

    rows = []
    window_radius = 120
    # Method 1
    for hotspot_name, insertion_site in hotspots_dict.items():
        win_start = max(0, insertion_site - window_radius)
        win_end = min(len(genome_sequence), insertion_site + window_radius)
        win_seq = genome_sequence[win_start:win_end]

        for i in range(len(win_seq) - 2):
            pam = win_seq[i:i+3]
            if pam[1:3] == "GG":
                pam_genomic_start = win_start + i
                pam_genomic_end = pam_genomic_start + 3
                guide_start = pam_genomic_start - 20
                guide_end = pam_genomic_start
                if guide_start < 0:
                    continue
                guide_seq = genome_sequence[guide_start:guide_end]
                dist = abs((pam_genomic_end - 1) - insertion_site)
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 1,
                    "pam_type": "NGG",
                    "pam_seq": pam,
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "+",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(dist),
                    "insertion_site": int(insertion_site)
                })

        for i in range(len(win_seq) - 2):
            motif = win_seq[i:i+3]
            if motif[0:2] == "CC":
                pam_genomic_start = win_start + i
                pam_genomic_end = pam_genomic_start + 3
                guide_start = pam_genomic_end
                guide_end = guide_start + 20
                if guide_end > len(genome_sequence):
                    continue
                guide_seq = revcomp(genome_sequence[guide_start:guide_end])
                dist = abs(pam_genomic_start - insertion_site)
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 1,
                    "pam_type": "NGG",
                    "pam_seq": revcomp(motif),
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "-",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(dist),
                    "insertion_site": int(insertion_site)
                })

    # Method 2
    for hotspot_name, ctx in _alignment_ctx.items():
        insertion_site = ctx["insertion_site"]
        window_start = ctx["window_start"]
        window_seq = ctx["window_seq"]
        best_aln = ctx["best_aln"]
        best_strand = ctx["best_strand"]
        search_seq = ctx["search_seq"]

        target_coords = best_aln.coordinates[1]
        target_start = int(target_coords[0])
        target_end = int(target_coords[-1])

        if best_strand == "+":
            genomic_start = window_start + target_start
            genomic_end = window_start + target_end
        else:
            genomic_start = window_start + (len(window_seq) - target_end)
            genomic_end = window_start + (len(window_seq) - target_start)

        query_seq = best_aln.query
        target_seq = best_aln.target

        first_match_query_pos = None
        first_match_target_pos = None
        query_pos = 0
        target_pos = 0
        for q, t in zip(query_seq, target_seq):
            if q != '-' and t != '-' and q == t:
                first_match_query_pos = query_pos
                first_match_target_pos = target_pos
                break
            if q != '-':
                query_pos += 1
            if t != '-':
                target_pos += 1

        if first_match_query_pos is not None:
            first_match_genomic = genomic_start + first_match_target_pos
            new_guide_start = first_match_genomic - first_match_query_pos
            new_guide_end = new_guide_start + 20
            if 0 <= new_guide_start and new_guide_end <= len(genome_sequence):
                if best_strand == "+":
                    new_guide = genome_sequence[new_guide_start:new_guide_end]
                    new_guide_gstart = new_guide_start
                    new_guide_gend = new_guide_end
                else:
                    new_guide = revcomp(genome_sequence[new_guide_start:new_guide_end])
                    new_guide_gstart = new_guide_start
                    new_guide_gend = new_guide_end

                if best_strand == "+":
                    five_prime_start = target_start - 3
                    five_prime_end = target_start
                    five_prime_seq = window_seq[five_prime_start:five_prime_end] if five_prime_start >= 0 else ""
                    distance_to_mcv = abs(new_guide_gstart - insertion_site)
                else:
                    five_prime_start = target_end
                    five_prime_end = target_end + 3
                    five_prime_seq = revcomp(window_seq)[five_prime_start:five_prime_end] if five_prime_end <= len(window_seq) else ""
                    distance_to_mcv = abs(new_guide_gend - insertion_site)

                pam_type = None
                pam_seq = five_prime_seq
                if len(pam_seq) == 3:
                    if pam_seq[1:3] == "GG":
                        pam_type = "NGG"
                    elif pam_seq[1:3] == "AG":
                        pam_type = "NAG"
                    elif pam_seq[1:3] == "GA":
                        pam_type = "NGA"

                if pam_type:
                    mismatch_count = sum(a != b for a, b in zip(original_guide, new_guide))
                    try:
                        aln_score = php.local_align(original_guide, new_guide).score
                    except Exception:
                        aln_score = None

                    rows.append({
                        "hotspot": hotspot_name,
                        "method": 2,
                        "pam_type": pam_type,
                        "pam_seq": pam_seq,
                        "guide_seq": new_guide,
                        "guide_start": int(new_guide_gstart),
                        "guide_end": int(new_guide_gend),
                        "strand": best_strand,
                        "mismatch_count": int(mismatch_count),
                        "alignment_score": aln_score,
                        "distance_to_mcv": int(distance_to_mcv),
                        "insertion_site": int(insertion_site)
                    })

    # Method 3
    for hotspot_name, ctx in _alignment_ctx.items():
        insertion_site = ctx["insertion_site"]
        window_start = ctx["window_start"]
        window_seq = ctx["window_seq"]
        best_aln = ctx["best_aln"]
        best_strand = ctx["best_strand"]

        target_coords = best_aln.coordinates[1]
        target_start = int(target_coords[0])
        target_end = int(target_coords[-1])

        if best_strand == "+":
            genomic_start = window_start + target_start
            genomic_end = window_start + target_end
        else:
            genomic_start = window_start + (len(window_seq) - target_end)
            genomic_end = window_start + (len(window_seq) - target_start)

        alignment_center = (genomic_start + genomic_end) // 2
        pam_search_start = max(0, alignment_center - 25)
        pam_search_end = min(len(genome_sequence), alignment_center + 25)
        pam_search_seq = genome_sequence[pam_search_start:pam_search_end]

        for i in range(len(pam_search_seq) - 2):
            pam_motif = pam_search_seq[i:i+3]
            pam_type = None
            if pam_motif[1:3] == "GG":
                pam_type = "NGG"
            elif pam_motif[1:3] == "AG":
                pam_type = "NAG"
            elif pam_motif[1:3] == "GA":
                pam_type = "NGA"
            if not pam_type:
                continue

            pam_genomic_start = pam_search_start + i
            pam_genomic_end = pam_genomic_start + 3

            guide_start = pam_genomic_start - 20
            guide_end = pam_genomic_start
            if guide_start >= 0:
                guide_seq = genome_sequence[guide_start:guide_end]
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                distance_to_mcv = abs(pam_genomic_end - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 3,
                    "pam_type": pam_type,
                    "pam_seq": genome_sequence[pam_genomic_start:pam_genomic_end],
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "+",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(distance_to_mcv),
                    "insertion_site": int(insertion_site)
                })

        for i in range(len(pam_search_seq) - 2):
            pam_motif = pam_search_seq[i:i+3]
            pam_type = None
            if pam_motif[0:2] == "CC":
                pam_type = "NGG"
            elif pam_motif[0:2] == "CT":
                pam_type = "NAG"
            elif pam_motif[0:2] == "TC":
                pam_type = "NGA"
            if not pam_type:
                continue

            pam_genomic_start = pam_search_start + i
            pam_genomic_end = pam_genomic_start + 3

            guide_start = pam_genomic_end
            guide_end = guide_start + 20
            if guide_end <= len(genome_sequence):
                guide_seq = revcomp(genome_sequence[guide_start:guide_end])
                mismatch_count = sum(a != b for a, b in zip(original_guide, guide_seq))
                try:
                    aln_score = php.local_align(original_guide, guide_seq).score
                except Exception:
                    aln_score = None
                distance_to_mcv = abs(pam_genomic_start - insertion_site)
                rows.append({
                    "hotspot": hotspot_name,
                    "method": 3,
                    "pam_type": pam_type,
                    "pam_seq": revcomp(genome_sequence[pam_genomic_start:pam_genomic_end]),
                    "guide_seq": guide_seq,
                    "guide_start": int(guide_start),
                    "guide_end": int(guide_end),
                    "strand": "-",
                    "mismatch_count": int(mismatch_count),
                    "alignment_score": aln_score,
                    "distance_to_mcv": int(distance_to_mcv),
                    "insertion_site": int(insertion_site)
                })

    # assemble DataFrame and compute PAM coords
    def compute_pam_coords(row):
        try:
            gs = int(row['guide_start']); ge = int(row['guide_end']); strand = row['strand']
        except Exception:
            return pd.Series([None, None])
        if strand == "+":
            return pd.Series([ge, ge + 3])
        else:
            return pd.Series([gs - 3, gs])

    df = pd.DataFrame(rows)
    if df.empty:
        skipped.append((sample_id, str(tsv_path), "No candidates generated"))
        continue

    df[['pam_start', 'pam_end']] = df.apply(compute_pam_coords, axis=1)
    df = df.dropna(subset=['pam_start','pam_end']).reset_index(drop=True)
    df['pam_start'] = df['pam_start'].astype(int)
    df['pam_end'] = df['pam_end'].astype(int)

    pams_unique = df[['hotspot','pam_start','pam_end','pam_type']].drop_duplicates().reset_index(drop=True)
    def overlap(a_s, a_e, b_s, b_e):
        return (a_s < b_e) and (b_s < a_e)

    pams_unique['overlap_any'] = False
    pams_unique['overlap_noncanonical'] = False
    pams_unique['adj_left_any'] = False
    pams_unique['adj_left_noncanonical'] = False
    pams_unique['adj_right_any'] = False
    pams_unique['adj_right_noncanonical'] = False

    for idx, p in pams_unique.iterrows():
        ps, pe, ptype, hotspot = int(p.pam_start), int(p.pam_end), p.pam_type, p.hotspot
        partners = pams_unique[(pams_unique.hotspot == hotspot) & ~((pams_unique.pam_start == ps) & (pams_unique.pam_end == pe))]
        for _, q in partners.iterrows():
            qs, qe, qtype = int(q.pam_start), int(q.pam_end), q.pam_type
            if overlap(ps,pe,qs,qe):
                pams_unique.at[idx,'overlap_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'overlap_noncanonical'] = True
            if qe == ps:
                pams_unique.at[idx,'adj_left_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'adj_left_noncanonical'] = True
            if qs == pe:
                pams_unique.at[idx,'adj_right_any'] = True
                if qtype != "NGG":
                    pams_unique.at[idx,'adj_right_noncanonical'] = True

    df = df.merge(pams_unique, on=['hotspot','pam_start','pam_end','pam_type'], how='left', suffixes=('','_u'))

    # Keep only NGG rows and then further filter 66-76 bp
    df_ngg = df[df['pam_type'] == 'NGG'].copy()
    df_ngg_filtered = df_ngg[df_ngg['distance_to_mcv'].between(66, 76)].copy()

    if df_ngg_filtered.empty:
        skipped.append((sample_id, str(tsv_path), "No NGG candidates 66-76 bp"))
        continue

    out_name = output_csv_dir / f"{sample_id}_guide_candidates_NGG_66-76bp.csv"
    df_ngg_filtered.to_csv(out_name, index=False)
    written.append((sample_id, str(tsv_path), str(out_name), len(df_ngg_filtered)))

print(f"\nDone. Wrote {len(written)} CSVs to: {output_csv_dir}")
if skipped:
    print(f"Skipped {len(skipped)} samples (no candidates after filtering):")
    for s in skipped[:10]:
        print(" ", s)
# Out:
# Done. Wrote 120 CSVs to: /Users/ecreed/Desktop/KelloggRotation/02052026_TagmentatioAnalysis_251218_260117_260203_combined/FilteredCandidateSpacersBulk
